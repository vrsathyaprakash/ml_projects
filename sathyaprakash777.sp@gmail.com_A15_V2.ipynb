# %% [markdown]
# <p style="font-size:36px;text-align:center"> <b>Personalized cancer diagnosis</b> </p>

# %% [markdown]
# <h1>1. Business Problem</h1>

# %% [markdown]
# <h2>1.1. Description</h2>

# %% [markdown]
# <p> Source: https://www.kaggle.com/c/msk-redefining-cancer-treatment/ </p>
# <p> Data: Memorial Sloan Kettering Cancer Center (MSKCC)</p>
# <p> Download training_variants.zip and training_text.zip from Kaggle.</p>
#
# <h6> Context:</h6>
# <p> Source: https://www.kaggle.com/c/msk-redefining-cancer-treatment/discussion/35336#198462</p>
#
# <h6> Problem statement : </h6>
# <p> Classify the given genetic variations/mutations based on evidence from text-based clinical literature. </p>

# %% [markdown]
# <h2>1.2. Source/Useful Links</h2>

# %% [markdown]
#  Some articles and reference blogs about the problem statement

# %% [markdown]
# 1. https://www.forbes.com/sites/matthewherper/2017/06/03/a-new-cancer-drug-helped-almost-everyone-who-took-it-almost-heres-what-it-teaches-us/#2a44ee2f6b25
# 2. https://www.youtube.com/watch?v=UwbuW7oK8rk
# 3. https://www.youtube.com/watch?v=qxXRKVompI8

# %% [markdown]
# <h2>1.3. Real-world/Business objectives and constraints.</h2>

# %% [markdown]
# * No low-latency requirement.
# * Interpretability is important.
# * Errors can be very costly.
# * Probability of a data-point belonging to each class is needed.

# %% [markdown]
# <h1>2. Machine Learning Problem Formulation</h1>

# %% [markdown]
# <h2>2.1. Data</h2>

# %% [markdown]
# <h3>2.1.1. Data Overview</h3>

# %% [markdown]
# - Source: https://www.kaggle.com/c/msk-redefining-cancer-treatment/data
# - We have two data files: one conatins the information about the genetic mutations and the other contains the clinical evidence (text) that  human experts/pathologists use to classify the genetic mutations.
# - Both these data files are have a common column called ID
# - <p>
#     Data file's information:
#     <ul>
#         <li>
#         training_variants (ID , Gene, Variations, Class)
#         </li>
#         <li>
#         training_text (ID, Text)
#         </li>
#     </ul>
# </p>

# %% [markdown]
# <h3>2.1.2. Example Data Point</h3>

# %% [markdown]
# <h6>training_variants</h6>
# <hr>
# ID,Gene,Variation,Class<br>
# 0,FAM58A,Truncating Mutations,1 <br>
# 1,CBL,W802*,2 <br>
# 2,CBL,Q249E,2 <br>
# ...
#
# <h6> training_text</h6>
# <hr>
# ID,Text <br>
# 0||Cyclin-dependent kinases (CDKs) regulate a variety of fundamental cellular processes. CDK10 stands out as one of the last orphan CDKs for which no activating cyclin has been identified and no kinase activity revealed. Previous work has shown that CDK10 silencing increases ETS2 (v-ets erythroblastosis virus E26 oncogene homolog 2)-driven activation of the MAPK pathway, which confers tamoxifen resistance to breast cancer cells. The precise mechanisms by which CDK10 modulates ETS2 activity, and more generally the functions of CDK10, remain elusive. Here we demonstrate that CDK10 is a cyclin-dependent kinase by identifying cyclin M as an activating cyclin. Cyclin M, an orphan cyclin, is the product of FAM58A, whose mutations cause STAR syndrome, a human developmental anomaly whose features include toe syndactyly, telecanthus, and anogenital and renal malformations. We show that STAR syndrome-associated cyclin M mutants are unable to interact with CDK10. Cyclin M silencing phenocopies CDK10 silencing in increasing c-Raf and in conferring tamoxifen resistance to breast cancer cells. CDK10/cyclin M phosphorylates ETS2 in vitro, and in cells it positively controls ETS2 degradation by the proteasome. ETS2 protein levels are increased in cells derived from a STAR patient, and this increase is attributable to decreased cyclin M levels. Altogether, our results reveal an additional regulatory mechanism for ETS2, which plays key roles in cancer and development. They also shed light on the molecular mechanisms underlying STAR syndrome.Cyclin-dependent kinases (CDKs) play a pivotal role in the control of a number of fundamental cellular processes (1). The human genome contains 21 genes encoding proteins that can be considered as members of the CDK family owing to their sequence similarity with bona fide CDKs, those known to be activated by cyclins (2). Although discovered almost 20 y ago (3, 4), CDK10 remains one of the two CDKs without an identified cyclin partner. This knowledge gap has largely impeded the exploration of its biological functions. CDK10 can act as a positive cell cycle regulator in some cells (5, 6) or as a tumor suppressor in others (7, 8). CDK10 interacts with the ETS2 (v-ets erythroblastosis virus E26 oncogene homolog 2) transcription factor and inhibits its transcriptional activity through an unknown mechanism (9). CDK10 knockdown derepresses ETS2, which increases the expression of the c-Raf protein kinase, activates the MAPK pathway, and induces resistance of MCF7 cells to tamoxifen (6). ...

# %% [markdown]
# <h2>2.2. Mapping the real-world problem to an ML problem</h2>

# %% [markdown]
# <h3>2.2.1. Type of Machine Learning Problem</h3>

# %% [markdown]
# <p>
#
#             There are nine different classes a genetic mutation can be classified into => Multi class classification problem
#
#
#
# </p>

# %% [markdown]
# <h3>2.2.2. Performance Metric</h3>

# %% [markdown]
# Source: https://www.kaggle.com/c/msk-redefining-cancer-treatment#evaluation
#
# Metric(s):
# * Multi class log-loss
# * Confusion matrix

# %% [markdown]
# <h3>2.2.3. Machine Learing Objectives and Constraints</h3>

# %% [markdown]
# <p> Objective: Predict the probability of each data-point belonging to each of the nine classes.
# </p>
# <p> Constraints:
# </p>
# * Interpretability
# * Class probabilities are needed.
# * Penalize the errors in class probabilites => Metric is Log-loss.
# * No Latency constraints.

# %% [markdown]
# <h2>2.3. Train, CV and Test Datasets</h2>

# %% [markdown]
#  Split the dataset randomly into three parts train, cross validation and test with 64%,16%, 20% of data respectively

# %% [markdown]
# <h1>3. Exploratory Data Analysis</h1>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import re
import time
import warnings
import numpy as np
from nltk.corpus import stopwords
from sklearn.decomposition import TruncatedSVD
from sklearn.preprocessing import normalize
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.manifold import TSNE
import seaborn as sns
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix
from sklearn.metrics.classification import accuracy_score, log_loss
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import SGDClassifier
from imblearn.over_sampling import SMOTE
from collections import Counter
from scipy.sparse import hstack
from sklearn.multiclass import OneVsRestClassifier
from sklearn.svm import SVC
#from sklearn.cross_validation import StratifiedKFold 
from collections import Counter, defaultdict
from sklearn.calibration import CalibratedClassifierCV
from sklearn.naive_bayes import MultinomialNB
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
import math
from sklearn.metrics import normalized_mutual_info_score
from sklearn.ensemble import RandomForestClassifier
warnings.filterwarnings("ignore")

from mlxtend.classifier import StackingClassifier

from sklearn import model_selection
from sklearn.linear_model import LogisticRegression
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/externals/six.py:31: DeprecationWarning: The module is deprecated in version 0.21 and will be removed in version 0.23 since we've dropped support for Python 2.7. Please rely on the official version of six (https://pypi.org/project/six/).
#   "(https://pypi.org/project/six/).", DeprecationWarning)

# %%
#https://stackoverflow.com/questions/54613949/how-to-properly-import-data-from-google-drive-to-google-colab-notebook
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# <h2>3.1. Reading Data</h2>

# %% [markdown]
# <h3>3.1.1. Reading Gene and Variation Data</h3>

# %%
data = pd.read_csv('/content/drive/My Drive/AI/train and text/training_variants')
print('Number of data points : ', data.shape[0])
print('Number of features : ', data.shape[1])
print('Features : ', data.columns.values)
data.head()
# Out:
# Number of data points :  3321
# Number of features :  4
# Features :  ['ID' 'Gene' 'Variation' 'Class']
#    ID    Gene             Variation  Class
# 0   0  FAM58A  Truncating Mutations      1
# 1   1     CBL                 W802*      2
# 2   2     CBL                 Q249E      2
# 3   3     CBL                 N454D      3
# 4   4     CBL                 L399V      4

# %% [markdown]
# <p>
#     training/training_variants is a comma separated file containing the description of the genetic mutations used for training. <br>
#     Fields are
#     <ul>
#         <li><b>ID : </b>the id of the row used to link the mutation to the clinical evidence</li>
#         <li><b>Gene : </b>the gene where this genetic mutation is located </li>
#         <li><b>Variation : </b>the aminoacid change for this mutations </li>
#         <li><b>Class :</b> 1-9 the class this genetic mutation has been classified on</li>
#     </ul>

# %% [markdown]
# <h3>3.1.2. Reading Text Data</h3>

# %%
# note the seprator in this file
data_text =pd.read_csv("/content/drive/My Drive/AI/train and text/training_text",sep="\|\|",engine="python",names=["ID","TEXT"],skiprows=1)
print('Number of data points : ', data_text.shape[0])
print('Number of features : ', data_text.shape[1])
print('Features : ', data_text.columns.values)
data_text.head()
# Out:
# Number of data points :  3321
# Number of features :  2
# Features :  ['ID' 'TEXT']
#    ID                                               TEXT
# 0   0  Cyclin-dependent kinases (CDKs) regulate a var...
# 1   1   Abstract Background  Non-small cell lung canc...
# 2   2   Abstract Background  Non-small cell lung canc...
# 3   3  Recent evidence has demonstrated that acquired...
# 4   4  Oncogenic mutations in the monomeric Casitas B...

# %% [markdown]
# <h3>3.1.3. Preprocessing of text</h3>

# %%
# loading stop words from nltk library
import nltk
nltk.download("stopwords")
stop_words = set(stopwords.words('english'))


def nlp_preprocessing(total_text, index, column):
    if type(total_text) is not int:
        string = ""
        # replace every special char with space
        total_text = re.sub('[^a-zA-Z0-9\n]', ' ', total_text)
        # replace multiple spaces with single space
        total_text = re.sub('\s+',' ', total_text)
        # converting all the chars into lower-case.
        total_text = total_text.lower()
        
        for word in total_text.split():
        # if the word is a not a stop word then retain that word from the data
            if not word in stop_words:
                string += word + " "
        
        data_text[column][index] = string
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
#text processing stage.
start_time = time.clock()
for index, row in data_text.iterrows():
    if type(row['TEXT']) is str:
        nlp_preprocessing(row['TEXT'], index, 'TEXT')
    else:
        print("there is no text description for id:",index)
print('Time took for preprocessing the text :',time.clock() - start_time, "seconds")
# Out:
# there is no text description for id: 1109
# there is no text description for id: 1277
# there is no text description for id: 1407
# there is no text description for id: 1639
# there is no text description for id: 2755
# Time took for preprocessing the text : 29.178565 seconds

# %%
#merging both gene_variations and text data based on ID
result = pd.merge(data, data_text,on='ID', how='left')
result.head()
# Out:
#    ID    Gene  ... Class                                               TEXT
# 0   0  FAM58A  ...     1  cyclin dependent kinases cdks regulate variety...
# 1   1     CBL  ...     2  abstract background non small cell lung cancer...
# 2   2     CBL  ...     2  abstract background non small cell lung cancer...
# 3   3     CBL  ...     3  recent evidence demonstrated acquired uniparen...
# 4   4     CBL  ...     4  oncogenic mutations monomeric casitas b lineag...
#
# [5 rows x 5 columns]

# %%
result[result.isnull().any(axis=1)]
# Out:
#         ID    Gene             Variation  Class TEXT
# 1109  1109   FANCA                S1088F      1  NaN
# 1277  1277  ARID5B  Truncating Mutations      1  NaN
# 1407  1407   FGFR3                 K508M      6  NaN
# 1639  1639    FLT1         Amplification      6  NaN
# 2755  2755    BRAF                 G596C      7  NaN

# %%
result.loc[result['TEXT'].isnull(),'TEXT'] = result['Gene'] +' '+result['Variation']

# %%
result[result['ID']==1109]
# Out:
#         ID   Gene Variation  Class          TEXT
# 1109  1109  FANCA    S1088F      1  FANCA S1088F

# %% [markdown]
# <h3>3.1.4. Test, Train and Cross Validation Split</h3>

# %% [markdown]
# <h4>3.1.4.1. Splitting data into train, test and cross validation (64:20:16)</h4>

# %%
y_true = result['Class'].values
result.Gene      = result.Gene.str.replace('\s+', '_')
result.Variation = result.Variation.str.replace('\s+', '_')

# split the data into test and train by maintaining same distribution of output varaible 'y_true' [stratify=y_true]
X_train, test_df, y_train, y_test = train_test_split(result, y_true, stratify=y_true, test_size=0.2)
# split the train data into train and cross validation by maintaining same distribution of output varaible 'y_train' [stratify=y_train]
train_df, cv_df, y_train, y_cv = train_test_split(X_train, y_train, stratify=y_train, test_size=0.2)
X_train.head()
# Out:
#         ID    Gene  ... Class                                               TEXT
# 2042  2042  MAP2K2  ...     7  patients brafv600 metastatic melanoma develop ...
# 1391  1391   FGFR1  ...     7  report patient lymphoblastic leukemia lymphoma...
# 528    528    TP53  ...     4  mutations p53 tumor suppressor frequently obse...
# 3216  3216   NTRK1  ...     4  background aim identification additional thera...
# 1306  1306    MLH1  ...     4  hereditary non polyposis colorectal cancer hnp...
#
# [5 rows x 5 columns]

# %% [markdown]
# <p> We split the data into train, test and cross validation data sets, preserving the ratio of class distribution in the original data set  </p>

# %%
print('Number of data points in train data:', train_df.shape[0])
print('Number of data points in test data:', test_df.shape[0])
print('Number of data points in cross validation data:', cv_df.shape[0])
# Out:
# Number of data points in train data: 2124
# Number of data points in test data: 665
# Number of data points in cross validation data: 532

# %% [markdown]
# <h4>3.1.4.2. Distribution of y_i's in Train, Test and Cross Validation datasets</h4>

# %%
# it returns a dict, keys as class labels and values as the number of data points in that class
train_class_distribution = train_df['Class'].value_counts().sort_index()
test_class_distribution = test_df['Class'].value_counts().sort_index()
cv_class_distribution = cv_df['Class'].value_counts().sort_index()

my_colors = 'rgbkymc'
train_class_distribution.plot(kind='bar')
plt.xlabel('Class')
plt.ylabel('Data points per Class')
plt.title('Distribution of yi in train data')
plt.grid()
plt.show()

# ref: argsort https://docs.scipy.org/doc/numpy/reference/generated/numpy.argsort.html
# -(train_class_distribution.values): the minus sign will give us in decreasing order
sorted_yi = np.argsort(-train_class_distribution.values)
for i in sorted_yi:
    print('Number of data points in class', i+1, ':',train_class_distribution.values[i], '(', np.round((train_class_distribution.values[i]/train_df.shape[0]*100), 3), '%)')

    
print('-'*80)
my_colors = 'rgbkymc'
test_class_distribution.plot(kind='bar')
plt.xlabel('Class')
plt.ylabel('Data points per Class')
plt.title('Distribution of yi in test data')
plt.grid()
plt.show()

# ref: argsort https://docs.scipy.org/doc/numpy/reference/generated/numpy.argsort.html
# -(train_class_distribution.values): the minus sign will give us in decreasing order
sorted_yi = np.argsort(-test_class_distribution.values)
for i in sorted_yi:
    print('Number of data points in class', i+1, ':',test_class_distribution.values[i], '(', np.round((test_class_distribution.values[i]/test_df.shape[0]*100), 3), '%)')

print('-'*80)
my_colors = 'rgbkymc'
cv_class_distribution.plot(kind='bar')
plt.xlabel('Class')
plt.ylabel('Data points per Class')
plt.title('Distribution of yi in cross validation data')
plt.grid()
plt.show()

# ref: argsort https://docs.scipy.org/doc/numpy/reference/generated/numpy.argsort.html
# -(train_class_distribution.values): the minus sign will give us in decreasing order
sorted_yi = np.argsort(-train_class_distribution.values)
for i in sorted_yi:
    print('Number of data points in class', i+1, ':',cv_class_distribution.values[i], '(', np.round((cv_class_distribution.values[i]/cv_df.shape[0]*100), 3), '%)')
# Out:
# Number of data points in class 7 : 609 ( 28.672 %)
# Number of data points in class 4 : 439 ( 20.669 %)
# Number of data points in class 1 : 363 ( 17.09 %)
# Number of data points in class 2 : 289 ( 13.606 %)
# Number of data points in class 6 : 176 ( 8.286 %)
# Number of data points in class 5 : 155 ( 7.298 %)
# Number of data points in class 3 : 57 ( 2.684 %)
# Number of data points in class 9 : 24 ( 1.13 %)
# Number of data points in class 8 : 12 ( 0.565 %)
# --------------------------------------------------------------------------------
# Number of data points in class 7 : 191 ( 28.722 %)
# Number of data points in class 4 : 137 ( 20.602 %)
# Number of data points in class 1 : 114 ( 17.143 %)
# Number of data points in class 2 : 91 ( 13.684 %)
# Number of data points in class 6 : 55 ( 8.271 %)
# Number of data points in class 5 : 48 ( 7.218 %)
# Number of data points in class 3 : 18 ( 2.707 %)
# Number of data points in class 9 : 7 ( 1.053 %)
# Number of data points in class 8 : 4 ( 0.602 %)
# --------------------------------------------------------------------------------
# Number of data points in class 7 : 153 ( 28.759 %)
# Number of data points in class 4 : 110 ( 20.677 %)
# Number of data points in class 1 : 91 ( 17.105 %)
# Number of data points in class 2 : 72 ( 13.534 %)
# Number of data points in class 6 : 44 ( 8.271 %)
# Number of data points in class 5 : 39 ( 7.331 %)
# Number of data points in class 3 : 14 ( 2.632 %)
# Number of data points in class 9 : 6 ( 1.128 %)
# Number of data points in class 8 : 3 ( 0.564 %)

# %% [markdown]
# <h2>3.2 Prediction using a 'Random' Model</h2>

# %% [markdown]
# <p style="font-size:16px"> In a 'Random' Model, we generate the NINE class probabilites randomly such that they sum to 1. </p>

# %%
# This function plots the confusion matrices given y_i, y_i_hat.
def plot_confusion_matrix(test_y, predict_y):
    C = confusion_matrix(test_y, predict_y)
    # C = 9,9 matrix, each cell (i,j) represents number of points of class i are predicted class j
    
    A =(((C.T)/(C.sum(axis=1))).T)
    #divid each element of the confusion matrix with the sum of elements in that column
    
    # C = [[1, 2],
    #     [3, 4]]
    # C.T = [[1, 3],
    #        [2, 4]]
    # C.sum(axis = 1)  axis=0 corresonds to columns and axis=1 corresponds to rows in two diamensional array
    # C.sum(axix =1) = [[3, 7]]
    # ((C.T)/(C.sum(axis=1))) = [[1/3, 3/7]
    #                           [2/3, 4/7]]

    # ((C.T)/(C.sum(axis=1))).T = [[1/3, 2/3]
    #                           [3/7, 4/7]]
    # sum of row elements = 1
    
    B =(C/C.sum(axis=0))
    #divid each element of the confusion matrix with the sum of elements in that row
    # C = [[1, 2],
    #     [3, 4]]
    # C.sum(axis = 0)  axis=0 corresonds to columns and axis=1 corresponds to rows in two diamensional array
    # C.sum(axix =0) = [[4, 6]]
    # (C/C.sum(axis=0)) = [[1/4, 2/6],
    #                      [3/4, 4/6]] 
    
    labels = [1,2,3,4,5,6,7,8,9]
    # representing A in heatmap format
    print("-"*20, "Confusion matrix", "-"*20)
    plt.figure(figsize=(20,7))
    sns.heatmap(C, annot=True, cmap="YlGnBu", fmt=".3f", xticklabels=labels, yticklabels=labels)
    plt.xlabel('Predicted Class')
    plt.ylabel('Original Class')
    plt.show()

    print("-"*20, "Precision matrix (Columm Sum=1)", "-"*20)
    plt.figure(figsize=(20,7))
    sns.heatmap(B, annot=True, cmap="YlGnBu", fmt=".3f", xticklabels=labels, yticklabels=labels)
    plt.xlabel('Predicted Class')
    plt.ylabel('Original Class')
    plt.show()
    
    # representing B in heatmap format
    print("-"*20, "Recall matrix (Row sum=1)", "-"*20)
    plt.figure(figsize=(20,7))
    sns.heatmap(A, annot=True, cmap="YlGnBu", fmt=".3f", xticklabels=labels, yticklabels=labels)
    plt.xlabel('Predicted Class')
    plt.ylabel('Original Class')
    plt.show()

# %%
# we need to generate 9 numbers and the sum of numbers should be 1
# one solution is to genarate 9 numbers and divide each of the numbers by their sum
# ref: https://stackoverflow.com/a/18662466/4084039
test_data_len = test_df.shape[0]
cv_data_len = cv_df.shape[0]

# we create a output array that has exactly same size as the CV data
cv_predicted_y = np.zeros((cv_data_len,9))
for i in range(cv_data_len):
    rand_probs = np.random.rand(1,9)
    cv_predicted_y[i] = ((rand_probs/sum(sum(rand_probs)))[0])

print("Log loss on Cross Validation Data using Random Model",log_loss(y_cv,cv_predicted_y, eps=1e-15))


# Test-Set error.
#we create a output array that has exactly same as the test data
test_predicted_y = np.zeros((test_data_len,9))
for i in range(test_data_len):
    rand_probs = np.random.rand(1,9)
    test_predicted_y[i] = ((rand_probs/sum(sum(rand_probs)))[0])
print("Log loss on Test Data using Random Model",log_loss(y_test,test_predicted_y, eps=1e-15))

predicted_y =np.argmax(test_predicted_y, axis=1)
plot_confusion_matrix(y_test, predicted_y+1)
# Out:
# Log loss on Cross Validation Data using Random Model 2.430350113944392
# Log loss on Test Data using Random Model 2.389386596253489
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# # 1st and 2nd part :TfidfVectorizer on text features whith max_features=1000

# %% [markdown]
# <h2>3.3 Univariate Analysis</h2>

# %%
# code for response coding with Laplace smoothing.
# alpha : used for laplace smoothing
# feature: ['gene', 'variation']
# df: ['train_df', 'test_df', 'cv_df']
# algorithm
# ----------
# Consider all unique values and the number of occurances of given feature in train data dataframe
# build a vector (1*9) , the first element = (number of times it occured in class1 + 10*alpha / number of time it occurred in total data+90*alpha)
# gv_dict is like a look up table, for every gene it store a (1*9) representation of it
# for a value of feature in df:
# if it is in train data:
# we add the vector that was stored in 'gv_dict' look up table to 'gv_fea'
# if it is not there is train:
# we add [1/9, 1/9, 1/9, 1/9,1/9, 1/9, 1/9, 1/9, 1/9] to 'gv_fea'
# return 'gv_fea'
# ----------------------

# get_gv_fea_dict: Get Gene varaition Feature Dict
def get_gv_fea_dict(alpha, feature, df):
    # value_count: it contains a dict like
    # print(train_df['Gene'].value_counts())
    # output:
    #        {BRCA1      174
    #         TP53       106
    #         EGFR        86
    #         BRCA2       75
    #         PTEN        69
    #         KIT         61
    #         BRAF        60
    #         ERBB2       47
    #         PDGFRA      46
    #         ...}
    # print(train_df['Variation'].value_counts())
    # output:
    # {
    # Truncating_Mutations                     63
    # Deletion                                 43
    # Amplification                            43
    # Fusions                                  22
    # Overexpression                            3
    # E17K                                      3
    # Q61L                                      3
    # S222D                                     2
    # P130S                                     2
    # ...
    # }
    value_count = train_df[feature].value_counts()
    
    # gv_dict : Gene Variation Dict, which contains the probability array for each gene/variation
    gv_dict = dict()
    
    # denominator will contain the number of time that particular feature occured in whole data
    for i, denominator in value_count.items():
        # vec will contain (p(yi==1/Gi) probability of gene/variation belongs to perticular class
        # vec is 9 diamensional vector
        vec = []
        for k in range(1,10):
            # print(train_df.loc[(train_df['Class']==1) & (train_df['Gene']=='BRCA1')])
            #         ID   Gene             Variation  Class  
            # 2470  2470  BRCA1                S1715C      1   
            # 2486  2486  BRCA1                S1841R      1   
            # 2614  2614  BRCA1                   M1R      1   
            # 2432  2432  BRCA1                L1657P      1   
            # 2567  2567  BRCA1                T1685A      1   
            # 2583  2583  BRCA1                E1660G      1   
            # 2634  2634  BRCA1                W1718L      1   
            # cls_cnt.shape[0] will return the number of rows

            cls_cnt = train_df.loc[(train_df['Class']==k) & (train_df[feature]==i)]
            
            # cls_cnt.shape[0](numerator) will contain the number of time that particular feature occured in whole data
            vec.append((cls_cnt.shape[0] + alpha*10)/ (denominator + 90*alpha))

        # we are adding the gene/variation to the dict as key and vec as value
        gv_dict[i]=vec
    return gv_dict

# Get Gene variation feature
def get_gv_feature(alpha, feature, df):
    # print(gv_dict)
    #     {'BRCA1': [0.20075757575757575, 0.03787878787878788, 0.068181818181818177, 0.13636363636363635, 0.25, 0.19318181818181818, 0.03787878787878788, 0.03787878787878788, 0.03787878787878788], 
    #      'TP53': [0.32142857142857145, 0.061224489795918366, 0.061224489795918366, 0.27040816326530615, 0.061224489795918366, 0.066326530612244902, 0.051020408163265307, 0.051020408163265307, 0.056122448979591837], 
    #      'EGFR': [0.056818181818181816, 0.21590909090909091, 0.0625, 0.068181818181818177, 0.068181818181818177, 0.0625, 0.34659090909090912, 0.0625, 0.056818181818181816], 
    #      'BRCA2': [0.13333333333333333, 0.060606060606060608, 0.060606060606060608, 0.078787878787878782, 0.1393939393939394, 0.34545454545454546, 0.060606060606060608, 0.060606060606060608, 0.060606060606060608], 
    #      'PTEN': [0.069182389937106917, 0.062893081761006289, 0.069182389937106917, 0.46540880503144655, 0.075471698113207544, 0.062893081761006289, 0.069182389937106917, 0.062893081761006289, 0.062893081761006289], 
    #      'KIT': [0.066225165562913912, 0.25165562913907286, 0.072847682119205295, 0.072847682119205295, 0.066225165562913912, 0.066225165562913912, 0.27152317880794702, 0.066225165562913912, 0.066225165562913912], 
    #      'BRAF': [0.066666666666666666, 0.17999999999999999, 0.073333333333333334, 0.073333333333333334, 0.093333333333333338, 0.080000000000000002, 0.29999999999999999, 0.066666666666666666, 0.066666666666666666],
    #      ...
    #     }
    gv_dict = get_gv_fea_dict(alpha, feature, df)
    # value_count is similar in get_gv_fea_dict
    value_count = train_df[feature].value_counts()
    
    # gv_fea: Gene_variation feature, it will contain the feature for each feature value in the data
    gv_fea = []
    # for every feature values in the given data frame we will check if it is there in the train data then we will add the feature to gv_fea
    # if not we will add [1/9,1/9,1/9,1/9,1/9,1/9,1/9,1/9,1/9] to gv_fea
    for index, row in df.iterrows():
        if row[feature] in dict(value_count).keys():
            gv_fea.append(gv_dict[row[feature]])
        else:
            gv_fea.append([1/9,1/9,1/9,1/9,1/9,1/9,1/9,1/9,1/9])
#             gv_fea.append([-1,-1,-1,-1,-1,-1,-1,-1,-1])
    return gv_fea

# %% [markdown]
# when we caculate the probability of a feature belongs to any particular class, we apply laplace smoothing
# <li>(numerator + 10\*alpha) / (denominator + 90\*alpha) </li>

# %% [markdown]
# <h3>3.2.1 Univariate Analysis on Gene Feature</h3>

# %% [markdown]
# <p style="font-size:18px;"> <b>Q1.</b> Gene, What type of feature it is ?</p>
# <p style="font-size:16px;"><b>Ans.</b> Gene is a categorical variable </p>
# <p style="font-size:18px;"> <b>Q2.</b> How many categories are there and How they are distributed?</p>

# %%
unique_genes = train_df['Gene'].value_counts()
print('Number of Unique Genes :', unique_genes.shape[0])
# the top 10 genes that occured most
print(unique_genes.head(10))
# Out:
# Number of Unique Genes : 224
# BRCA1     180
# TP53      103
# PTEN       83
# EGFR       81
# BRCA2      73
# KIT        67
# BRAF       55
# ALK        47
# ERBB2      44
# PDGFRA     39
# Name: Gene, dtype: int64

# %%
print("Ans: There are", unique_genes.shape[0] ,"different categories of genes in the train data, and they are distibuted as follows",)
# Out:
# Ans: There are 224 different categories of genes in the train data, and they are distibuted as follows

# %%
s = sum(unique_genes.values);
h = unique_genes.values/s;
plt.plot(h, label="Histrogram of Genes")
plt.xlabel('Index of a Gene')
plt.ylabel('Number of Occurances')
plt.legend()
plt.grid()
plt.show()

# %%
c = np.cumsum(h)
plt.plot(c,label='Cumulative distribution of Genes')
plt.grid()
plt.legend()
plt.show()

# %% [markdown]
# <p style="font-size:18px;"> <b>Q3.</b> How to featurize this Gene feature ?</p>
#
# <p style="font-size:16px;"><b>Ans.</b>there are two ways we can featurize this variable
# check out this video: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/handling-categorical-and-numerical-features/
# <ol><li>One hot Encoding</li><li>Response coding</li></ol></p>
# <p> We will choose the appropriate featurization based on the ML model we use.  For this problem of multi-class classification with categorical features, one-hot encoding is better for Logistic regression while response coding is better for Random Forests. </p>

# %%
#response-coding of the Gene feature
# alpha is used for laplace smoothing
alpha = 1
# train gene feature
train_gene_feature_responseCoding = np.array(get_gv_feature(alpha, "Gene", train_df))
# test gene feature
test_gene_feature_responseCoding = np.array(get_gv_feature(alpha, "Gene", test_df))
# cross validation gene feature
cv_gene_feature_responseCoding = np.array(get_gv_feature(alpha, "Gene", cv_df))

# %%
print("train_gene_feature_responseCoding is converted feature using respone coding method. The shape of gene feature:", train_gene_feature_responseCoding.shape)
# Out:
# train_gene_feature_responseCoding is converted feature using respone coding method. The shape of gene feature: (2124, 9)

# %%
# one-hot encoding of Gene feature.
gene_vectorizer = CountVectorizer()
train_gene_feature_onehotCoding = gene_vectorizer.fit_transform(train_df['Gene'])
test_gene_feature_onehotCoding = gene_vectorizer.transform(test_df['Gene'])
cv_gene_feature_onehotCoding = gene_vectorizer.transform(cv_df['Gene'])

# %%
train_df['Gene'].head()
# Out:
# 2802     BRCA2
# 1201    PIK3CA
# 2498     BRCA1
# 226       EGFR
# 715      ERBB2
# Name: Gene, dtype: object

# %%
gene_vectorizer.get_feature_names()
# Out:
# ['abl1',
#  'acvr1',
#  'ago2',
#  'akt1',
#  'akt2',
#  'akt3',
#  'alk',
#  'apc',
#  'ar',
#  'araf',
#  'arid1b',
#  'arid2',
#  'arid5b',
#  'atm',
#  'atrx',
#  'aurka',
#  'aurkb',
#  'axl',
#  'b2m',
#  'bap1',
#  'bard1',
#  'bcl2',
#  'bcl2l11',
#  'bcor',
#  'braf',
#  'brca1',
#  'brca2',
#  'brd4',
#  'brip1',
#  'btk',
#  'card11',
#  'carm1',
#  'casp8',
#  'cbl',
#  'ccnd1',
#  'ccnd3',
#  'ccne1',
#  'cdh1',
#  'cdk12',
#  'cdk4',
#  'cdk6',
#  'cdkn1a',
#  'cdkn1b',
#  'cdkn2a',
#  'cdkn2b',
#  'cdkn2c',
#  'cebpa',
#  'chek2',
#  'cic',
#  'crebbp',
#  'ctcf',
#  'ctla4',
#  'ctnnb1',
#  'ddr2',
#  'dicer1',
#  'dnmt3a',
#  'dnmt3b',
#  'egfr',
#  'elf3',
#  'ep300',
#  'epas1',
#  'erbb2',
#  'erbb3',
#  'erbb4',
#  'ercc2',
#  'ercc3',
#  'ercc4',
#  'erg',
#  'errfi1',
#  'esr1',
#  'etv1',
#  'etv6',
#  'ewsr1',
#  'ezh2',
#  'fanca',
#  'fbxw7',
#  'fgf19',
#  'fgf3',
#  'fgf4',
#  'fgfr1',
#  'fgfr2',
#  'fgfr3',
#  'fgfr4',
#  'flt1',
#  'flt3',
#  'foxa1',
#  'foxl2',
#  'foxp1',
#  'gli1',
#  'gnaq',
#  'gnas',
#  'h3f3a',
#  'hist1h1c',
#  'hla',
#  'hnf1a',
#  'hras',
#  'idh1',
#  'idh2',
#  'igf1r',
#  'ikbke',
#  'ikzf1',
#  'il7r',
#  'jak1',
#  'jak2',
#  'kdm5a',
#  'kdm5c',
#  'kdr',
#  'keap1',
#  'kit',
#  'kmt2a',
#  'kmt2b',
#  'kmt2c',
#  'kmt2d',
#  'knstrn',
#  'kras',
#  'lats1',
#  'lats2',
#  'map2k1',
#  'map2k2',
#  'map2k4',
#  'map3k1',
#  'mapk1',
#  'mdm2',
#  'med12',
#  'men1',
#  'met',
#  'mga',
#  'mlh1',
#  'mpl',
#  'msh2',
#  'msh6',
#  'mtor',
#  'myc',
#  'mycn',
#  'myd88',
#  'myod1',
#  'ncor1',
#  'nf1',
#  'nf2',
#  'nfe2l2',
#  'nfkbia',
#  'nkx2',
#  'notch1',
#  'nras',
#  'ntrk1',
#  'ntrk2',
#  'ntrk3',
#  'nup93',
#  'pak1',
#  'pax8',
#  'pbrm1',
#  'pdgfra',
#  'pdgfrb',
#  'pik3ca',
#  'pik3cb',
#  'pik3cd',
#  'pik3r1',
#  'pik3r2',
#  'pik3r3',
#  'pim1',
#  'pms1',
#  'pms2',
#  'pole',
#  'ppp2r1a',
#  'ppp6c',
#  'prdm1',
#  'ptch1',
#  'pten',
#  'ptpn11',
#  'ptprd',
#  'ptprt',
#  'rab35',
#  'rac1',
#  'rad21',
#  'rad50',
#  'rad51c',
#  'rad54l',
#  'raf1',
#  'rara',
#  'rasa1',
#  'rb1',
#  'rbm10',
#  'ret',
#  'rheb',
#  'rhoa',
#  'rictor',
#  'rnf43',
#  'ros1',
#  'rras2',
#  'runx1',
#  'rxra',
#  'rybp',
#  'sdhb',
#  'sdhc',
#  'setd2',
#  'sf3b1',
#  'shoc2',
#  'smad2',
#  'smad3',
#  'smad4',
#  'smarca4',
#  'smarcb1',
#  'smo',
#  'sos1',
#  'sox9',
#  'spop',
#  'stat3',
#  'stk11',
#  'tcf3',
#  'tert',
#  'tet1',
#  'tet2',
#  'tgfbr1',
#  'tgfbr2',
#  'tmprss2',
#  'tp53',
#  'tsc1',
#  'tsc2',
#  'u2af1',
#  'vhl',
#  'xpo1',
#  'xrcc2',
#  'yap1']

# %%
print("train_gene_feature_onehotCoding is converted feature using one-hot encoding method. The shape of gene feature:", train_gene_feature_onehotCoding.shape)
# Out:
# train_gene_feature_onehotCoding is converted feature using one-hot encoding method. The shape of gene feature: (2124, 223)

# %% [markdown]
# <p style="font-size:18px;"> <b>Q4.</b> How good is this gene feature  in predicting y_i?</p>

# %% [markdown]
# There are many ways to estimate how good a feature is, in predicting y_i. One of the good methods is to build a proper ML model using just this feature. In this case, we will build a logistic regression model using only Gene feature (one hot encoded) to predict y_i.

# %%
alpha = [10 ** x for x in range(-5, 1)] # hyperparam for SGD classifier.

# read more about SGDClassifier() at http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.SGDClassifier.html
# ------------------------------
# default parameters
# SGDClassifier(loss=’hinge’, penalty=’l2’, alpha=0.0001, l1_ratio=0.15, fit_intercept=True, max_iter=None, tol=None, 
# shuffle=True, verbose=0, epsilon=0.1, n_jobs=1, random_state=None, learning_rate=’optimal’, eta0=0.0, power_t=0.5, 
# class_weight=None, warm_start=False, average=False, n_iter=None)

# some of methods
# fit(X, y[, coef_init, intercept_init, …])	Fit linear model with Stochastic Gradient Descent.
# predict(X)	Predict class labels for samples in X.

#-------------------------------
# video link: 
#------------------------------


cv_log_error_array=[]
for i in alpha:
    clf = SGDClassifier(alpha=i, penalty='l2', loss='log', random_state=42)
    clf.fit(train_gene_feature_onehotCoding, y_train)
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_gene_feature_onehotCoding, y_train)
    predict_y = sig_clf.predict_proba(cv_gene_feature_onehotCoding)
    cv_log_error_array.append(log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
    print('For values of alpha = ', i, "The log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))

fig, ax = plt.subplots()
ax.plot(alpha, cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[i],np.round(txt,3)), (alpha[i],cv_log_error_array[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()


best_alpha = np.argmin(cv_log_error_array)
clf = SGDClassifier(alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
clf.fit(train_gene_feature_onehotCoding, y_train)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_gene_feature_onehotCoding, y_train)

predict_y = sig_clf.predict_proba(train_gene_feature_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(cv_gene_feature_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(test_gene_feature_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# For values of alpha =  1e-05 The log loss is: 1.1902796118409305
# For values of alpha =  0.0001 The log loss is: 1.158456320609033
# For values of alpha =  0.001 The log loss is: 1.2008023672063188
# For values of alpha =  0.01 The log loss is: 1.3154798195974013
# For values of alpha =  0.1 The log loss is: 1.4174866144147837
# For values of alpha =  1 The log loss is: 1.4692964241283248
# For values of best alpha =  0.0001 The train log loss is: 1.0096233951468363
# For values of best alpha =  0.0001 The cross validation log loss is: 1.158456320609033
# For values of best alpha =  0.0001 The test log loss is: 1.1834040004407498

# %% [markdown]
# <p style="font-size:18px;"> <b>Q5.</b> Is the Gene feature stable across all the data sets (Test, Train, Cross validation)?</p>
# <p style="font-size:16px;"> <b>Ans.</b> Yes, it is. Otherwise, the CV and Test errors would be significantly more than train error. </p>

# %%
print("Q6. How many data points in Test and CV datasets are covered by the ", unique_genes.shape[0], " genes in train dataset?")

test_coverage=test_df[test_df['Gene'].isin(list(set(train_df['Gene'])))].shape[0]
cv_coverage=cv_df[cv_df['Gene'].isin(list(set(train_df['Gene'])))].shape[0]

print('Ans\n1. In test data',test_coverage, 'out of',test_df.shape[0], ":",(test_coverage/test_df.shape[0])*100)
print('2. In cross validation data',cv_coverage, 'out of ',cv_df.shape[0],":" ,(cv_coverage/cv_df.shape[0])*100)
# Out:
# Q6. How many data points in Test and CV datasets are covered by the  224  genes in train dataset?
# Ans
# 1. In test data 633 out of 665 : 95.18796992481204
# 2. In cross validation data 504 out of  532 : 94.73684210526315

# %% [markdown]
# <h3>3.2.2 Univariate Analysis on Variation Feature</h3>

# %% [markdown]
# <p style="font-size:18px;"> <b>Q7.</b> Variation, What type of feature is it ?</p>
# <p style="font-size:16px;"><b>Ans.</b> Variation is a categorical variable </p>
# <p style="font-size:18px;"> <b>Q8.</b> How many categories are there?</p>

# %%
unique_variations = train_df['Variation'].value_counts()
print('Number of Unique Variations :', unique_variations.shape[0])
# the top 10 variations that occured most
print(unique_variations.head(10))
# Out:
# Number of Unique Variations : 1939
# Truncating_Mutations    54
# Deletion                42
# Amplification           42
# Fusions                 28
# Q61H                     3
# Overexpression           3
# Q61L                     3
# E542K                    2
# M1R                      2
# E17K                     2
# Name: Variation, dtype: int64

# %%
print("Ans: There are", unique_variations.shape[0] ,"different categories of variations in the train data, and they are distibuted as follows",)
# Out:
# Ans: There are 1939 different categories of variations in the train data, and they are distibuted as follows

# %%
s = sum(unique_variations.values);
h = unique_variations.values/s;
plt.plot(h, label="Histrogram of Variations")
plt.xlabel('Index of a Variation')
plt.ylabel('Number of Occurances')
plt.legend()
plt.grid()
plt.show()

# %%
c = np.cumsum(h)
print(c)
plt.plot(c,label='Cumulative distribution of Variations')
plt.grid()
plt.legend()
plt.show()
# Out:
# [0.02542373 0.04519774 0.06497175 ... 0.99905838 0.99952919 1.        ]

# %% [markdown]
# <p style="font-size:18px;"> <b>Q9.</b> How to featurize this Variation feature ?</p>
#
# <p style="font-size:16px;"><b>Ans.</b>There are two ways we can featurize this variable
# check out this video: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/handling-categorical-and-numerical-features/
# <ol><li>One hot Encoding</li><li>Response coding</li></ol></p>
# <p> We will be using both these methods to featurize the Variation Feature </p>

# %%
# alpha is used for laplace smoothing
alpha = 1
# train gene feature
train_variation_feature_responseCoding = np.array(get_gv_feature(alpha, "Variation", train_df))
# test gene feature
test_variation_feature_responseCoding = np.array(get_gv_feature(alpha, "Variation", test_df))
# cross validation gene feature
cv_variation_feature_responseCoding = np.array(get_gv_feature(alpha, "Variation", cv_df))

# %%
print("train_variation_feature_responseCoding is a converted feature using the response coding method. The shape of Variation feature:", train_variation_feature_responseCoding.shape)
# Out:
# train_variation_feature_responseCoding is a converted feature using the response coding method. The shape of Variation feature: (2124, 9)

# %%
# one-hot encoding of variation feature.
variation_vectorizer =  CountVectorizer()
train_variation_feature_onehotCoding = variation_vectorizer.fit_transform(train_df['Variation'])
test_variation_feature_onehotCoding = variation_vectorizer.transform(test_df['Variation'])
cv_variation_feature_onehotCoding = variation_vectorizer.transform(cv_df['Variation'])

# %%
print("train_variation_feature_onehotEncoded is converted feature using the onne-hot encoding method. The shape of Variation feature:", train_variation_feature_onehotCoding.shape)
# Out:
# train_variation_feature_onehotEncoded is converted feature using the onne-hot encoding method. The shape of Variation feature: (2124, 1970)

# %% [markdown]
# <p style="font-size:18px;"> <b>Q10.</b> How good is this Variation feature  in predicting y_i?</p>

# %% [markdown]
# Let's build a model just like the earlier!

# %%
alpha = [10 ** x for x in range(-5, 1)]

# read more about SGDClassifier() at http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.SGDClassifier.html
# ------------------------------
# default parameters
# SGDClassifier(loss=’hinge’, penalty=’l2’, alpha=0.0001, l1_ratio=0.15, fit_intercept=True, max_iter=None, tol=None, 
# shuffle=True, verbose=0, epsilon=0.1, n_jobs=1, random_state=None, learning_rate=’optimal’, eta0=0.0, power_t=0.5, 
# class_weight=None, warm_start=False, average=False, n_iter=None)

# some of methods
# fit(X, y[, coef_init, intercept_init, …])	Fit linear model with Stochastic Gradient Descent.
# predict(X)	Predict class labels for samples in X.

#-------------------------------
# video link: 
#------------------------------


cv_log_error_array=[]
for i in alpha:
    clf = SGDClassifier(alpha=i, penalty='l2', loss='log', random_state=42)
    clf.fit(train_variation_feature_onehotCoding, y_train)
    
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_variation_feature_onehotCoding, y_train)
    predict_y = sig_clf.predict_proba(cv_variation_feature_onehotCoding)
    
    cv_log_error_array.append(log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
    print('For values of alpha = ', i, "The log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))

fig, ax = plt.subplots()
ax.plot(alpha, cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[i],np.round(txt,3)), (alpha[i],cv_log_error_array[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()


best_alpha = np.argmin(cv_log_error_array)
clf = SGDClassifier(alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
clf.fit(train_variation_feature_onehotCoding, y_train)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_variation_feature_onehotCoding, y_train)

predict_y = sig_clf.predict_proba(train_variation_feature_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(cv_variation_feature_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(test_variation_feature_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# For values of alpha =  1e-05 The log loss is: 1.6897242158650112
# For values of alpha =  0.0001 The log loss is: 1.6817133922010006
# For values of alpha =  0.001 The log loss is: 1.6836028713627915
# For values of alpha =  0.01 The log loss is: 1.6921994399184241
# For values of alpha =  0.1 The log loss is: 1.7022692663253776
# For values of alpha =  1 The log loss is: 1.7026819267854556
# For values of best alpha =  0.0001 The train log loss is: 0.742072953007162
# For values of best alpha =  0.0001 The cross validation log loss is: 1.6817133922010006
# For values of best alpha =  0.0001 The test log loss is: 1.7033242228929066

# %% [markdown]
# <p style="font-size:18px;"> <b>Q11.</b> Is the Variation feature stable across all the data sets (Test, Train, Cross validation)?</p>
# <p style="font-size:16px;"> <b>Ans.</b> Not sure! But lets be very sure using the below analysis. </p>

# %%
print("Q12. How many data points are covered by total ", unique_variations.shape[0], " genes in test and cross validation data sets?")
test_coverage=test_df[test_df['Variation'].isin(list(set(train_df['Variation'])))].shape[0]
cv_coverage=cv_df[cv_df['Variation'].isin(list(set(train_df['Variation'])))].shape[0]
print('Ans\n1. In test data',test_coverage, 'out of',test_df.shape[0], ":",(test_coverage/test_df.shape[0])*100)
print('2. In cross validation data',cv_coverage, 'out of ',cv_df.shape[0],":" ,(cv_coverage/cv_df.shape[0])*100)
# Out:
# Q12. How many data points are covered by total  1939  genes in test and cross validation data sets?
# Ans
# 1. In test data 77 out of 665 : 11.578947368421053
# 2. In cross validation data 59 out of  532 : 11.090225563909774

# %% [markdown]
# <h3>3.2.3 Univariate Analysis on Text Feature</h3>

# %% [markdown]
# 1. How many unique words are present in train data?
# 2. How are word frequencies distributed?
# 3. How to featurize text field?
# 4. Is the text feature useful in predicitng y_i?
# 5. Is the text feature stable across train, test and CV datasets?

# %%
# cls_text is a data frame
# for every row in data fram consider the 'TEXT'
# split the words by space
# make a dict with those words
# increment its count whenever we see that word

def extract_dictionary_paddle(cls_text):
    dictionary = defaultdict(int)
    for index, row in cls_text.iterrows():
        for word in row['TEXT'].split():
            dictionary[word] +=1
    return dictionary

# %%
import math
#https://stackoverflow.com/a/1602964
def get_text_responsecoding(df):
    text_feature_responseCoding = np.zeros((df.shape[0],9))
    for i in range(0,9):
        row_index = 0
        for index, row in df.iterrows():
            sum_prob = 0
            for word in row['TEXT'].split():
                sum_prob += math.log(((dict_list[i].get(word,0)+10 )/(total_dict.get(word,0)+90)))
            text_feature_responseCoding[row_index][i] = math.exp(sum_prob/len(row['TEXT'].split()))
            row_index += 1
    return text_feature_responseCoding

# %%
# building a CountVectorizer with all the words that occured minimum 3 times in train data
text_vectorizer = TfidfVectorizer(max_features=1000,min_df=3)
train_text_feature_onehotCoding = text_vectorizer.fit_transform(train_df['TEXT'])
# getting all the feature names (words)
train_text_features= text_vectorizer.get_feature_names()

# train_text_feature_onehotCoding.sum(axis=0).A1 will sum every row and returns (1*number of features) vector
train_text_fea_counts = train_text_feature_onehotCoding.sum(axis=0).A1

# zip(list(text_features),text_fea_counts) will zip a word with its number of times it occured
text_fea_dict = dict(zip(list(train_text_features),train_text_fea_counts))


print("Total number of unique words in train data :", len(train_text_features))
# Out:
# Total number of unique words in train data : 1000

# %%
dict_list = []
# dict_list =[] contains 9 dictoinaries each corresponds to a class
for i in range(1,10):
    cls_text = train_df[train_df['Class']==i]
    # build a word dict based on the words in that class
    dict_list.append(extract_dictionary_paddle(cls_text))
    # append it to dict_list

# dict_list[i] is build on i'th  class text data
# total_dict is buid on whole training text data
total_dict = extract_dictionary_paddle(train_df)


confuse_array = []
for i in train_text_features:
    ratios = []
    max_val = -1
    for j in range(0,9):
        ratios.append((dict_list[j][i]+10 )/(total_dict[i]+90))
    confuse_array.append(ratios)
confuse_array = np.array(confuse_array)

# %%
#response coding of text features
train_text_feature_responseCoding  = get_text_responsecoding(train_df)
test_text_feature_responseCoding  = get_text_responsecoding(test_df)
cv_text_feature_responseCoding  = get_text_responsecoding(cv_df)

# %%
# https://stackoverflow.com/a/16202486
# we convert each row values such that they sum to 1  
train_text_feature_responseCoding = (train_text_feature_responseCoding.T/train_text_feature_responseCoding.sum(axis=1)).T
test_text_feature_responseCoding = (test_text_feature_responseCoding.T/test_text_feature_responseCoding.sum(axis=1)).T
cv_text_feature_responseCoding = (cv_text_feature_responseCoding.T/cv_text_feature_responseCoding.sum(axis=1)).T

# %%
# don't forget to normalize every feature
train_text_feature_onehotCoding = normalize(train_text_feature_onehotCoding, axis=0)

# we use the same vectorizer that was trained on train data
test_text_feature_onehotCoding = text_vectorizer.transform(test_df['TEXT'])
# don't forget to normalize every feature
test_text_feature_onehotCoding = normalize(test_text_feature_onehotCoding, axis=0)

# we use the same vectorizer that was trained on train data
cv_text_feature_onehotCoding = text_vectorizer.transform(cv_df['TEXT'])
# don't forget to normalize every feature
cv_text_feature_onehotCoding = normalize(cv_text_feature_onehotCoding, axis=0)

# %%
#https://stackoverflow.com/a/2258273/4084039
sorted_text_fea_dict = dict(sorted(text_fea_dict.items(), key=lambda x: x[1] , reverse=True))
sorted_text_occur = np.array(list(sorted_text_fea_dict.values()))

# %%
# Number of words for a given frequency.
print(Counter(sorted_text_occur))
# Out:
# Counter({253.0099532485524: 1, 178.24299408590002: 1, 138.23011993821967: 1, 130.94685450612874: 1, 125.07898165818193: 1, 117.13908236866696: 1, 116.93517772331084: 1, 116.705564152593: 1, 111.06503866140338: 1, 110.10620692549065: 1, 109.31773828570897: 1, 90.74666230054089: 1, 89.91767188447211: 1, 83.24695781699259: 1, 82.22582313988416: 1, 81.07979582133328: 1, 79.27136890703322: 1, 78.6967786737594: 1, 77.78232751403645: 1, 77.07401888756607: 1, 76.15466154617037: 1, 71.91995471255218: 1, 71.38326383952028: 1, 70.42235422868576: 1, 68.13150829930154: 1, 67.01004946382533: 1, 65.60611414773763: 1, 64.74024237021493: 1, 64.43149070668828: 1, 64.25227326316944: 1, 64.08180104177262: 1, 63.48447524611506: 1, 63.24025535627732: 1, 59.934844604340554: 1, 59.67012542834538: 1, 56.934417243860715: 1, 56.205292443559536: 1, 56.152528346893035: 1, 54.29094657255908: 1, 51.902968362093965: 1, 51.77762193925797: 1, 49.98321403596873: 1, 49.39690766523408: 1, 49.08199808191968: 1, 48.8027177318399: 1, 47.274123221554945: 1, 47.00832518248315: 1, 45.93596047627771: 1, 45.278677902189706: 1, 44.53167216774366: 1, 44.04261665422641: 1, 43.64862670197358: 1, 43.518866110388956: 1, 43.431083347741065: 1, 43.29423334895397: 1, 43.12204817683299: 1, 42.562143628852105: 1, 42.372917628195744: 1, 42.351300630344284: 1, 42.30175451570826: 1, 42.05984341718864: 1, 41.96142847733196: 1, 41.732355148976474: 1, 41.623928085952606: 1, 40.66119726435665: 1, 40.607688431387686: 1, 40.246849905943: 1, 39.48802105927158: 1, 39.45647306142263: 1, 39.051750515433454: 1, 38.85784239483027: 1, 38.781537664379066: 1, 38.563863353241345: 1, 38.546777609936115: 1, 38.45940213668782: 1, 37.00920285421143: 1, 36.515958438792: 1, 36.36062830669436: 1, 36.02790602795828: 1, 35.91176528989492: 1, 35.85378086630453: 1, 35.60369490789986: 1, 35.438377172440354: 1, 34.994428497772375: 1, 34.53851971858009: 1, 34.16336894925203: 1, 34.10456876155944: 1, 33.986569485070085: 1, 33.93447023990094: 1, 33.68460188798762: 1, 33.61420676571291: 1, 33.42133741890551: 1, 33.36779669739535: 1, 33.155176429476725: 1, 33.13240379783375: 1, 32.751702120504795: 1, 32.68718326115862: 1, 32.654763631834086: 1, 32.44627454407389: 1, 32.43250131022708: 1, 32.01222111334473: 1, 31.97331397055357: 1, 31.902976430121388: 1, 31.83048172044839: 1, 31.78871336193097: 1, 31.72205560164758: 1, 31.678111480529807: 1, 31.4925503709807: 1, 31.428004439837423: 1, 31.388586910513073: 1, 31.36664388543797: 1, 31.184809890106386: 1, 31.12920902517753: 1, 31.111539113351643: 1, 30.961201074386825: 1, 30.943323306205194: 1, 30.823793341236605: 1, 30.585112645766856: 1, 30.577602074239508: 1, 30.344694265918637: 1, 30.271472253950115: 1, 29.827487272043193: 1, 29.7229436530285: 1, 29.54789921047666: 1, 29.527320720936913: 1, 29.50228489343885: 1, 29.243271446977047: 1, 28.87316301640065: 1, 28.82382572839843: 1, 28.767041481188123: 1, 28.503822656318935: 1, 28.4213339331477: 1, 28.22163614865309: 1, 28.15538521808361: 1, 28.117588274341845: 1, 28.041731950852586: 1, 27.61642346599694: 1, 27.602377819560967: 1, 27.465273882909575: 1, 27.082352218588593: 1, 26.873004107476785: 1, 26.794476786182646: 1, 26.714069812552676: 1, 26.69673468527077: 1, 26.58662265782419: 1, 26.423034917009037: 1, 26.364505553361223: 1, 26.23734239069763: 1, 26.033030057673127: 1, 25.867387780671592: 1, 25.845616390587615: 1, 25.8343233241057: 1, 25.72011986943197: 1, 25.587431389858565: 1, 25.538539405860814: 1, 25.259149152505252: 1, 25.200367169759534: 1, 25.08945999214578: 1, 25.085045653487963: 1, 25.064280654389965: 1, 24.9231727419278: 1, 24.889444270511035: 1, 24.750943498704437: 1, 24.746860681013764: 1, 24.473028787467914: 1, 24.38851122711154: 1, 24.371804675587903: 1, 24.368963161917456: 1, 24.281836650288337: 1, 24.236938081910463: 1, 24.208969136808555: 1, 24.099632041460712: 1, 24.02966971411987: 1, 23.817612311334283: 1, 23.797418346119372: 1, 23.786557383340142: 1, 23.76424296301696: 1, 23.672627088951465: 1, 23 ...

# %%
# Train a Logistic regression+Calibration model using text features whicha re on-hot encoded
alpha = [10 ** x for x in range(-5, 1)]

# read more about SGDClassifier() at http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.SGDClassifier.html
# ------------------------------
# default parameters
# SGDClassifier(loss=’hinge’, penalty=’l2’, alpha=0.0001, l1_ratio=0.15, fit_intercept=True, max_iter=None, tol=None, 
# shuffle=True, verbose=0, epsilon=0.1, n_jobs=1, random_state=None, learning_rate=’optimal’, eta0=0.0, power_t=0.5, 
# class_weight=None, warm_start=False, average=False, n_iter=None)

# some of methods
# fit(X, y[, coef_init, intercept_init, …])	Fit linear model with Stochastic Gradient Descent.
# predict(X)	Predict class labels for samples in X.

#-------------------------------
# video link: 
#------------------------------


cv_log_error_array=[]
for i in alpha:
    clf = SGDClassifier(alpha=i, penalty='l2', loss='log', random_state=42)
    clf.fit(train_text_feature_onehotCoding, y_train)
    
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_text_feature_onehotCoding, y_train)
    predict_y = sig_clf.predict_proba(cv_text_feature_onehotCoding)
    cv_log_error_array.append(log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
    print('For values of alpha = ', i, "The log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))

fig, ax = plt.subplots()
ax.plot(alpha, cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[i],np.round(txt,3)), (alpha[i],cv_log_error_array[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()


best_alpha = np.argmin(cv_log_error_array)
clf = SGDClassifier(alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
clf.fit(train_text_feature_onehotCoding, y_train)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_text_feature_onehotCoding, y_train)
best_alpha_ran=alpha[best_alpha]
predict_y = sig_clf.predict_proba(train_text_feature_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
train_loss_ran=log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15)
predict_y = sig_clf.predict_proba(cv_text_feature_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
cv_loss_ran=log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15)
predict_y = sig_clf.predict_proba(test_text_feature_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
test_loss_ran=log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15)
# Out:
# For values of alpha =  1e-05 The log loss is: 1.0969579767411413
# For values of alpha =  0.0001 The log loss is: 1.1279215292810767
# For values of alpha =  0.001 The log loss is: 1.408825725718236
# For values of alpha =  0.01 The log loss is: 1.9313683330885936
# For values of alpha =  0.1 The log loss is: 2.023296383928813
# For values of alpha =  1 The log loss is: 2.0111522392368593
# For values of best alpha =  1e-05 The train log loss is: 0.7186954948033449
# For values of best alpha =  1e-05 The cross validation log loss is: 1.0969579767411413
# For values of best alpha =  1e-05 The test log loss is: 1.078928076408927

# %% [markdown]
# <p style="font-size:18px;"> <b>Q.</b> Is the Text feature stable across all the data sets (Test, Train, Cross validation)?</p>
# <p style="font-size:16px;"> <b>Ans.</b> Yes, it seems like! </p>

# %%
def get_intersec_text(df):
    df_text_vec = TfidfVectorizer(min_df=3)
    df_text_fea = df_text_vec.fit_transform(df['TEXT'])
    df_text_features = df_text_vec.get_feature_names()

    df_text_fea_counts = df_text_fea.sum(axis=0).A1
    df_text_fea_dict = dict(zip(list(df_text_features),df_text_fea_counts))
    len1 = len(set(df_text_features))
    len2 = len(set(train_text_features) & set(df_text_features))
    return len1,len2

# %%
len1,len2 = get_intersec_text(test_df)
print(np.round((len2/len1)*100, 3), "% of word of test data appeared in train data")
len1,len2 = get_intersec_text(cv_df)
print(np.round((len2/len1)*100, 3), "% of word of Cross Validation appeared in train data")
# Out:
# 3.44 % of word of test data appeared in train data
# 3.929 % of word of Cross Validation appeared in train data

# %% [markdown]
# <h1>4. Machine Learning Models</h1>

# %%
#Data preparation for ML models.

#Misc. functionns for ML models

misc_classified=[]
def predict_and_plot_confusion_matrix(train_x, train_y,test_x, test_y, clf):
    clf.fit(train_x, train_y)
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_x, train_y)
    pred_y = sig_clf.predict(test_x)

    # for calculating log_loss we willl provide the array of probabilities belongs to each class
    print("Log loss :",log_loss(test_y, sig_clf.predict_proba(test_x)))
    # calculating the number of data points that are misclassified
    print("Number of mis-classified points :", np.count_nonzero((pred_y- test_y))/test_y.shape[0])
    misc_classified.append((np.count_nonzero((pred_y- test_y))/test_y.shape[0])*100)
    plot_confusion_matrix(test_y, pred_y)

# %%
def report_log_loss(train_x, train_y, test_x, test_y,  clf):
    clf.fit(train_x, train_y)
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_x, train_y)
    sig_clf_probs = sig_clf.predict_proba(test_x)
    return log_loss(test_y, sig_clf_probs, eps=1e-15)

# %%
# this function will be used just for naive bayes
# for the given indices, we will print the name of the features
# and we will check whether the feature present in the test point text or not
def get_impfeature_names(indices, text, gene, var, no_features):
    gene_count_vec = CountVectorizer()
    var_count_vec = CountVectorizer()
    text_count_vec = TfidfVectorizer(max_features=1000,min_df=3)
    
    gene_vec = gene_count_vec.fit(train_df['Gene'])
    var_vec  = var_count_vec.fit(train_df['Variation'])
    text_vec = text_count_vec.fit(train_df['TEXT'])
    
    fea1_len = len(gene_vec.get_feature_names())
    fea2_len = len(var_count_vec.get_feature_names())
    
    word_present = 0
    for i,v in enumerate(indices):
        if (v < fea1_len):
            word = gene_vec.get_feature_names()[v]
            yes_no = True if word == gene else False
            if yes_no:
                word_present += 1
                print(i, "Gene feature [{}] present in test data point [{}]".format(word,yes_no))
        elif (v < fea1_len+fea2_len):
            word = var_vec.get_feature_names()[v-(fea1_len)]
            yes_no = True if word == var else False
            if yes_no:
                word_present += 1
                print(i, "variation feature [{}] present in test data point [{}]".format(word,yes_no))
        else:
            word = text_vec.get_feature_names()[v-(fea1_len+fea2_len)]
            yes_no = True if word in text.split() else False
            if yes_no:
                word_present += 1
                print(i, "Text feature [{}] present in test data point [{}]".format(word,yes_no))

    print("Out of the top ",no_features," features ", word_present, "are present in query point")

# %% [markdown]
# <p style="font-size:24px;text-align:Center"> <b>Stacking the three types of features </b><p>

# %%
# merging gene, variance and text features

# building train, test and cross validation data sets
# a = [[1, 2], 
#      [3, 4]]
# b = [[4, 5], 
#      [6, 7]]
# hstack(a, b) = [[1, 2, 4, 5],
#                [ 3, 4, 6, 7]]

train_gene_var_onehotCoding = hstack((train_gene_feature_onehotCoding,train_variation_feature_onehotCoding))
test_gene_var_onehotCoding = hstack((test_gene_feature_onehotCoding,test_variation_feature_onehotCoding))
cv_gene_var_onehotCoding = hstack((cv_gene_feature_onehotCoding,cv_variation_feature_onehotCoding))

train_x_onehotCoding = hstack((train_gene_var_onehotCoding, train_text_feature_onehotCoding)).tocsr()
train_y = np.array(list(train_df['Class']))

test_x_onehotCoding = hstack((test_gene_var_onehotCoding, test_text_feature_onehotCoding)).tocsr()
test_y = np.array(list(test_df['Class']))

cv_x_onehotCoding = hstack((cv_gene_var_onehotCoding, cv_text_feature_onehotCoding)).tocsr()
cv_y = np.array(list(cv_df['Class']))


train_gene_var_responseCoding = np.hstack((train_gene_feature_responseCoding,train_variation_feature_responseCoding))
test_gene_var_responseCoding = np.hstack((test_gene_feature_responseCoding,test_variation_feature_responseCoding))
cv_gene_var_responseCoding = np.hstack((cv_gene_feature_responseCoding,cv_variation_feature_responseCoding))

train_x_responseCoding = np.hstack((train_gene_var_responseCoding, train_text_feature_responseCoding))
test_x_responseCoding = np.hstack((test_gene_var_responseCoding, test_text_feature_responseCoding))
cv_x_responseCoding = np.hstack((cv_gene_var_responseCoding, cv_text_feature_responseCoding))

# %%
print("One hot encoding features :")
print("(number of data points * number of features) in train data = ", train_x_onehotCoding.shape)
print("(number of data points * number of features) in test data = ", test_x_onehotCoding.shape)
print("(number of data points * number of features) in cross validation data =", cv_x_onehotCoding.shape)
# Out:
# One hot encoding features :
# (number of data points * number of features) in train data =  (2124, 3193)
# (number of data points * number of features) in test data =  (665, 3193)
# (number of data points * number of features) in cross validation data = (532, 3193)

# %%
print(" Response encoding features :")
print("(number of data points * number of features) in train data = ", train_x_responseCoding.shape)
print("(number of data points * number of features) in test data = ", test_x_responseCoding.shape)
print("(number of data points * number of features) in cross validation data =", cv_x_responseCoding.shape)
# Out:
#  Response encoding features :
# (number of data points * number of features) in train data =  (2124, 27)
# (number of data points * number of features) in test data =  (665, 27)
# (number of data points * number of features) in cross validation data = (532, 27)

# %% [markdown]
# <h2>4.1. Base Line Model</h2>

# %% [markdown]
# <h3>4.1.1. Naive Bayes</h3>

# %% [markdown]
# <h4>4.1.1.1. Hyper parameter tuning</h4>

# %%
# find more about Multinomial Naive base function here http://scikit-learn.org/stable/modules/generated/sklearn.naive_bayes.MultinomialNB.html
# -------------------------
# default paramters
# sklearn.naive_bayes.MultinomialNB(alpha=1.0, fit_prior=True, class_prior=None)

# some of methods of MultinomialNB()
# fit(X, y[, sample_weight])	Fit Naive Bayes classifier according to X, y
# predict(X)	Perform classification on an array of test vectors X.
# predict_log_proba(X)	Return log-probability estimates for the test vector X.
# -----------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/naive-bayes-algorithm-1/
# -----------------------


# find more about CalibratedClassifierCV here at http://scikit-learn.org/stable/modules/generated/sklearn.calibration.CalibratedClassifierCV.html
# ----------------------------
# default paramters
# sklearn.calibration.CalibratedClassifierCV(base_estimator=None, method=’sigmoid’, cv=3)
#
# some of the methods of CalibratedClassifierCV()
# fit(X, y[, sample_weight])	Fit the calibrated model
# get_params([deep])	Get parameters for this estimator.
# predict(X)	Predict the target of new samples.
# predict_proba(X)	Posterior probabilities of classification
# ----------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/naive-bayes-algorithm-1/
# -----------------------


alpha = [0.00001, 0.0001, 0.001, 0.1, 1, 10, 100,1000]
cv_log_error_array = []
for i in alpha:
    print("for alpha =", i)
    clf = MultinomialNB(alpha=i)
    clf.fit(train_x_onehotCoding, train_y)
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_x_onehotCoding, train_y)
    sig_clf_probs = sig_clf.predict_proba(cv_x_onehotCoding)
    cv_log_error_array.append(log_loss(cv_y, sig_clf_probs, labels=clf.classes_, eps=1e-15))
    # to avoid rounding error while multiplying probabilites we use log-probability estimates
    print("Log Loss :",log_loss(cv_y, sig_clf_probs)) 

fig, ax = plt.subplots()
ax.plot(np.log10(alpha), cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[i],str(txt)), (np.log10(alpha[i]),cv_log_error_array[i]))
plt.grid()
plt.xticks(np.log10(alpha))
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()


best_alpha = np.argmin(cv_log_error_array)
clf = MultinomialNB(alpha=alpha[best_alpha])
clf.fit(train_x_onehotCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_onehotCoding, train_y)
best_alpha_nb=alpha[best_alpha]

predict_y = sig_clf.predict_proba(train_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
train_loss_nb=log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15)
predict_y = sig_clf.predict_proba(cv_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
cv_loss_nb=log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15)
predict_y = sig_clf.predict_proba(test_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
test_loss_nb=log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15)
# Out:
# for alpha = 1e-05
# Log Loss : 1.1497361226746428
# for alpha = 0.0001
# Log Loss : 1.149420974019943
# for alpha = 0.001
# Log Loss : 1.1486456468448543
# for alpha = 0.1
# Log Loss : 1.1860889210764074
# for alpha = 1
# Log Loss : 1.2715994678959224
# for alpha = 10
# Log Loss : 1.4485720141588119
# for alpha = 100
# Log Loss : 1.4061653979416893
# for alpha = 1000
# Log Loss : 1.3994415676194096
# For values of best alpha =  0.001 The train log loss is: 0.5243035652808403
# For values of best alpha =  0.001 The cross validation log loss is: 1.1486456468448543
# For values of best alpha =  0.001 The test log loss is: 1.2015032671401378

# %% [markdown]
# <h4>4.1.1.2. Testing the model with best hyper paramters</h4>

# %%
# find more about Multinomial Naive base function here http://scikit-learn.org/stable/modules/generated/sklearn.naive_bayes.MultinomialNB.html
# -------------------------
# default paramters
# sklearn.naive_bayes.MultinomialNB(alpha=1.0, fit_prior=True, class_prior=None)

# some of methods of MultinomialNB()
# fit(X, y[, sample_weight])	Fit Naive Bayes classifier according to X, y
# predict(X)	Perform classification on an array of test vectors X.
# predict_log_proba(X)	Return log-probability estimates for the test vector X.
# -----------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/naive-bayes-algorithm-1/
# -----------------------


# find more about CalibratedClassifierCV here at http://scikit-learn.org/stable/modules/generated/sklearn.calibration.CalibratedClassifierCV.html
# ----------------------------
# default paramters
# sklearn.calibration.CalibratedClassifierCV(base_estimator=None, method=’sigmoid’, cv=3)
#
# some of the methods of CalibratedClassifierCV()
# fit(X, y[, sample_weight])	Fit the calibrated model
# get_params([deep])	Get parameters for this estimator.
# predict(X)	Predict the target of new samples.
# predict_proba(X)	Posterior probabilities of classification
# ----------------------------

clf = MultinomialNB(alpha=alpha[best_alpha])
clf.fit(train_x_onehotCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_onehotCoding, train_y)
sig_clf_probs = sig_clf.predict_proba(cv_x_onehotCoding)
# to avoid rounding error while multiplying probabilites we use log-probability estimates
print("Log Loss :",log_loss(cv_y, sig_clf_probs))
print("Number of missclassified point :", np.count_nonzero((sig_clf.predict(cv_x_onehotCoding)- cv_y))/cv_y.shape[0])
misc_classified_nb= (np.count_nonzero((sig_clf.predict(cv_x_onehotCoding)- cv_y))/cv_y.shape[0])*100
plot_confusion_matrix(cv_y, sig_clf.predict(cv_x_onehotCoding.toarray()))
# Out:
# Log Loss : 1.1486456468448543
# Number of missclassified point : 0.37218045112781956
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# <h4>4.1.1.3. Feature Importance, Correctly classified point</h4>

# %%
test_point_index = 1
no_feature = 100
predicted_cls = sig_clf.predict(test_x_onehotCoding[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.coef_)[predicted_cls-1][:,:no_feature]
print("-"*50)
get_impfeature_names(indices[0], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 7
# Predicted Class Probabilities: [[0.07   0.1103 0.012  0.07   0.0351 0.0782 0.6178 0.003  0.0036]]
# Actual Class : 2
# --------------------------------------------------
# 15 Text feature [activation] present in test data point [True]
# 17 Text feature [activated] present in test data point [True]
# 18 Text feature [kinase] present in test data point [True]
# 19 Text feature [cells] present in test data point [True]
# 20 Text feature [expressing] present in test data point [True]
# 25 Text feature [inhibitor] present in test data point [True]
# 26 Text feature [factor] present in test data point [True]
# 27 Text feature [signaling] present in test data point [True]
# 28 Text feature [also] present in test data point [True]
# 29 Text feature [growth] present in test data point [True]
# 30 Text feature [independent] present in test data point [True]
# 31 Text feature [cell] present in test data point [True]
# 32 Text feature [contrast] present in test data point [True]
# 36 Text feature [10] present in test data point [True]
# 37 Text feature [sensitive] present in test data point [True]
# 38 Text feature [however] present in test data point [True]
# 39 Text feature [shown] present in test data point [True]
# 40 Text feature [similar] present in test data point [True]
# 41 Text feature [treatment] present in test data point [True]
# 42 Text feature [constitutive] present in test data point [True]
# 43 Text feature [well] present in test data point [True]
# 44 Text feature [addition] present in test data point [True]
# 45 Text feature [recently] present in test data point [True]
# 46 Text feature [oncogenic] present in test data point [True]
# 48 Text feature [compared] present in test data point [True]
# 49 Text feature [found] present in test data point [True]
# 50 Text feature [mutations] present in test data point [True]
# 51 Text feature [previously] present in test data point [True]
# 52 Text feature [activating] present in test data point [True]
# 53 Text feature [activate] present in test data point [True]
# 54 Text feature [potential] present in test data point [True]
# 55 Text feature [higher] present in test data point [True]
# 56 Text feature [presence] present in test data point [True]
# 57 Text feature [inhibitors] present in test data point [True]
# 58 Text feature [suggest] present in test data point [True]
# 59 Text feature [may] present in test data point [True]
# 60 Text feature [showed] present in test data point [True]
# 61 Text feature [tyrosine] present in test data point [True]
# 63 Text feature [although] present in test data point [True]
# 65 Text feature [without] present in test data point [True]
# 66 Text feature [absence] present in test data point [True]
# 67 Text feature [mechanism] present in test data point [True]
# 68 Text feature [increased] present in test data point [True]
# 69 Text feature [described] present in test data point [True]
# 70 Text feature [total] present in test data point [True]
# 71 Text feature [observed] present in test data point [True]
# 72 Text feature [phosphorylation] present in test data point [True]
# 73 Text feature [receptor] present in test data point [True]
# 74 Text feature [results] present in test data point [True]
# 75 Text feature [inhibition] present in test data point [True]
# 77 Text feature [including] present in test data point [True]
# 78 Text feature [pathways] present in test data point [True]
# 79 Text feature [fig] present in test data point [True]
# 81 Text feature [mutation] present in test data point [True]
# 82 Text feature [different] present in test data point [True]
# 83 Text feature [24] present in test data point [True]
# 84 Text feature [consistent] present in test data point [True]
# 86 Text feature [12] present in test data point [True]
# 87 Text feature [reported] present in test data point [True]
# 88 Text feature [domain] present in test data point [True]
# 89 Text feature [studies] present in test data point [True]
# 90 Text feature [enhanced] present in test data point [True]
# 91 Text feature [various] present in test data point [True]
# 93 Text feature [using] present in test data point [True]
# 94 Text feature [followed] present in test data point [True]
# 96 Text feature [two] present in test data point [True]
# 97 Text feature [examined] present in test data point [True]
# 98 Text feature [therapeutic] present in test data point [True]
# 99 Text feature [discussion] present in test data point [True]
# Out of the top  100  features  69 are present in query point

# %% [markdown]
# <h4>4.1.1.4. Feature Importance, Incorrectly classified point</h4>

# %%
test_point_index = 100
no_feature = 100
predicted_cls = sig_clf.predict(test_x_onehotCoding[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.coef_)[predicted_cls-1][:,:no_feature]
print("-"*50)
get_impfeature_names(indices[0], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 7
# Predicted Class Probabilities: [[0.0621 0.0633 0.0114 0.0623 0.0308 0.029  0.7352 0.0027 0.0032]]
# Actual Class : 7
# --------------------------------------------------
# 15 Text feature [activation] present in test data point [True]
# 17 Text feature [activated] present in test data point [True]
# 18 Text feature [kinase] present in test data point [True]
# 19 Text feature [cells] present in test data point [True]
# 20 Text feature [expressing] present in test data point [True]
# 24 Text feature [downstream] present in test data point [True]
# 25 Text feature [inhibitor] present in test data point [True]
# 26 Text feature [factor] present in test data point [True]
# 27 Text feature [signaling] present in test data point [True]
# 28 Text feature [also] present in test data point [True]
# 29 Text feature [growth] present in test data point [True]
# 30 Text feature [independent] present in test data point [True]
# 31 Text feature [cell] present in test data point [True]
# 32 Text feature [contrast] present in test data point [True]
# 36 Text feature [10] present in test data point [True]
# 37 Text feature [sensitive] present in test data point [True]
# 38 Text feature [however] present in test data point [True]
# 39 Text feature [shown] present in test data point [True]
# 40 Text feature [similar] present in test data point [True]
# 41 Text feature [treatment] present in test data point [True]
# 42 Text feature [constitutive] present in test data point [True]
# 43 Text feature [well] present in test data point [True]
# 44 Text feature [addition] present in test data point [True]
# 45 Text feature [recently] present in test data point [True]
# 46 Text feature [oncogenic] present in test data point [True]
# 47 Text feature [treated] present in test data point [True]
# 48 Text feature [compared] present in test data point [True]
# 49 Text feature [found] present in test data point [True]
# 50 Text feature [mutations] present in test data point [True]
# 51 Text feature [previously] present in test data point [True]
# 52 Text feature [activating] present in test data point [True]
# 53 Text feature [activate] present in test data point [True]
# 54 Text feature [potential] present in test data point [True]
# 55 Text feature [higher] present in test data point [True]
# 56 Text feature [presence] present in test data point [True]
# 57 Text feature [inhibitors] present in test data point [True]
# 58 Text feature [suggest] present in test data point [True]
# 59 Text feature [may] present in test data point [True]
# 60 Text feature [showed] present in test data point [True]
# 61 Text feature [tyrosine] present in test data point [True]
# 62 Text feature [3b] present in test data point [True]
# 63 Text feature [although] present in test data point [True]
# 64 Text feature [proliferation] present in test data point [True]
# 65 Text feature [without] present in test data point [True]
# 66 Text feature [absence] present in test data point [True]
# 67 Text feature [mechanism] present in test data point [True]
# 68 Text feature [increased] present in test data point [True]
# 69 Text feature [described] present in test data point [True]
# 70 Text feature [total] present in test data point [True]
# 71 Text feature [observed] present in test data point [True]
# 72 Text feature [phosphorylation] present in test data point [True]
# 73 Text feature [receptor] present in test data point [True]
# 74 Text feature [results] present in test data point [True]
# 75 Text feature [inhibition] present in test data point [True]
# 76 Text feature [constitutively] present in test data point [True]
# 77 Text feature [including] present in test data point [True]
# 78 Text feature [pathways] present in test data point [True]
# 79 Text feature [fig] present in test data point [True]
# 80 Text feature [pathway] present in test data point [True]
# 81 Text feature [mutation] present in test data point [True]
# 82 Text feature [different] present in test data point [True]
# 83 Text feature [24] present in test data point [True]
# 84 Text feature [consistent] present in test data point [True]
# 85 Text feature [figure] present in test data point [True]
# 86 Text feature [12] present in test data point [True]
# 87 Text feature [reported] present in test data point [True]
# 88 Text feature [domain] present in test data point [True]
# 89 Text feature [studies] present in test data point [True]
# 90 Text feature [enhanced] present in test data point [True]
# 91 Text feature [various] present in test data point [True]
# 92 Text feature [increase] present in test data point [True]
# 93 Text feature [using] present in test data point [True]
# 94 Text feature [followed] present in test data point [True]
# 95 Text feature [interestingly] present in test data point [True]
# 96 Text feature [two] present in test data point [True]
# 97 Text feature [examined] present in test data point [True]
# 98 Text feature [therapeutic] present in test data point [True]
# 99 Text feature [discussion] present in test data point [True]
# Out of the top  100  features  78 are present in query point

# %% [markdown]
# <h2>4.2. K Nearest Neighbour Classification</h2>

# %% [markdown]
# <h3>4.2.1. Hyper parameter tuning</h3>

# %%
# find more about KNeighborsClassifier() here http://scikit-learn.org/stable/modules/generated/sklearn.neighbors.KNeighborsClassifier.html
# -------------------------
# default parameter
# KNeighborsClassifier(n_neighbors=5, weights=’uniform’, algorithm=’auto’, leaf_size=30, p=2, 
# metric=’minkowski’, metric_params=None, n_jobs=1, **kwargs)

# methods of
# fit(X, y) : Fit the model using X as training data and y as target values
# predict(X):Predict the class labels for the provided data
# predict_proba(X):Return probability estimates for the test data X.
#-------------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/k-nearest-neighbors-geometric-intuition-with-a-toy-example-1/
#-------------------------------------


# find more about CalibratedClassifierCV here at http://scikit-learn.org/stable/modules/generated/sklearn.calibration.CalibratedClassifierCV.html
# ----------------------------
# default paramters
# sklearn.calibration.CalibratedClassifierCV(base_estimator=None, method=’sigmoid’, cv=3)
#
# some of the methods of CalibratedClassifierCV()
# fit(X, y[, sample_weight])	Fit the calibrated model
# get_params([deep])	Get parameters for this estimator.
# predict(X)	Predict the target of new samples.
# predict_proba(X)	Posterior probabilities of classification
#-------------------------------------
# video link:
#-------------------------------------


alpha = [5, 11, 15, 21, 31, 41, 51, 99]
cv_log_error_array = []
for i in alpha:
    print("for alpha =", i)
    clf = KNeighborsClassifier(n_neighbors=i)
    clf.fit(train_x_responseCoding, train_y)
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_x_responseCoding, train_y)
    sig_clf_probs = sig_clf.predict_proba(cv_x_responseCoding)
    cv_log_error_array.append(log_loss(cv_y, sig_clf_probs, labels=clf.classes_, eps=1e-15))
    # to avoid rounding error while multiplying probabilites we use log-probability estimates
    print("Log Loss :",log_loss(cv_y, sig_clf_probs)) 

fig, ax = plt.subplots()
ax.plot(alpha, cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[i],str(txt)), (alpha[i],cv_log_error_array[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()


best_alpha = np.argmin(cv_log_error_array)
clf = KNeighborsClassifier(n_neighbors=alpha[best_alpha])
clf.fit(train_x_responseCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_responseCoding, train_y)
best_alpha_knn=alpha[best_alpha]
predict_y = sig_clf.predict_proba(train_x_responseCoding)
print('For values of best alpha = ', alpha[best_alpha], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
train_loss_knn=log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15)
predict_y = sig_clf.predict_proba(cv_x_responseCoding)
print('For values of best alpha = ', alpha[best_alpha], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
cv_loss_knn=log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15)
predict_y = sig_clf.predict_proba(test_x_responseCoding)
print('For values of best alpha = ', alpha[best_alpha], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
test_loss_knn=log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15)
# Out:
# for alpha = 5
# Log Loss : 1.0279903955760674
# for alpha = 11
# Log Loss : 0.991652199939474
# for alpha = 15
# Log Loss : 1.0019110608140664
# for alpha = 21
# Log Loss : 1.0053579028805424
# for alpha = 31
# Log Loss : 1.0110115335256478
# for alpha = 41
# Log Loss : 1.0412355444938222
# for alpha = 51
# Log Loss : 1.061635712328158
# for alpha = 99
# Log Loss : 1.1005812123387781
# For values of best alpha =  11 The train log loss is: 0.6404419932259463
# For values of best alpha =  11 The cross validation log loss is: 0.991652199939474
# For values of best alpha =  11 The test log loss is: 1.0436650360926654

# %% [markdown]
# <h3>4.2.2. Testing the model with best hyper paramters</h3>

# %%
# find more about KNeighborsClassifier() here http://scikit-learn.org/stable/modules/generated/sklearn.neighbors.KNeighborsClassifier.html
# -------------------------
# default parameter
# KNeighborsClassifier(n_neighbors=5, weights=’uniform’, algorithm=’auto’, leaf_size=30, p=2, 
# metric=’minkowski’, metric_params=None, n_jobs=1, **kwargs)

# methods of
# fit(X, y) : Fit the model using X as training data and y as target values
# predict(X):Predict the class labels for the provided data
# predict_proba(X):Return probability estimates for the test data X.
#-------------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/k-nearest-neighbors-geometric-intuition-with-a-toy-example-1/
#-------------------------------------
clf = KNeighborsClassifier(n_neighbors=alpha[best_alpha])
predict_and_plot_confusion_matrix(train_x_responseCoding, train_y, cv_x_responseCoding, cv_y, clf)
# Out:
# Log loss : 0.991652199939474
# Number of mis-classified points : 0.34774436090225563
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# <h3>4.2.3.Sample Query point -1</h3>

# %%
clf = KNeighborsClassifier(n_neighbors=alpha[best_alpha])
clf.fit(train_x_responseCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_responseCoding, train_y)

test_point_index = 1
predicted_cls = sig_clf.predict(test_x_responseCoding[0].reshape(1,-1))
print("Predicted Class :", predicted_cls[0])
print("Actual Class :", test_y[test_point_index])
neighbors = clf.kneighbors(test_x_responseCoding[test_point_index].reshape(1, -1), alpha[best_alpha])
print("The ",alpha[best_alpha]," nearest neighbours of the test points belongs to classes",train_y[neighbors[1][0]])
print("Fequency of nearest points :",Counter(train_y[neighbors[1][0]]))
# Out:
# Predicted Class : 2
# Actual Class : 2
# The  11  nearest neighbours of the test points belongs to classes [2 6 6 6 6 6 6 6 6 6 2]
# Fequency of nearest points : Counter({6: 9, 2: 2})

# %% [markdown]
# <h3>4.2.4. Sample Query Point-2 </h3>

# %%
clf = KNeighborsClassifier(n_neighbors=alpha[best_alpha])
clf.fit(train_x_responseCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_responseCoding, train_y)

test_point_index = 100

predicted_cls = sig_clf.predict(test_x_responseCoding[test_point_index].reshape(1,-1))
print("Predicted Class :", predicted_cls[0])
print("Actual Class :", test_y[test_point_index])
neighbors = clf.kneighbors(test_x_responseCoding[test_point_index].reshape(1, -1), alpha[best_alpha])
print("the k value for knn is",alpha[best_alpha],"and the nearest neighbours of the test points belongs to classes",train_y[neighbors[1][0]])
print("Fequency of nearest points :",Counter(train_y[neighbors[1][0]]))
# Out:
# Predicted Class : 7
# Actual Class : 7
# the k value for knn is 11 and the nearest neighbours of the test points belongs to classes [7 7 7 7 7 3 7 7 7 3 7]
# Fequency of nearest points : Counter({7: 9, 3: 2})

# %% [markdown]
# <h2>4.3. Logistic Regression</h2>

# %% [markdown]
# <h3>4.3.1. With Class balancing</h3>

# %% [markdown]
# <h4>4.3.1.1. Hyper paramter tuning</h4>

# %%
# read more about SGDClassifier() at http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.SGDClassifier.html
# ------------------------------
# default parameters
# SGDClassifier(loss=’hinge’, penalty=’l2’, alpha=0.0001, l1_ratio=0.15, fit_intercept=True, max_iter=None, tol=None, 
# shuffle=True, verbose=0, epsilon=0.1, n_jobs=1, random_state=None, learning_rate=’optimal’, eta0=0.0, power_t=0.5, 
# class_weight=None, warm_start=False, average=False, n_iter=None)

# some of methods
# fit(X, y[, coef_init, intercept_init, …])	Fit linear model with Stochastic Gradient Descent.
# predict(X)	Predict class labels for samples in X.

#-------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/geometric-intuition-1/
#------------------------------


# find more about CalibratedClassifierCV here at http://scikit-learn.org/stable/modules/generated/sklearn.calibration.CalibratedClassifierCV.html
# ----------------------------
# default paramters
# sklearn.calibration.CalibratedClassifierCV(base_estimator=None, method=’sigmoid’, cv=3)
#
# some of the methods of CalibratedClassifierCV()
# fit(X, y[, sample_weight])	Fit the calibrated model
# get_params([deep])	Get parameters for this estimator.
# predict(X)	Predict the target of new samples.
# predict_proba(X)	Posterior probabilities of classification
#-------------------------------------
# video link:
#-------------------------------------

alpha = [10 ** x for x in range(-6, 3)]
cv_log_error_array = []
for i in alpha:
    print("for alpha =", i)
    clf = SGDClassifier(class_weight='balanced', alpha=i, penalty='l2', loss='log', random_state=42)
    clf.fit(train_x_onehotCoding, train_y)
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_x_onehotCoding, train_y)
    sig_clf_probs = sig_clf.predict_proba(cv_x_onehotCoding)
    cv_log_error_array.append(log_loss(cv_y, sig_clf_probs, labels=clf.classes_, eps=1e-15))
    # to avoid rounding error while multiplying probabilites we use log-probability estimates
    print("Log Loss :",log_loss(cv_y, sig_clf_probs)) 

fig, ax = plt.subplots()
ax.plot(alpha, cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[i],str(txt)), (alpha[i],cv_log_error_array[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()


best_alpha = np.argmin(cv_log_error_array)
clf = SGDClassifier(class_weight='balanced', alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
clf.fit(train_x_onehotCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_onehotCoding, train_y)
best_alpha_lr=alpha[best_alpha]
predict_y = sig_clf.predict_proba(train_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
train_loss_lr=log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15)
predict_y = sig_clf.predict_proba(cv_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
cv_loss_lr=log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15)
predict_y = sig_clf.predict_proba(test_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
test_loss_lr=log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15)
# Out:
# for alpha = 1e-06
# Log Loss : 1.1029601677090393
# for alpha = 1e-05
# Log Loss : 1.0272891513470002
# for alpha = 0.0001
# Log Loss : 0.9742227936011115
# for alpha = 0.001
# Log Loss : 1.002688152997765
# for alpha = 0.01
# Log Loss : 1.1360261077042146
# for alpha = 0.1
# Log Loss : 1.6325906644948334
# for alpha = 1
# Log Loss : 1.7887086766800024
# for alpha = 10
# Log Loss : 1.8065900937126798
# for alpha = 100
# Log Loss : 1.8087217685230468
# For values of best alpha =  0.0001 The train log loss is: 0.44891544288419505
# For values of best alpha =  0.0001 The cross validation log loss is: 0.9742227936011115
# For values of best alpha =  0.0001 The test log loss is: 1.0096068557907842

# %% [markdown]
# <h4>4.3.1.2. Testing the model with best hyper paramters</h4>

# %%
# read more about SGDClassifier() at http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.SGDClassifier.html
# ------------------------------
# default parameters
# SGDClassifier(loss=’hinge’, penalty=’l2’, alpha=0.0001, l1_ratio=0.15, fit_intercept=True, max_iter=None, tol=None, 
# shuffle=True, verbose=0, epsilon=0.1, n_jobs=1, random_state=None, learning_rate=’optimal’, eta0=0.0, power_t=0.5, 
# class_weight=None, warm_start=False, average=False, n_iter=None)

# some of methods
# fit(X, y[, coef_init, intercept_init, …])	Fit linear model with Stochastic Gradient Descent.
# predict(X)	Predict class labels for samples in X.

#-------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/geometric-intuition-1/
#------------------------------
clf = SGDClassifier(class_weight='balanced', alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
predict_and_plot_confusion_matrix(train_x_onehotCoding, train_y, cv_x_onehotCoding, cv_y, clf)
# Out:
# Log loss : 0.9742227936011115
# Number of mis-classified points : 0.33646616541353386
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# <h4>4.3.1.3. Feature Importance</h4>

# %%
def get_imp_feature_names(text, indices, removed_ind = []):
    word_present = 0
    tabulte_list = []
    incresingorder_ind = 0
    for i in indices:
        if i < train_gene_feature_onehotCoding.shape[1]:
            tabulte_list.append([incresingorder_ind, "Gene", "Yes"])
        elif i< 18:
            tabulte_list.append([incresingorder_ind,"Variation", "Yes"])
        if ((i > 17) & (i not in removed_ind)) :
            word = train_text_features[i]
            yes_no = True if word in text.split() else False
            if yes_no:
                word_present += 1
            tabulte_list.append([incresingorder_ind,train_text_features[i], yes_no])
        incresingorder_ind += 1
    print(word_present, "most importent features are present in our query point")
    print("-"*50)
    print("The features that are most importent of the ",predicted_cls[0]," class:")
    print (tabulate(tabulte_list, headers=["Index",'Feature name', 'Present or Not']))

# %% [markdown]
# <h5>4.3.1.3.1. Correctly Classified point</h5>

# %%
# from tabulate import tabulate
clf = SGDClassifier(class_weight='balanced', alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
clf.fit(train_x_onehotCoding,train_y)
test_point_index = 1
no_feature = 500
predicted_cls = sig_clf.predict(test_x_onehotCoding[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.coef_)[predicted_cls-1][:,:no_feature]
print("-"*50)
get_impfeature_names(indices[0], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 6
# Predicted Class Probabilities: [[0.0147 0.1771 0.0046 0.0145 0.0202 0.5148 0.2501 0.0017 0.0022]]
# Actual Class : 2
# --------------------------------------------------
# 58 Text feature [blue] present in test data point [True]
# 70 Text feature [values] present in test data point [True]
# 94 Text feature [right] present in test data point [True]
# 98 Text feature [substitution] present in test data point [True]
# 100 Text feature [lapatinib] present in test data point [True]
# 101 Text feature [binds] present in test data point [True]
# 109 Text feature [substitutions] present in test data point [True]
# 115 Text feature [considered] present in test data point [True]
# 116 Text feature [resistance] present in test data point [True]
# 120 Text feature [concentration] present in test data point [True]
# 123 Text feature [substrate] present in test data point [True]
# 126 Text feature [showing] present in test data point [True]
# 130 Text feature [42] present in test data point [True]
# 135 Text feature [inhibitors] present in test data point [True]
# 137 Text feature [basis] present in test data point [True]
# 138 Text feature [site] present in test data point [True]
# 141 Text feature [nucleotide] present in test data point [True]
# 142 Text feature [interactions] present in test data point [True]
# 143 Text feature [conformation] present in test data point [True]
# 144 Text feature [direct] present in test data point [True]
# 145 Text feature [induce] present in test data point [True]
# 146 Text feature [models] present in test data point [True]
# 151 Text feature [inhibition] present in test data point [True]
# 156 Text feature [dose] present in test data point [True]
# 157 Text feature [metastatic] present in test data point [True]
# 164 Text feature [significant] present in test data point [True]
# 173 Text feature [atp] present in test data point [True]
# 174 Text feature [powerpoint] present in test data point [True]
# 180 Text feature [state] present in test data point [True]
# 186 Text feature [factor] present in test data point [True]
# 190 Text feature [expected] present in test data point [True]
# 195 Text feature [cause] present in test data point [True]
# 199 Text feature [47] present in test data point [True]
# 202 Text feature [predicted] present in test data point [True]
# 204 Text feature [evidence] present in test data point [True]
# 209 Text feature [affect] present in test data point [True]
# 213 Text feature [ic50] present in test data point [True]
# 215 Text feature [single] present in test data point [True]
# 218 Text feature [structural] present in test data point [True]
# 220 Text feature [confer] present in test data point [True]
# 226 Text feature [status] present in test data point [True]
# 227 Text feature [play] present in test data point [True]
# 229 Text feature [000] present in test data point [True]
# 233 Text feature [inactive] present in test data point [True]
# 235 Text feature [determined] present in test data point [True]
# 237 Text feature [mechanism] present in test data point [True]
# 238 Text feature [erk] present in test data point [True]
# 239 Text feature [45] present in test data point [True]
# 245 Text feature [helix] present in test data point [True]
# 246 Text feature [free] present in test data point [True]
# 248 Text feature [active] present in test data point [True]
# 249 Text feature [drug] present in test data point [True]
# 251 Text feature [43] present in test data point [True]
# 254 Text feature [200] present in test data point [True]
# 255 Text feature [erbb2] present in test data point [True]
# 257 Text feature [frequently] present in test data point [True]
# 259 Text feature [decreased] present in test data point [True]
# 260 Text feature [selection] present in test data point [True]
# 261 Text feature [therapy] present in test data point [True]
# 262 Text feature [download] present in test data point [True]
# 264 Text feature [approximately] present in test data point [True]
# 265 Text feature [screen] present in test data point [True]
# 266 Text feature [ability] present in test data point [True]
# 268 Text feature [acid] present in test data point [True]
# 269 Text feature [inhibit] present in test data point [True]
# 274 Text feature [loss] present in test data point [True]
# 277 Text feature [express] present in test data point [True]
# 278 Text feature [frequent] present in test data point [True]
# 281 Text feature [receptor] present in test data point [True]
# 283 Text feature [important] present in test data point [True]
# 288 Text feature [38] present in test data point [True]
# 290 Text feature [hydrophobic] present in test data point [True]
# 291 Text feature [use] present in test data point [True]
# 301 Text feature [95] present in test data point [True]
# 302 Text feature [identified] present in test data point [True]
# 304 Text feature [potent] present in test data point [True]
# 307 Text feature [six] present in test data point [True]
# 308 Text feature [ovarian] present in test data point [True]
# 309 Text feature [bind] present in test data point [True]
# 313 Text feature [51] present in test data point [True]
# 319 Text feature [44] present in test data point [True]
# 322 Text feature [therapeutic] present in test data point [True]
# 324 Text feature [dependent] present in test data point [True]
# 327 Text feature [binding] present in test data point [True]
# 329 Text feature [thus] present in test data point [True]
# 330 Text feature [showed] present in test data point [True]
# 332 Text feature [targeted] present in test data point [True]
# 335 Text feature [20] present in test data point [True]
# 339 Text feature [domains] present in test data point [True]
# 340 Text feature [frequency] present in test data point [True]
# 344 Text feature [type] present in test data point [True]
# 346 Text feature [four] present in test data point [True]
# 347 Text feature [five] present in test data point [True]
# 354 Text feature [combination] present in test data point [True]
# 358 Text feature [higher] present in test data point [True]
# 359 Text feature [approach] present in test data point [True]
# 362 Text feature [time] present in test data point [True]
# 365 Text feature [52] present in test data point [True]
# 367 Text feature [changes] present in test data point [True]
# 368 Text feature [development] present in test data point [True]
# 371 Text feature [27] present in test data point [True]
# 372 Text feature [including] present in test data point [True]
# 373 Text feature [reaction] present in test data point [True]
# 374 Text feature [30] present in test data point [True]
# 375 Text feature [selective] present in test data point [True]
# 376 Text feature [40] present in test data point [True]
# 378 Text feature [residues] present in test data point [True]
# 379 Text feature [response] present in test data point [True]
# 381 Text feature [yet] present in test data point [True]
# 382 Text feature [red] present in test data point [True]
# 383 Text feature [residue] present in test data point [True]
# 384 Text feature [indicates] present in test data point [True]
# 385 Text feature [overall] present in test data point [True]
# 387 Text feature [double] present in test data point [True]
# 388 Text feature [regions] present in test data point [True]
# 390 Text feature [potential] present in test data point [True]
# 391 Text feature [required] present in test data point [True]
# 392 Text feature [differences] present in test data point [True]
# 393 Text feature [particular] present in test data point [True]
# 395 Text feature [23] present in test data point [True]
# 396 Text feature [model] present in test data point [True]
# 398 Text feature [35] present in test data point [True]
# 399 Text feature [selected] present in test data point [True]
# 401 Text feature [wild] present in test data point [True]
# 405 Text feature [reported] present in test data point [True]
# 406 Text feature [stability] present in test data point [True]
# 408 Text feature [31] present in test data point [True]
# 409 Text feature [least] present in test data point [True]
# 411 Text feature [loop] present in test data point [True]
# 412 Text feature [gel] present in test data point [True]
# 413 Text feature [value] present in test data point [True]
# 415 Text feature [associated] present in test data point [True]
# 416 Text feature [2006] present in test data point [True]
# 417 Text feature [due] present in test data point [True]
# 421 Text feature [group] present in test data point [True]
# 423 Text feature [26] present in test data point [True]
# 424 Text feature [manufacturer] present in test data point [True]
# 426 Text feature [according] present in test data point [True]
# 429 Text feature [clinically] present in test data point [True]
# 431 Text feature [observation] present in test data point [True]
# 432 Text feature [sequence] present in test data point [True]
# 433 Text feature [methods] present in test data point [True]
# 435 Text feature [variant] present in test data point [True]
# 437 Text feature [15] present in test data point [True]
# 438 Text feature [association] present in test data point [True]
# 439 Text feature [respectively] present in test data point [True]
# 443 Text feature [formation] present in test data point [True]
# 445 Text feature [dna] present in test data point [True]
# 447 Text feature [34] present in test data point [True]
# 448 Text feature [41] present in test data point [True]
# 451 Text feature [region] present in test data point [True]
# 452 Text feature [lung] present in test data point [True]
# 453 Text feature [pathways] present in test data point [True]
# 456 Text feature [met] present in test data point [True]
# 457 Text feature [structure] present in test data point [True]
# 460 Text feature [mechanisms] present in test data point [True]
# 462 Text feature [multiple] present in test data point [True]
# 466 Text feature [volume] present in test data point [True]
# 468 Text feature [kinase] present in test data point [True]
# 470 Text feature [positions] present in test data point [True]
# 471 Text feature [subjected] present in test data point [True]
# 474 Text feature [90] present in test data point [True]
# 475 Text feature [amino] present in test data point [True]
# 476 Text feature [amplification] present in test data point [True]
# 477 Text feature [spectrum] present in test data point [True]
# 478 Text feature [materials] present in test data point [True]
# 479 Text feature [32] present in test data point [True]
# 480 Text feature [versus] present in test data point [True]
# 481 Text feature [ligand] present in test data point [True]
# 482 Text feature [specific] present in test data point [True]
# 483 Text feature [identification] present in test data point [True]
# 484 Text feature [mammalian] present in test data point [True]
# 486 Text feature [il] present in test data point [True]
# 487 Text feature [17] present in test data point [True]
# 488 Text feature [11] present in test data point [True]
# 491 Text feature [without] present in test data point [True]
# 496 Text feature [46] present in test data point [True]
# Out of the top  500  features  177 are present in query point

# %% [markdown]
# <h5>4.3.1.3.2. Incorrectly Classified point</h5>

# %%
test_point_index = 100
no_feature = 500
predicted_cls = sig_clf.predict(test_x_onehotCoding[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.coef_)[predicted_cls-1][:,:no_feature]
print("-"*50)
get_impfeature_names(indices[0], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 7
# Predicted Class Probabilities: [[8.300e-03 6.580e-02 1.620e-02 4.500e-03 1.260e-02 3.600e-03 8.868e-01
#   7.000e-04 1.600e-03]]
# Actual Class : 7
# --------------------------------------------------
# 8 Text feature [activation] present in test data point [True]
# 10 Text feature [activated] present in test data point [True]
# 16 Text feature [downstream] present in test data point [True]
# 17 Text feature [activate] present in test data point [True]
# 22 Text feature [constitutive] present in test data point [True]
# 23 Text feature [transformed] present in test data point [True]
# 29 Text feature [oncogenic] present in test data point [True]
# 32 Text feature [ras] present in test data point [True]
# 34 Text feature [codon] present in test data point [True]
# 36 Text feature [oncogene] present in test data point [True]
# 37 Text feature [expressing] present in test data point [True]
# 42 Text feature [overexpression] present in test data point [True]
# 50 Text feature [gists] present in test data point [True]
# 59 Text feature [extracellular] present in test data point [True]
# 68 Text feature [phospho] present in test data point [True]
# 71 Text feature [3b] present in test data point [True]
# 82 Text feature [enhanced] present in test data point [True]
# 89 Text feature [000] present in test data point [True]
# 92 Text feature [sensitive] present in test data point [True]
# 101 Text feature [elevated] present in test data point [True]
# 109 Text feature [fold] present in test data point [True]
# 112 Text feature [colony] present in test data point [True]
# 119 Text feature [ligand] present in test data point [True]
# 126 Text feature [specimens] present in test data point [True]
# 128 Text feature [leukemia] present in test data point [True]
# 129 Text feature [epithelial] present in test data point [True]
# 131 Text feature [factor] present in test data point [True]
# 141 Text feature [days] present in test data point [True]
# 145 Text feature [derived] present in test data point [True]
# 153 Text feature [transformation] present in test data point [True]
# 165 Text feature [signaling] present in test data point [True]
# 168 Text feature [per] present in test data point [True]
# 172 Text feature [pathways] present in test data point [True]
# 177 Text feature [pdgfr] present in test data point [True]
# 182 Text feature [phosphorylated] present in test data point [True]
# 188 Text feature [regulated] present in test data point [True]
# 202 Text feature [positive] present in test data point [True]
# 206 Text feature [wt] present in test data point [True]
# 242 Text feature [constitutively] present in test data point [True]
# 254 Text feature [approximately] present in test data point [True]
# 260 Text feature [receptors] present in test data point [True]
# 262 Text feature [activating] present in test data point [True]
# 275 Text feature [serum] present in test data point [True]
# 278 Text feature [lung] present in test data point [True]
# 281 Text feature [size] present in test data point [True]
# 290 Text feature [basal] present in test data point [True]
# 310 Text feature [conditions] present in test data point [True]
# 311 Text feature [concentrations] present in test data point [True]
# 316 Text feature [examined] present in test data point [True]
# 327 Text feature [malignant] present in test data point [True]
# 337 Text feature [fig] present in test data point [True]
# 344 Text feature [exhibited] present in test data point [True]
# 349 Text feature [total] present in test data point [True]
# 354 Text feature [signals] present in test data point [True]
# 366 Text feature [lead] present in test data point [True]
# 383 Text feature [various] present in test data point [True]
# 385 Text feature [open] present in test data point [True]
# 387 Text feature [position] present in test data point [True]
# 396 Text feature [mutants] present in test data point [True]
# 406 Text feature [75] present in test data point [True]
# 407 Text feature [cdna] present in test data point [True]
# 420 Text feature [tissue] present in test data point [True]
# 422 Text feature [inhibitor] present in test data point [True]
# 432 Text feature [2a] present in test data point [True]
# 439 Text feature [reverse] present in test data point [True]
# 440 Text feature [without] present in test data point [True]
# 444 Text feature [occur] present in test data point [True]
# 446 Text feature [volume] present in test data point [True]
# 448 Text feature [tyrosine] present in test data point [True]
# 450 Text feature [regions] present in test data point [True]
# 453 Text feature [akt] present in test data point [True]
# 470 Text feature [form] present in test data point [True]
# 489 Text feature [inhibited] present in test data point [True]
# 492 Text feature [additional] present in test data point [True]
# Out of the top  500  features  74 are present in query point

# %% [markdown]
# <h3>4.3.2. Without Class balancing</h3>

# %% [markdown]
# <h4>4.3.2.1. Hyper paramter tuning</h4>

# %%
# read more about SGDClassifier() at http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.SGDClassifier.html
# ------------------------------
# default parameters
# SGDClassifier(loss=’hinge’, penalty=’l2’, alpha=0.0001, l1_ratio=0.15, fit_intercept=True, max_iter=None, tol=None, 
# shuffle=True, verbose=0, epsilon=0.1, n_jobs=1, random_state=None, learning_rate=’optimal’, eta0=0.0, power_t=0.5, 
# class_weight=None, warm_start=False, average=False, n_iter=None)

# some of methods
# fit(X, y[, coef_init, intercept_init, …])	Fit linear model with Stochastic Gradient Descent.
# predict(X)	Predict class labels for samples in X.

#-------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/geometric-intuition-1/
#------------------------------



# find more about CalibratedClassifierCV here at http://scikit-learn.org/stable/modules/generated/sklearn.calibration.CalibratedClassifierCV.html
# ----------------------------
# default paramters
# sklearn.calibration.CalibratedClassifierCV(base_estimator=None, method=’sigmoid’, cv=3)
#
# some of the methods of CalibratedClassifierCV()
# fit(X, y[, sample_weight])	Fit the calibrated model
# get_params([deep])	Get parameters for this estimator.
# predict(X)	Predict the target of new samples.
# predict_proba(X)	Posterior probabilities of classification
#-------------------------------------
# video link:
#-------------------------------------

alpha = [10 ** x for x in range(-6, 1)]
cv_log_error_array = []
for i in alpha:
    print("for alpha =", i)
    clf = SGDClassifier(alpha=i, penalty='l2', loss='log', random_state=42)
    clf.fit(train_x_onehotCoding, train_y)
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_x_onehotCoding, train_y)
    sig_clf_probs = sig_clf.predict_proba(cv_x_onehotCoding)
    cv_log_error_array.append(log_loss(cv_y, sig_clf_probs, labels=clf.classes_, eps=1e-15))
    print("Log Loss :",log_loss(cv_y, sig_clf_probs)) 

fig, ax = plt.subplots()
ax.plot(alpha, cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[i],str(txt)), (alpha[i],cv_log_error_array[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()


best_alpha = np.argmin(cv_log_error_array)
clf = SGDClassifier(alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
clf.fit(train_x_onehotCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_onehotCoding, train_y)
best_alpha_lrwb=alpha[best_alpha]
predict_y = sig_clf.predict_proba(train_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
train_loss_lrwb=log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15)
predict_y = sig_clf.predict_proba(cv_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
cv_loss_lrwb=log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15)
predict_y = sig_clf.predict_proba(test_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
test_loss_lrwb=log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15)
# Out:
# for alpha = 1e-06
# Log Loss : 1.1197489740190814
# for alpha = 1e-05
# Log Loss : 1.0684494824584014
# for alpha = 0.0001
# Log Loss : 1.0088740455111798
# for alpha = 0.001
# Log Loss : 1.0620291498306065
# for alpha = 0.01
# Log Loss : 1.2496745265433917
# for alpha = 0.1
# Log Loss : 1.6983507398869504
# for alpha = 1
# Log Loss : 1.826208493903066
# For values of best alpha =  0.0001 The train log loss is: 0.44145989793593887
# For values of best alpha =  0.0001 The cross validation log loss is: 1.0088740455111798
# For values of best alpha =  0.0001 The test log loss is: 1.0380644421835399

# %% [markdown]
# <h4>4.3.2.2. Testing model with best hyper parameters</h4>

# %%
# read more about SGDClassifier() at http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.SGDClassifier.html
# ------------------------------
# default parameters
# SGDClassifier(loss=’hinge’, penalty=’l2’, alpha=0.0001, l1_ratio=0.15, fit_intercept=True, max_iter=None, tol=None, 
# shuffle=True, verbose=0, epsilon=0.1, n_jobs=1, random_state=None, learning_rate=’optimal’, eta0=0.0, power_t=0.5, 
# class_weight=None, warm_start=False, average=False, n_iter=None)

# some of methods
# fit(X, y[, coef_init, intercept_init, …])	Fit linear model with Stochastic Gradient Descent.
# predict(X)	Predict class labels for samples in X.

#-------------------------------
# video link: 
#------------------------------

clf = SGDClassifier(alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
predict_and_plot_confusion_matrix(train_x_onehotCoding, train_y, cv_x_onehotCoding, cv_y, clf)
# Out:
# Log loss : 1.0088740455111798
# Number of mis-classified points : 0.33646616541353386
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# <h4>4.3.2.3. Feature Importance, Correctly Classified point</h4>

# %%
clf = SGDClassifier(alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
clf.fit(train_x_onehotCoding,train_y)
test_point_index = 1
no_feature = 500
predicted_cls = sig_clf.predict(test_x_onehotCoding[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.coef_)[predicted_cls-1][:,:no_feature]
print("-"*50)
get_impfeature_names(indices[0], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 6
# Predicted Class Probabilities: [[0.0173 0.1872 0.0044 0.016  0.0219 0.5162 0.2353 0.0006 0.0012]]
# Actual Class : 2
# --------------------------------------------------
# 58 Text feature [blue] present in test data point [True]
# 69 Text feature [values] present in test data point [True]
# 94 Text feature [right] present in test data point [True]
# 95 Text feature [substitution] present in test data point [True]
# 101 Text feature [lapatinib] present in test data point [True]
# 103 Text feature [binds] present in test data point [True]
# 109 Text feature [substitutions] present in test data point [True]
# 116 Text feature [resistance] present in test data point [True]
# 117 Text feature [considered] present in test data point [True]
# 120 Text feature [concentration] present in test data point [True]
# 124 Text feature [substrate] present in test data point [True]
# 127 Text feature [showing] present in test data point [True]
# 131 Text feature [basis] present in test data point [True]
# 133 Text feature [42] present in test data point [True]
# 136 Text feature [inhibitors] present in test data point [True]
# 138 Text feature [site] present in test data point [True]
# 139 Text feature [conformation] present in test data point [True]
# 141 Text feature [nucleotide] present in test data point [True]
# 143 Text feature [interactions] present in test data point [True]
# 144 Text feature [models] present in test data point [True]
# 145 Text feature [direct] present in test data point [True]
# 148 Text feature [induce] present in test data point [True]
# 158 Text feature [dose] present in test data point [True]
# 159 Text feature [inhibition] present in test data point [True]
# 162 Text feature [metastatic] present in test data point [True]
# 165 Text feature [significant] present in test data point [True]
# 171 Text feature [atp] present in test data point [True]
# 180 Text feature [state] present in test data point [True]
# 182 Text feature [expected] present in test data point [True]
# 185 Text feature [powerpoint] present in test data point [True]
# 194 Text feature [factor] present in test data point [True]
# 196 Text feature [predicted] present in test data point [True]
# 199 Text feature [47] present in test data point [True]
# 202 Text feature [cause] present in test data point [True]
# 208 Text feature [evidence] present in test data point [True]
# 210 Text feature [ic50] present in test data point [True]
# 214 Text feature [affect] present in test data point [True]
# 217 Text feature [single] present in test data point [True]
# 222 Text feature [structural] present in test data point [True]
# 223 Text feature [confer] present in test data point [True]
# 228 Text feature [status] present in test data point [True]
# 229 Text feature [000] present in test data point [True]
# 230 Text feature [play] present in test data point [True]
# 235 Text feature [helix] present in test data point [True]
# 237 Text feature [inactive] present in test data point [True]
# 238 Text feature [45] present in test data point [True]
# 240 Text feature [drug] present in test data point [True]
# 241 Text feature [free] present in test data point [True]
# 243 Text feature [43] present in test data point [True]
# 247 Text feature [determined] present in test data point [True]
# 248 Text feature [active] present in test data point [True]
# 252 Text feature [erk] present in test data point [True]
# 258 Text feature [erbb2] present in test data point [True]
# 259 Text feature [mechanism] present in test data point [True]
# 260 Text feature [selection] present in test data point [True]
# 261 Text feature [screen] present in test data point [True]
# 262 Text feature [inhibit] present in test data point [True]
# 263 Text feature [decreased] present in test data point [True]
# 265 Text feature [therapy] present in test data point [True]
# 266 Text feature [frequently] present in test data point [True]
# 267 Text feature [200] present in test data point [True]
# 270 Text feature [loss] present in test data point [True]
# 273 Text feature [download] present in test data point [True]
# 277 Text feature [frequent] present in test data point [True]
# 279 Text feature [ability] present in test data point [True]
# 280 Text feature [hydrophobic] present in test data point [True]
# 281 Text feature [approximately] present in test data point [True]
# 283 Text feature [receptor] present in test data point [True]
# 285 Text feature [acid] present in test data point [True]
# 287 Text feature [38] present in test data point [True]
# 289 Text feature [express] present in test data point [True]
# 290 Text feature [ovarian] present in test data point [True]
# 292 Text feature [use] present in test data point [True]
# 297 Text feature [important] present in test data point [True]
# 307 Text feature [95] present in test data point [True]
# 309 Text feature [six] present in test data point [True]
# 311 Text feature [potent] present in test data point [True]
# 314 Text feature [identified] present in test data point [True]
# 315 Text feature [bind] present in test data point [True]
# 316 Text feature [51] present in test data point [True]
# 318 Text feature [44] present in test data point [True]
# 325 Text feature [therapeutic] present in test data point [True]
# 326 Text feature [thus] present in test data point [True]
# 333 Text feature [binding] present in test data point [True]
# 336 Text feature [20] present in test data point [True]
# 337 Text feature [targeted] present in test data point [True]
# 339 Text feature [52] present in test data point [True]
# 342 Text feature [frequency] present in test data point [True]
# 345 Text feature [changes] present in test data point [True]
# 347 Text feature [four] present in test data point [True]
# 348 Text feature [showed] present in test data point [True]
# 349 Text feature [dependent] present in test data point [True]
# 352 Text feature [domains] present in test data point [True]
# 353 Text feature [combination] present in test data point [True]
# 356 Text feature [selective] present in test data point [True]
# 357 Text feature [approach] present in test data point [True]
# 360 Text feature [five] present in test data point [True]
# 363 Text feature [time] present in test data point [True]
# 367 Text feature [27] present in test data point [True]
# 369 Text feature [development] present in test data point [True]
# 373 Text feature [reaction] present in test data point [True]
# 374 Text feature [30] present in test data point [True]
# 375 Text feature [type] present in test data point [True]
# 376 Text feature [40] present in test data point [True]
# 377 Text feature [residue] present in test data point [True]
# 378 Text feature [higher] present in test data point [True]
# 379 Text feature [residues] present in test data point [True]
# 380 Text feature [including] present in test data point [True]
# 381 Text feature [response] present in test data point [True]
# 382 Text feature [overall] present in test data point [True]
# 383 Text feature [potential] present in test data point [True]
# 384 Text feature [yet] present in test data point [True]
# 385 Text feature [red] present in test data point [True]
# 386 Text feature [indicates] present in test data point [True]
# 389 Text feature [regions] present in test data point [True]
# 390 Text feature [31] present in test data point [True]
# 391 Text feature [differences] present in test data point [True]
# 392 Text feature [double] present in test data point [True]
# 393 Text feature [particular] present in test data point [True]
# 394 Text feature [23] present in test data point [True]
# 395 Text feature [model] present in test data point [True]
# 397 Text feature [required] present in test data point [True]
# 398 Text feature [35] present in test data point [True]
# 400 Text feature [stability] present in test data point [True]
# 401 Text feature [value] present in test data point [True]
# 402 Text feature [selected] present in test data point [True]
# 405 Text feature [reported] present in test data point [True]
# 406 Text feature [loop] present in test data point [True]
# 409 Text feature [least] present in test data point [True]
# 410 Text feature [due] present in test data point [True]
# 412 Text feature [associated] present in test data point [True]
# 413 Text feature [clinically] present in test data point [True]
# 416 Text feature [wild] present in test data point [True]
# 417 Text feature [2006] present in test data point [True]
# 420 Text feature [26] present in test data point [True]
# 423 Text feature [group] present in test data point [True]
# 425 Text feature [gel] present in test data point [True]
# 427 Text feature [association] present in test data point [True]
# 429 Text feature [methods] present in test data point [True]
# 430 Text feature [sequence] present in test data point [True]
# 432 Text feature [variant] present in test data point [True]
# 436 Text feature [41] present in test data point [True]
# 438 Text feature [according] present in test data point [True]
# 439 Text feature [15] present in test data point [True]
# 440 Text feature [observation] present in test data point [True]
# 441 Text feature [34] present in test data point [True]
# 442 Text feature [manufacturer] present in test data point [True]
# 443 Text feature [respectively] present in test data point [True]
# 445 Text feature [formation] present in test data point [True]
# 446 Text feature [lung] present in test data point [True]
# 447 Text feature [dna] present in test data point [True]
# 448 Text feature [structure] present in test data point [True]
# 451 Text feature [region] present in test data point [True]
# 455 Text feature [amplification] present in test data point [True]
# 458 Text feature [volume] present in test data point [True]
# 460 Text feature [met] present in test data point [True]
# 462 Text feature [versus] present in test data point [True]
# 463 Text feature [pathways] present in test data point [True]
# 466 Text feature [mechanisms] present in test data point [True]
# 468 Text feature [positions] present in test data point [True]
# 469 Text feature [kinase] present in test data point [True]
# 470 Text feature [multiple] present in test data point [True]
# 471 Text feature [spectrum] present in test data point [True]
# 472 Text feature [32] present in test data point [True]
# 473 Text feature [90] present in test data point [True]
# 475 Text feature [identification] present in test data point [True]
# 478 Text feature [materials] present in test data point [True]
# 479 Text feature [subjected] present in test data point [True]
# 482 Text feature [amino] present in test data point [True]
# 484 Text feature [17] present in test data point [True]
# 485 Text feature [ligand] present in test data point [True]
# 486 Text feature [resistant] present in test data point [True]
# 488 Text feature [specific] present in test data point [True]
# 490 Text feature [11] present in test data point [True]
# 491 Text feature [il] present in test data point [True]
# 492 Text feature [without] present in test data point [True]
# 495 Text feature [mammalian] present in test data point [True]
# 497 Text feature [46] present in test data point [True]
# 498 Text feature [breast] present in test data point [True]
# Out of the top  500  features  179 are present in query point

# %% [markdown]
# <h4>4.3.2.4. Feature Importance, Inorrectly Classified point</h4>

# %%
test_point_index = 100
no_feature = 500
predicted_cls = sig_clf.predict(test_x_onehotCoding[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.coef_)[predicted_cls-1][:,:no_feature]
print("-"*50)
get_impfeature_names(indices[0], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 7
# Predicted Class Probabilities: [[8.600e-03 6.510e-02 1.790e-02 4.900e-03 9.800e-03 3.700e-03 8.892e-01
#   1.000e-04 6.000e-04]]
# Actual Class : 7
# --------------------------------------------------
# 11 Text feature [activated] present in test data point [True]
# 13 Text feature [activation] present in test data point [True]
# 18 Text feature [downstream] present in test data point [True]
# 20 Text feature [activate] present in test data point [True]
# 32 Text feature [constitutive] present in test data point [True]
# 41 Text feature [codon] present in test data point [True]
# 44 Text feature [ras] present in test data point [True]
# 50 Text feature [transformed] present in test data point [True]
# 52 Text feature [oncogenic] present in test data point [True]
# 59 Text feature [expressing] present in test data point [True]
# 69 Text feature [overexpression] present in test data point [True]
# 74 Text feature [oncogene] present in test data point [True]
# 81 Text feature [gists] present in test data point [True]
# 87 Text feature [extracellular] present in test data point [True]
# 92 Text feature [3b] present in test data point [True]
# 93 Text feature [elevated] present in test data point [True]
# 95 Text feature [phospho] present in test data point [True]
# 99 Text feature [000] present in test data point [True]
# 105 Text feature [sensitive] present in test data point [True]
# 110 Text feature [enhanced] present in test data point [True]
# 135 Text feature [colony] present in test data point [True]
# 136 Text feature [fold] present in test data point [True]
# 162 Text feature [days] present in test data point [True]
# 176 Text feature [derived] present in test data point [True]
# 183 Text feature [regulated] present in test data point [True]
# 184 Text feature [ligand] present in test data point [True]
# 201 Text feature [per] present in test data point [True]
# 202 Text feature [specimens] present in test data point [True]
# 204 Text feature [wt] present in test data point [True]
# 206 Text feature [leukemia] present in test data point [True]
# 207 Text feature [epithelial] present in test data point [True]
# 220 Text feature [phosphorylated] present in test data point [True]
# 226 Text feature [lung] present in test data point [True]
# 232 Text feature [pdgfr] present in test data point [True]
# 243 Text feature [factor] present in test data point [True]
# 253 Text feature [positive] present in test data point [True]
# 271 Text feature [pathways] present in test data point [True]
# 272 Text feature [concentrations] present in test data point [True]
# 274 Text feature [approximately] present in test data point [True]
# 289 Text feature [signaling] present in test data point [True]
# 294 Text feature [transformation] present in test data point [True]
# 296 Text feature [examined] present in test data point [True]
# 316 Text feature [activating] present in test data point [True]
# 320 Text feature [basal] present in test data point [True]
# 324 Text feature [size] present in test data point [True]
# 328 Text feature [various] present in test data point [True]
# 334 Text feature [regions] present in test data point [True]
# 341 Text feature [fig] present in test data point [True]
# 358 Text feature [lead] present in test data point [True]
# 363 Text feature [total] present in test data point [True]
# 367 Text feature [receptors] present in test data point [True]
# 376 Text feature [constitutively] present in test data point [True]
# 383 Text feature [conditions] present in test data point [True]
# 384 Text feature [position] present in test data point [True]
# 386 Text feature [mutants] present in test data point [True]
# 401 Text feature [signals] present in test data point [True]
# 402 Text feature [serum] present in test data point [True]
# 414 Text feature [75] present in test data point [True]
# 440 Text feature [akt] present in test data point [True]
# 442 Text feature [inhibitor] present in test data point [True]
# 443 Text feature [contribute] present in test data point [True]
# 446 Text feature [additional] present in test data point [True]
# 452 Text feature [without] present in test data point [True]
# 455 Text feature [exhibited] present in test data point [True]
# 457 Text feature [form] present in test data point [True]
# 463 Text feature [reverse] present in test data point [True]
# 478 Text feature [tissue] present in test data point [True]
# 482 Text feature [primer] present in test data point [True]
# 485 Text feature [cdna] present in test data point [True]
# 487 Text feature [occur] present in test data point [True]
# 490 Text feature [inhibited] present in test data point [True]
# 491 Text feature [malignant] present in test data point [True]
# 497 Text feature [open] present in test data point [True]
# Out of the top  500  features  73 are present in query point

# %% [markdown]
# <h2>4.4. Linear Support Vector Machines</h2>

# %% [markdown]
# <h3>4.4.1. Hyper paramter tuning</h3>

# %%
# read more about support vector machines with linear kernals here http://scikit-learn.org/stable/modules/generated/sklearn.svm.SVC.html

# --------------------------------
# default parameters 
# SVC(C=1.0, kernel=’rbf’, degree=3, gamma=’auto’, coef0=0.0, shrinking=True, probability=False, tol=0.001, 
# cache_size=200, class_weight=None, verbose=False, max_iter=-1, decision_function_shape=’ovr’, random_state=None)

# Some of methods of SVM()
# fit(X, y, [sample_weight])	Fit the SVM model according to the given training data.
# predict(X)	Perform classification on samples in X.
# --------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/mathematical-derivation-copy-8/
# --------------------------------



# find more about CalibratedClassifierCV here at http://scikit-learn.org/stable/modules/generated/sklearn.calibration.CalibratedClassifierCV.html
# ----------------------------
# default paramters
# sklearn.calibration.CalibratedClassifierCV(base_estimator=None, method=’sigmoid’, cv=3)
#
# some of the methods of CalibratedClassifierCV()
# fit(X, y[, sample_weight])	Fit the calibrated model
# get_params([deep])	Get parameters for this estimator.
# predict(X)	Predict the target of new samples.
# predict_proba(X)	Posterior probabilities of classification
#-------------------------------------
# video link:
#-------------------------------------

alpha = [10 ** x for x in range(-5, 3)]
cv_log_error_array = []
for i in alpha:
    print("for C =", i)
#     clf = SVC(C=i,kernel='linear',probability=True, class_weight='balanced')
    clf = SGDClassifier( class_weight='balanced', alpha=i, penalty='l2', loss='hinge', random_state=42)
    clf.fit(train_x_onehotCoding, train_y)
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_x_onehotCoding, train_y)
    sig_clf_probs = sig_clf.predict_proba(cv_x_onehotCoding)
    cv_log_error_array.append(log_loss(cv_y, sig_clf_probs, labels=clf.classes_, eps=1e-15))
    print("Log Loss :",log_loss(cv_y, sig_clf_probs)) 

fig, ax = plt.subplots()
ax.plot(alpha, cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[i],str(txt)), (alpha[i],cv_log_error_array[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()


best_alpha = np.argmin(cv_log_error_array)
# clf = SVC(C=i,kernel='linear',probability=True, class_weight='balanced')
clf = SGDClassifier(class_weight='balanced', alpha=alpha[best_alpha], penalty='l2', loss='hinge', random_state=42)
clf.fit(train_x_onehotCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_onehotCoding, train_y)
best_alpha_svm=alpha[best_alpha]
predict_y = sig_clf.predict_proba(train_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
train_loss_svm=log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15)
predict_y = sig_clf.predict_proba(cv_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
cv_loss_svm=log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15)
predict_y = sig_clf.predict_proba(test_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
test_loss_svm=log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15)
# Out:
# for C = 1e-05
# Log Loss : 1.0575715326776762
# for C = 0.0001
# Log Loss : 1.0219671861400514
# for C = 0.001
# Log Loss : 1.0238299185450892
# for C = 0.01
# Log Loss : 1.2869100679643668
# for C = 0.1
# Log Loss : 1.6468982784682114
# for C = 1
# Log Loss : 1.8093400109292341
# for C = 10
# Log Loss : 1.809339911483276
# for C = 100
# Log Loss : 1.8093399696455754
# For values of best alpha =  0.0001 The train log loss is: 0.40073081441227104
# For values of best alpha =  0.0001 The cross validation log loss is: 1.0219671861400514
# For values of best alpha =  0.0001 The test log loss is: 1.0568017216889973

# %% [markdown]
# <h3>4.4.2. Testing model with best hyper parameters</h3>

# %%
# read more about support vector machines with linear kernals here http://scikit-learn.org/stable/modules/generated/sklearn.svm.SVC.html

# --------------------------------
# default parameters 
# SVC(C=1.0, kernel=’rbf’, degree=3, gamma=’auto’, coef0=0.0, shrinking=True, probability=False, tol=0.001, 
# cache_size=200, class_weight=None, verbose=False, max_iter=-1, decision_function_shape=’ovr’, random_state=None)

# Some of methods of SVM()
# fit(X, y, [sample_weight])	Fit the SVM model according to the given training data.
# predict(X)	Perform classification on samples in X.
# --------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/mathematical-derivation-copy-8/
# --------------------------------


# clf = SVC(C=alpha[best_alpha],kernel='linear',probability=True, class_weight='balanced')
clf = SGDClassifier(alpha=alpha[best_alpha], penalty='l2', loss='hinge', random_state=42,class_weight='balanced')
predict_and_plot_confusion_matrix(train_x_onehotCoding, train_y,cv_x_onehotCoding,cv_y, clf)
# Out:
# Log loss : 1.0219671861400514
# Number of mis-classified points : 0.3383458646616541
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# <h3>4.3.3. Feature Importance</h3>

# %% [markdown]
# <h4>4.3.3.1. For Correctly classified point</h4>

# %%
clf = SGDClassifier(alpha=alpha[best_alpha], penalty='l2', loss='hinge', random_state=42)
clf.fit(train_x_onehotCoding,train_y)
test_point_index = 1
# test_point_index = 100
no_feature = 500
predicted_cls = sig_clf.predict(test_x_onehotCoding[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.coef_)[predicted_cls-1][:,:no_feature]
print("-"*50)
get_impfeature_names(indices[0], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 6
# Predicted Class Probabilities: [[0.0469 0.1628 0.0092 0.0359 0.0216 0.5647 0.1536 0.002  0.0033]]
# Actual Class : 2
# --------------------------------------------------
# 91 Text feature [values] present in test data point [True]
# 92 Text feature [blue] present in test data point [True]
# 94 Text feature [lapatinib] present in test data point [True]
# 103 Text feature [direct] present in test data point [True]
# 105 Text feature [substitutions] present in test data point [True]
# 106 Text feature [binds] present in test data point [True]
# 107 Text feature [showing] present in test data point [True]
# 109 Text feature [substitution] present in test data point [True]
# 112 Text feature [right] present in test data point [True]
# 113 Text feature [nucleotide] present in test data point [True]
# 114 Text feature [substrate] present in test data point [True]
# 115 Text feature [resistance] present in test data point [True]
# 116 Text feature [site] present in test data point [True]
# 118 Text feature [inhibitors] present in test data point [True]
# 119 Text feature [considered] present in test data point [True]
# 137 Text feature [factor] present in test data point [True]
# 138 Text feature [interactions] present in test data point [True]
# 139 Text feature [conformation] present in test data point [True]
# 140 Text feature [inhibition] present in test data point [True]
# 143 Text feature [42] present in test data point [True]
# 146 Text feature [models] present in test data point [True]
# 147 Text feature [powerpoint] present in test data point [True]
# 149 Text feature [metastatic] present in test data point [True]
# 150 Text feature [significant] present in test data point [True]
# 151 Text feature [dose] present in test data point [True]
# 153 Text feature [concentration] present in test data point [True]
# 156 Text feature [atp] present in test data point [True]
# 161 Text feature [basis] present in test data point [True]
# 162 Text feature [mechanism] present in test data point [True]
# 163 Text feature [induce] present in test data point [True]
# 166 Text feature [expected] present in test data point [True]
# 167 Text feature [erk] present in test data point [True]
# 170 Text feature [cause] present in test data point [True]
# 173 Text feature [manufacturer] present in test data point [True]
# 175 Text feature [showed] present in test data point [True]
# 217 Text feature [evidence] present in test data point [True]
# 218 Text feature [predicted] present in test data point [True]
# 219 Text feature [confer] present in test data point [True]
# 220 Text feature [type] present in test data point [True]
# 221 Text feature [use] present in test data point [True]
# 226 Text feature [inactive] present in test data point [True]
# 228 Text feature [dependent] present in test data point [True]
# 229 Text feature [single] present in test data point [True]
# 230 Text feature [determined] present in test data point [True]
# 232 Text feature [47] present in test data point [True]
# 233 Text feature [acid] present in test data point [True]
# 234 Text feature [approximately] present in test data point [True]
# 235 Text feature [ic50] present in test data point [True]
# 236 Text feature [structural] present in test data point [True]
# 237 Text feature [frequently] present in test data point [True]
# 239 Text feature [play] present in test data point [True]
# 240 Text feature [frequent] present in test data point [True]
# 241 Text feature [affect] present in test data point [True]
# 242 Text feature [loss] present in test data point [True]
# 244 Text feature [status] present in test data point [True]
# 245 Text feature [200] present in test data point [True]
# 246 Text feature [including] present in test data point [True]
# 247 Text feature [000] present in test data point [True]
# 249 Text feature [according] present in test data point [True]
# 252 Text feature [indicates] present in test data point [True]
# 253 Text feature [higher] present in test data point [True]
# 255 Text feature [free] present in test data point [True]
# 258 Text feature [identified] present in test data point [True]
# 259 Text feature [decreased] present in test data point [True]
# 260 Text feature [selection] present in test data point [True]
# 262 Text feature [active] present in test data point [True]
# 263 Text feature [ability] present in test data point [True]
# 264 Text feature [38] present in test data point [True]
# 265 Text feature [express] present in test data point [True]
# 266 Text feature [required] present in test data point [True]
# 268 Text feature [frequency] present in test data point [True]
# 270 Text feature [support] present in test data point [True]
# 272 Text feature [binding] present in test data point [True]
# 273 Text feature [screen] present in test data point [True]
# 275 Text feature [six] present in test data point [True]
# 277 Text feature [yet] present in test data point [True]
# 285 Text feature [targeted] present in test data point [True]
# 287 Text feature [thus] present in test data point [True]
# 289 Text feature [domains] present in test data point [True]
# 290 Text feature [download] present in test data point [True]
# 291 Text feature [erbb2] present in test data point [True]
# 292 Text feature [selective] present in test data point [True]
# 293 Text feature [wild] present in test data point [True]
# 294 Text feature [observation] present in test data point [True]
# 295 Text feature [inhibit] present in test data point [True]
# 296 Text feature [45] present in test data point [True]
# 297 Text feature [therapeutic] present in test data point [True]
# 299 Text feature [2006] present in test data point [True]
# 300 Text feature [mammalian] present in test data point [True]
# 301 Text feature [state] present in test data point [True]
# 302 Text feature [overall] present in test data point [True]
# 303 Text feature [important] present in test data point [True]
# 304 Text feature [receptor] present in test data point [True]
# 306 Text feature [bind] present in test data point [True]
# 307 Text feature [therapy] present in test data point [True]
# 308 Text feature [amplification] present in test data point [True]
# 309 Text feature [drug] present in test data point [True]
# 310 Text feature [double] present in test data point [True]
# 311 Text feature [five] present in test data point [True]
# 313 Text feature [activity] present in test data point [True]
# 315 Text feature [gel] present in test data point [True]
# 317 Text feature [potent] present in test data point [True]
# 363 Text feature [il] present in test data point [True]
# 364 Text feature [variant] present in test data point [True]
# 365 Text feature [regions] present in test data point [True]
# 366 Text feature [reaction] present in test data point [True]
# 367 Text feature [reported] present in test data point [True]
# 370 Text feature [subjected] present in test data point [True]
# 371 Text feature [response] present in test data point [True]
# 373 Text feature [helix] present in test data point [True]
# 375 Text feature [associated] present in test data point [True]
# 376 Text feature [20] present in test data point [True]
# 377 Text feature [ba] present in test data point [True]
# 378 Text feature [region] present in test data point [True]
# 379 Text feature [f3] present in test data point [True]
# 380 Text feature [example] present in test data point [True]
# 381 Text feature [35] present in test data point [True]
# 382 Text feature [loop] present in test data point [True]
# 383 Text feature [40] present in test data point [True]
# 386 Text feature [four] present in test data point [True]
# 387 Text feature [23] present in test data point [True]
# 389 Text feature [sequencing] present in test data point [True]
# 390 Text feature [differences] present in test data point [True]
# 391 Text feature [43] present in test data point [True]
# 392 Text feature [due] present in test data point [True]
# 394 Text feature [44] present in test data point [True]
# 395 Text feature [group] present in test data point [True]
# 399 Text feature [identification] present in test data point [True]
# 403 Text feature [time] present in test data point [True]
# 404 Text feature [phosphorylation] present in test data point [True]
# 405 Text feature [lung] present in test data point [True]
# 407 Text feature [ovarian] present in test data point [True]
# 409 Text feature [red] present in test data point [True]
# 410 Text feature [pathways] present in test data point [True]
# 411 Text feature [proteins] present in test data point [True]
# 412 Text feature [multiple] present in test data point [True]
# 413 Text feature [sequence] present in test data point [True]
# 416 Text feature [27] present in test data point [True]
# 419 Text feature [least] present in test data point [True]
# 421 Text feature [confirmed] present in test data point [True]
# 422 Text feature [kinase] present in test data point [True]
# 424 Text feature [development] present in test data point [True]
# 428 Text feature [formation] present in test data point [True]
# 429 Text feature [mechanisms] present in test data point [True]
# 430 Text feature [particular] present in test data point [True]
# 432 Text feature [spectrum] present in test data point [True]
# 433 Text feature [box] present in test data point [True]
# 435 Text feature [discussion] present in test data point [True]
# 438 Text feature [signal] present in test data point [True]
# 440 Text feature [51] present in test data point [True]
# 443 Text feature [stability] present in test data point [True]
# 445 Text feature [11] present in test data point [True]
# 446 Text feature [report] present in test data point [True]
# 451 Text feature [15] present in test data point [True]
# 453 Text feature [generation] present in test data point [True]
# 456 Text feature [value] present in test data point [True]
# 457 Text feature [combination] present in test data point [True]
# 460 Text feature [amino] present in test data point [True]
# 463 Text feature [dna] present in test data point [True]
# 465 Text feature [analysis] present in test data point [True]
# 468 Text feature [34] present in test data point [True]
# 470 Text feature [volume] present in test data point [True]
# 472 Text feature [measured] present in test data point [True]
# 474 Text feature [occur] present in test data point [True]
# 475 Text feature [potential] present in test data point [True]
# 478 Text feature [ref] present in test data point [True]
# 479 Text feature [acids] present in test data point [True]
# 480 Text feature [residues] present in test data point [True]
# 482 Text feature [clinically] present in test data point [True]
# 484 Text feature [30] present in test data point [True]
# 485 Text feature [total] present in test data point [True]
# 487 Text feature [context] present in test data point [True]
# 490 Text feature [methods] present in test data point [True]
# 491 Text feature [selected] present in test data point [True]
# 492 Text feature [stable] present in test data point [True]
# 493 Text feature [activation] present in test data point [True]
# 495 Text feature [mutational] present in test data point [True]
# 496 Text feature [culture] present in test data point [True]
# 497 Text feature [phosphorylated] present in test data point [True]
# 498 Text feature [included] present in test data point [True]
# Out of the top  500  features  180 are present in query point

# %% [markdown]
# <h4>4.3.3.2. For Incorrectly classified point</h4>

# %%
test_point_index = 100
no_feature = 500
predicted_cls = sig_clf.predict(test_x_onehotCoding[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.coef_)[predicted_cls-1][:,:no_feature]
print("-"*50)
get_impfeature_names(indices[0], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 7
# Predicted Class Probabilities: [[0.029  0.0605 0.0057 0.0187 0.0228 0.0075 0.8511 0.001  0.0037]]
# Actual Class : 7
# --------------------------------------------------
# 29 Text feature [downstream] present in test data point [True]
# 77 Text feature [000] present in test data point [True]
# 78 Text feature [codon] present in test data point [True]
# 79 Text feature [ras] present in test data point [True]
# 80 Text feature [phospho] present in test data point [True]
# 82 Text feature [activated] present in test data point [True]
# 83 Text feature [activate] present in test data point [True]
# 84 Text feature [activation] present in test data point [True]
# 85 Text feature [elevated] present in test data point [True]
# 86 Text feature [fold] present in test data point [True]
# 87 Text feature [constitutive] present in test data point [True]
# 88 Text feature [transformed] present in test data point [True]
# 90 Text feature [oncogene] present in test data point [True]
# 214 Text feature [regulated] present in test data point [True]
# 215 Text feature [overexpression] present in test data point [True]
# 216 Text feature [sensitive] present in test data point [True]
# 217 Text feature [gists] present in test data point [True]
# 218 Text feature [colony] present in test data point [True]
# 219 Text feature [expressing] present in test data point [True]
# 220 Text feature [extracellular] present in test data point [True]
# 221 Text feature [derived] present in test data point [True]
# 222 Text feature [regions] present in test data point [True]
# 223 Text feature [lung] present in test data point [True]
# 224 Text feature [contribute] present in test data point [True]
# 225 Text feature [3b] present in test data point [True]
# 229 Text feature [additional] present in test data point [True]
# 230 Text feature [wt] present in test data point [True]
# 231 Text feature [epithelial] present in test data point [True]
# 234 Text feature [oncogenic] present in test data point [True]
# 235 Text feature [without] present in test data point [True]
# 236 Text feature [examined] present in test data point [True]
# 237 Text feature [phase] present in test data point [True]
# 239 Text feature [deletion] present in test data point [True]
# 401 Text feature [distinct] present in test data point [True]
# 402 Text feature [positive] present in test data point [True]
# 403 Text feature [phosphorylated] present in test data point [True]
# 404 Text feature [per] present in test data point [True]
# 405 Text feature [leukemia] present in test data point [True]
# 406 Text feature [series] present in test data point [True]
# 408 Text feature [lead] present in test data point [True]
# 409 Text feature [note] present in test data point [True]
# 410 Text feature [pdgfr] present in test data point [True]
# 411 Text feature [days] present in test data point [True]
# 412 Text feature [1997] present in test data point [True]
# 413 Text feature [1998] present in test data point [True]
# 414 Text feature [enhanced] present in test data point [True]
# 415 Text feature [mutants] present in test data point [True]
# 416 Text feature [form] present in test data point [True]
# 417 Text feature [conditions] present in test data point [True]
# 418 Text feature [mm] present in test data point [True]
# 419 Text feature [concentrations] present in test data point [True]
# 420 Text feature [position] present in test data point [True]
# 421 Text feature [specimens] present in test data point [True]
# 422 Text feature [various] present in test data point [True]
# 424 Text feature [five] present in test data point [True]
# 425 Text feature [total] present in test data point [True]
# 428 Text feature [genomic] present in test data point [True]
# 429 Text feature [consistent] present in test data point [True]
# 430 Text feature [previously] present in test data point [True]
# 431 Text feature [pathways] present in test data point [True]
# 432 Text feature [occur] present in test data point [True]
# 434 Text feature [primer] present in test data point [True]
# 435 Text feature [approximately] present in test data point [True]
# 437 Text feature [akt] present in test data point [True]
# 438 Text feature [fig] present in test data point [True]
# 440 Text feature [cancers] present in test data point [True]
# 441 Text feature [obtained] present in test data point [True]
# 442 Text feature [basal] present in test data point [True]
# 443 Text feature [coding] present in test data point [True]
# 444 Text feature [observation] present in test data point [True]
# 445 Text feature [within] present in test data point [True]
# 446 Text feature [observations] present in test data point [True]
# 447 Text feature [corresponding] present in test data point [True]
# 448 Text feature [reverse] present in test data point [True]
# 449 Text feature [events] present in test data point [True]
# 450 Text feature [70] present in test data point [True]
# 451 Text feature [75] present in test data point [True]
# 453 Text feature [mechanisms] present in test data point [True]
# 454 Text feature [inhibitor] present in test data point [True]
# 455 Text feature [ligand] present in test data point [True]
# 456 Text feature [transduced] present in test data point [True]
# 458 Text feature [size] present in test data point [True]
# 459 Text feature [high] present in test data point [True]
# 460 Text feature [cdna] present in test data point [True]
# 461 Text feature [free] present in test data point [True]
# 462 Text feature [2012] present in test data point [True]
# 464 Text feature [made] present in test data point [True]
# 465 Text feature [presence] present in test data point [True]
# 466 Text feature [22] present in test data point [True]
# 467 Text feature [targeting] present in test data point [True]
# 468 Text feature [led] present in test data point [True]
# 469 Text feature [cycle] present in test data point [True]
# 470 Text feature [2003] present in test data point [True]
# 471 Text feature [harboring] present in test data point [True]
# 473 Text feature [subsequent] present in test data point [True]
# 474 Text feature [proliferation] present in test data point [True]
# 476 Text feature [receptors] present in test data point [True]
# 477 Text feature [open] present in test data point [True]
# 478 Text feature [insertion] present in test data point [True]
# 480 Text feature [comparison] present in test data point [True]
# Out of the top  500  features  100 are present in query point

# %% [markdown]
# <h2>4.5 Random Forest Classifier</h2>

# %% [markdown]
# <h3>4.5.1. Hyper paramter tuning (With One hot Encoding)</h3>

# %%
# --------------------------------
# default parameters 
# sklearn.ensemble.RandomForestClassifier(n_estimators=10, criterion=’gini’, max_depth=None, min_samples_split=2, 
# min_samples_leaf=1, min_weight_fraction_leaf=0.0, max_features=’auto’, max_leaf_nodes=None, min_impurity_decrease=0.0, 
# min_impurity_split=None, bootstrap=True, oob_score=False, n_jobs=1, random_state=None, verbose=0, warm_start=False, 
# class_weight=None)

# Some of methods of RandomForestClassifier()
# fit(X, y, [sample_weight])	Fit the SVM model according to the given training data.
# predict(X)	Perform classification on samples in X.
# predict_proba (X)	Perform classification on samples in X.

# some of attributes of  RandomForestClassifier()
# feature_importances_ : array of shape = [n_features]
# The feature importances (the higher, the more important the feature).

# --------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/random-forest-and-their-construction-2/
# --------------------------------


# find more about CalibratedClassifierCV here at http://scikit-learn.org/stable/modules/generated/sklearn.calibration.CalibratedClassifierCV.html
# ----------------------------
# default paramters
# sklearn.calibration.CalibratedClassifierCV(base_estimator=None, method=’sigmoid’, cv=3)
#
# some of the methods of CalibratedClassifierCV()
# fit(X, y[, sample_weight])	Fit the calibrated model
# get_params([deep])	Get parameters for this estimator.
# predict(X)	Predict the target of new samples.
# predict_proba(X)	Posterior probabilities of classification
#-------------------------------------
# video link:
#-------------------------------------

alpha = [100,200,500,1000,2000]
max_depth = [5, 10]
cv_log_error_array = []
for i in alpha:
    for j in max_depth:
        print("for n_estimators =", i,"and max depth = ", j)
        clf = RandomForestClassifier(n_estimators=i, criterion='gini', max_depth=j, random_state=42, n_jobs=-1)
        clf.fit(train_x_onehotCoding, train_y)
        sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
        sig_clf.fit(train_x_onehotCoding, train_y)
        sig_clf_probs = sig_clf.predict_proba(cv_x_onehotCoding)
        cv_log_error_array.append(log_loss(cv_y, sig_clf_probs, labels=clf.classes_, eps=1e-15))
        print("Log Loss :",log_loss(cv_y, sig_clf_probs)) 

'''fig, ax = plt.subplots()
features = np.dot(np.array(alpha)[:,None],np.array(max_depth)[None]).ravel()
ax.plot(features, cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[int(i/2)],max_depth[int(i%2)],str(txt)), (features[i],cv_log_error_array[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()
'''

best_alpha = np.argmin(cv_log_error_array)
clf = RandomForestClassifier(n_estimators=alpha[int(best_alpha/2)], criterion='gini', max_depth=max_depth[int(best_alpha%2)], random_state=42, n_jobs=-1)
clf.fit(train_x_onehotCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_onehotCoding, train_y)
best_alpha_rf=alpha[int(best_alpha/2)]
predict_y = sig_clf.predict_proba(train_x_onehotCoding)
print('For values of best estimator = ', alpha[int(best_alpha/2)], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
train_loss_rf=log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15)
predict_y = sig_clf.predict_proba(cv_x_onehotCoding)
print('For values of best estimator = ', alpha[int(best_alpha/2)], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
cv_loss_rf=log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15)
predict_y = sig_clf.predict_proba(test_x_onehotCoding)
print('For values of best estimator = ', alpha[int(best_alpha/2)], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
test_loss_rf=log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15)
# Out:
# for n_estimators = 100 and max depth =  5
# Log Loss : 1.2502317867883679
# for n_estimators = 100 and max depth =  10
# Log Loss : 1.2630778895800703
# for n_estimators = 200 and max depth =  5
# Log Loss : 1.2337528018022275
# for n_estimators = 200 and max depth =  10
# Log Loss : 1.253349503660297
# for n_estimators = 500 and max depth =  5
# Log Loss : 1.2226327625818187
# for n_estimators = 500 and max depth =  10
# Log Loss : 1.2500177318466825
# for n_estimators = 1000 and max depth =  5
# Log Loss : 1.2202084064147962
# for n_estimators = 1000 and max depth =  10
# Log Loss : 1.247153495913669
# for n_estimators = 2000 and max depth =  5
# Log Loss : 1.2180179738018773
# for n_estimators = 2000 and max depth =  10
# Log Loss : 1.2451065569828323
# For values of best estimator =  2000 The train log loss is: 0.8671504716348339
# For values of best estimator =  2000 The cross validation log loss is: 1.2180179738018775
# For values of best estimator =  2000 The test log loss is: 1.2036835141157372

# %% [markdown]
# <h3>4.5.2. Testing model with best hyper parameters (One Hot Encoding)</h3>

# %%
# --------------------------------
# default parameters 
# sklearn.ensemble.RandomForestClassifier(n_estimators=10, criterion=’gini’, max_depth=None, min_samples_split=2, 
# min_samples_leaf=1, min_weight_fraction_leaf=0.0, max_features=’auto’, max_leaf_nodes=None, min_impurity_decrease=0.0, 
# min_impurity_split=None, bootstrap=True, oob_score=False, n_jobs=1, random_state=None, verbose=0, warm_start=False, 
# class_weight=None)

# Some of methods of RandomForestClassifier()
# fit(X, y, [sample_weight])	Fit the SVM model according to the given training data.
# predict(X)	Perform classification on samples in X.
# predict_proba (X)	Perform classification on samples in X.

# some of attributes of  RandomForestClassifier()
# feature_importances_ : array of shape = [n_features]
# The feature importances (the higher, the more important the feature).

# --------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/random-forest-and-their-construction-2/
# --------------------------------

clf = RandomForestClassifier(n_estimators=alpha[int(best_alpha/2)], criterion='gini', max_depth=max_depth[int(best_alpha%2)], random_state=42, n_jobs=-1)
predict_and_plot_confusion_matrix(train_x_onehotCoding, train_y,cv_x_onehotCoding,cv_y, clf)
# Out:
# Log loss : 1.2180179738018773
# Number of mis-classified points : 0.424812030075188
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# <h3>4.5.3. Feature Importance</h3>

# %% [markdown]
# <h4>4.5.3.1. Correctly Classified point</h4>

# %%
# test_point_index = 10
clf = RandomForestClassifier(n_estimators=alpha[int(best_alpha/2)], criterion='gini', max_depth=max_depth[int(best_alpha%2)], random_state=42, n_jobs=-1)
clf.fit(train_x_onehotCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_onehotCoding, train_y)

test_point_index = 1
no_feature = 100
predicted_cls = sig_clf.predict(test_x_onehotCoding[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.feature_importances_)
print("-"*50)
get_impfeature_names(indices[:no_feature], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 7
# Predicted Class Probabilities: [[0.0274 0.2035 0.0169 0.0193 0.0377 0.2587 0.4306 0.0032 0.0027]]
# Actual Class : 2
# --------------------------------------------------
# 0 Text feature [kinase] present in test data point [True]
# 1 Text feature [activating] present in test data point [True]
# 2 Text feature [tyrosine] present in test data point [True]
# 3 Text feature [activation] present in test data point [True]
# 4 Text feature [activated] present in test data point [True]
# 5 Text feature [inhibitors] present in test data point [True]
# 7 Text feature [phosphorylation] present in test data point [True]
# 8 Text feature [function] present in test data point [True]
# 9 Text feature [treatment] present in test data point [True]
# 10 Text feature [constitutive] present in test data point [True]
# 11 Text feature [inhibitor] present in test data point [True]
# 12 Text feature [loss] present in test data point [True]
# 13 Text feature [transforming] present in test data point [True]
# 14 Text feature [oncogenic] present in test data point [True]
# 17 Text feature [receptor] present in test data point [True]
# 18 Text feature [pten] present in test data point [True]
# 20 Text feature [therapy] present in test data point [True]
# 21 Text feature [signaling] present in test data point [True]
# 22 Text feature [extracellular] present in test data point [True]
# 23 Text feature [protein] present in test data point [True]
# 24 Text feature [therapeutic] present in test data point [True]
# 25 Text feature [variants] present in test data point [True]
# 28 Text feature [erk] present in test data point [True]
# 32 Text feature [cells] present in test data point [True]
# 34 Text feature [growth] present in test data point [True]
# 36 Text feature [akt] present in test data point [True]
# 39 Text feature [functional] present in test data point [True]
# 42 Text feature [ba] present in test data point [True]
# 43 Text feature [activate] present in test data point [True]
# 44 Text feature [cell] present in test data point [True]
# 45 Text feature [drug] present in test data point [True]
# 46 Text feature [efficacy] present in test data point [True]
# 48 Text feature [proteins] present in test data point [True]
# 49 Text feature [expression] present in test data point [True]
# 51 Text feature [inhibition] present in test data point [True]
# 53 Text feature [f3] present in test data point [True]
# 54 Text feature [kinases] present in test data point [True]
# 55 Text feature [stability] present in test data point [True]
# 57 Text feature [resistance] present in test data point [True]
# 60 Text feature [patients] present in test data point [True]
# 61 Text feature [phosphatase] present in test data point [True]
# 63 Text feature [3t3] present in test data point [True]
# 66 Text feature [repair] present in test data point [True]
# 68 Text feature [ovarian] present in test data point [True]
# 69 Text feature [predicted] present in test data point [True]
# 71 Text feature [assays] present in test data point [True]
# 73 Text feature [clinical] present in test data point [True]
# 75 Text feature [ic50] present in test data point [True]
# 76 Text feature [survival] present in test data point [True]
# 78 Text feature [expressing] present in test data point [True]
# 82 Text feature [conserved] present in test data point [True]
# 83 Text feature [response] present in test data point [True]
# 84 Text feature [variant] present in test data point [True]
# 86 Text feature [use] present in test data point [True]
# 87 Text feature [ligand] present in test data point [True]
# 88 Text feature [expected] present in test data point [True]
# 91 Text feature [sensitivity] present in test data point [True]
# 93 Text feature [imatinib] present in test data point [True]
# 94 Text feature [activity] present in test data point [True]
# 95 Text feature [dna] present in test data point [True]
# 97 Text feature [based] present in test data point [True]
# 99 Text feature [serum] present in test data point [True]
# Out of the top  100  features  62 are present in query point

# %% [markdown]
# <h4>4.5.3.2. Inorrectly Classified point</h4>

# %%
test_point_index = 100
no_feature = 100
predicted_cls = sig_clf.predict(test_x_onehotCoding[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding[test_point_index]),4))
print("Actuall Class :", test_y[test_point_index])
indices = np.argsort(-clf.feature_importances_)
print("-"*50)
get_impfeature_names(indices[:no_feature], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 7
# Predicted Class Probabilities: [[0.0167 0.2194 0.0156 0.0093 0.0281 0.0217 0.6842 0.0021 0.003 ]]
# Actuall Class : 7
# --------------------------------------------------
# 0 Text feature [kinase] present in test data point [True]
# 1 Text feature [activating] present in test data point [True]
# 2 Text feature [tyrosine] present in test data point [True]
# 3 Text feature [activation] present in test data point [True]
# 4 Text feature [activated] present in test data point [True]
# 5 Text feature [inhibitors] present in test data point [True]
# 6 Text feature [suppressor] present in test data point [True]
# 7 Text feature [phosphorylation] present in test data point [True]
# 8 Text feature [function] present in test data point [True]
# 9 Text feature [treatment] present in test data point [True]
# 10 Text feature [constitutive] present in test data point [True]
# 11 Text feature [inhibitor] present in test data point [True]
# 12 Text feature [loss] present in test data point [True]
# 14 Text feature [oncogenic] present in test data point [True]
# 17 Text feature [receptor] present in test data point [True]
# 20 Text feature [therapy] present in test data point [True]
# 21 Text feature [signaling] present in test data point [True]
# 22 Text feature [extracellular] present in test data point [True]
# 23 Text feature [protein] present in test data point [True]
# 24 Text feature [therapeutic] present in test data point [True]
# 25 Text feature [variants] present in test data point [True]
# 26 Text feature [downstream] present in test data point [True]
# 31 Text feature [classified] present in test data point [True]
# 32 Text feature [cells] present in test data point [True]
# 33 Text feature [trials] present in test data point [True]
# 34 Text feature [growth] present in test data point [True]
# 36 Text feature [akt] present in test data point [True]
# 37 Text feature [treated] present in test data point [True]
# 38 Text feature [pathogenic] present in test data point [True]
# 39 Text feature [functional] present in test data point [True]
# 40 Text feature [constitutively] present in test data point [True]
# 41 Text feature [functions] present in test data point [True]
# 42 Text feature [ba] present in test data point [True]
# 43 Text feature [activate] present in test data point [True]
# 44 Text feature [cell] present in test data point [True]
# 45 Text feature [drug] present in test data point [True]
# 46 Text feature [efficacy] present in test data point [True]
# 48 Text feature [proteins] present in test data point [True]
# 49 Text feature [expression] present in test data point [True]
# 51 Text feature [inhibition] present in test data point [True]
# 53 Text feature [f3] present in test data point [True]
# 54 Text feature [kinases] present in test data point [True]
# 56 Text feature [months] present in test data point [True]
# 57 Text feature [resistance] present in test data point [True]
# 60 Text feature [patients] present in test data point [True]
# 62 Text feature [inhibited] present in test data point [True]
# 64 Text feature [advanced] present in test data point [True]
# 69 Text feature [predicted] present in test data point [True]
# 70 Text feature [stimulation] present in test data point [True]
# 71 Text feature [assays] present in test data point [True]
# 73 Text feature [clinical] present in test data point [True]
# 74 Text feature [phospho] present in test data point [True]
# 75 Text feature [ic50] present in test data point [True]
# 76 Text feature [survival] present in test data point [True]
# 78 Text feature [expressing] present in test data point [True]
# 80 Text feature [oncogene] present in test data point [True]
# 82 Text feature [conserved] present in test data point [True]
# 83 Text feature [response] present in test data point [True]
# 85 Text feature [proliferation] present in test data point [True]
# 86 Text feature [use] present in test data point [True]
# 87 Text feature [ligand] present in test data point [True]
# 88 Text feature [expected] present in test data point [True]
# 89 Text feature [risk] present in test data point [True]
# 91 Text feature [sensitivity] present in test data point [True]
# 92 Text feature [nsclc] present in test data point [True]
# 93 Text feature [imatinib] present in test data point [True]
# 94 Text feature [activity] present in test data point [True]
# 95 Text feature [dna] present in test data point [True]
# 96 Text feature [information] present in test data point [True]
# 97 Text feature [based] present in test data point [True]
# 99 Text feature [serum] present in test data point [True]
# Out of the top  100  features  71 are present in query point

# %% [markdown]
# <h3>4.5.3. Hyper paramter tuning (With Response Coding)</h3>

# %%
# --------------------------------
# default parameters 
# sklearn.ensemble.RandomForestClassifier(n_estimators=10, criterion=’gini’, max_depth=None, min_samples_split=2, 
# min_samples_leaf=1, min_weight_fraction_leaf=0.0, max_features=’auto’, max_leaf_nodes=None, min_impurity_decrease=0.0, 
# min_impurity_split=None, bootstrap=True, oob_score=False, n_jobs=1, random_state=None, verbose=0, warm_start=False, 
# class_weight=None)

# Some of methods of RandomForestClassifier()
# fit(X, y, [sample_weight])	Fit the SVM model according to the given training data.
# predict(X)	Perform classification on samples in X.
# predict_proba (X)	Perform classification on samples in X.

# some of attributes of  RandomForestClassifier()
# feature_importances_ : array of shape = [n_features]
# The feature importances (the higher, the more important the feature).

# --------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/random-forest-and-their-construction-2/
# --------------------------------


# find more about CalibratedClassifierCV here at http://scikit-learn.org/stable/modules/generated/sklearn.calibration.CalibratedClassifierCV.html
# ----------------------------
# default paramters
# sklearn.calibration.CalibratedClassifierCV(base_estimator=None, method=’sigmoid’, cv=3)
#
# some of the methods of CalibratedClassifierCV()
# fit(X, y[, sample_weight])	Fit the calibrated model
# get_params([deep])	Get parameters for this estimator.
# predict(X)	Predict the target of new samples.
# predict_proba(X)	Posterior probabilities of classification
#-------------------------------------
# video link:
#-------------------------------------

alpha = [10,50,100,200,500,1000]
max_depth = [2,3,5,10]
cv_log_error_array = []
for i in alpha:
    for j in max_depth:
        print("for n_estimators =", i,"and max depth = ", j)
        clf = RandomForestClassifier(n_estimators=i, criterion='gini', max_depth=j, random_state=42, n_jobs=-1)
        clf.fit(train_x_responseCoding, train_y)
        sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
        sig_clf.fit(train_x_responseCoding, train_y)
        sig_clf_probs = sig_clf.predict_proba(cv_x_responseCoding)
        cv_log_error_array.append(log_loss(cv_y, sig_clf_probs, labels=clf.classes_, eps=1e-15))
        print("Log Loss :",log_loss(cv_y, sig_clf_probs)) 
'''
fig, ax = plt.subplots()
features = np.dot(np.array(alpha)[:,None],np.array(max_depth)[None]).ravel()
ax.plot(features, cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[int(i/4)],max_depth[int(i%4)],str(txt)), (features[i],cv_log_error_array[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()
'''

best_alpha = np.argmin(cv_log_error_array)
clf = RandomForestClassifier(n_estimators=alpha[int(best_alpha/4)], criterion='gini', max_depth=max_depth[int(best_alpha%4)], random_state=42, n_jobs=-1)
clf.fit(train_x_responseCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_responseCoding, train_y)
best_alpha_rfrc=alpha[int(best_alpha/4)]
predict_y = sig_clf.predict_proba(train_x_responseCoding)
print('For values of best alpha = ', alpha[int(best_alpha/4)], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
train_loss_rfrc=log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15)
predict_y = sig_clf.predict_proba(cv_x_responseCoding)
print('For values of best alpha = ', alpha[int(best_alpha/4)], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
cv_loss_rfrc=log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15)
predict_y = sig_clf.predict_proba(test_x_responseCoding)
print('For values of best alpha = ', alpha[int(best_alpha/4)], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
test_loss_rfrc=log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15)
# Out:
# for n_estimators = 10 and max depth =  2
# Log Loss : 2.155966700921911
# for n_estimators = 10 and max depth =  3
# Log Loss : 1.8190796326344818
# for n_estimators = 10 and max depth =  5
# Log Loss : 1.562392775082956
# for n_estimators = 10 and max depth =  10
# Log Loss : 1.5688286207357605
# for n_estimators = 50 and max depth =  2
# Log Loss : 1.7726430500139152
# for n_estimators = 50 and max depth =  3
# Log Loss : 1.4533662137435852
# for n_estimators = 50 and max depth =  5
# Log Loss : 1.2638955053032033
# for n_estimators = 50 and max depth =  10
# Log Loss : 1.6191818392616781
# for n_estimators = 100 and max depth =  2
# Log Loss : 1.5944358122100906
# for n_estimators = 100 and max depth =  3
# Log Loss : 1.4697191126397173
# for n_estimators = 100 and max depth =  5
# Log Loss : 1.2330337792619523
# for n_estimators = 100 and max depth =  10
# Log Loss : 1.5886643578869504
# for n_estimators = 200 and max depth =  2
# Log Loss : 1.6046256860800177
# for n_estimators = 200 and max depth =  3
# Log Loss : 1.479798269110038
# for n_estimators = 200 and max depth =  5
# Log Loss : 1.2675466397565538
# for n_estimators = 200 and max depth =  10
# Log Loss : 1.5508765279379753
# for n_estimators = 500 and max depth =  2
# Log Loss : 1.657868836834346
# for n_estimators = 500 and max depth =  3
# Log Loss : 1.5366709632457332
# for n_estimators = 500 and max depth =  5
# Log Loss : 1.2990223220926307
# for n_estimators = 500 and max depth =  10
# Log Loss : 1.564781810952074
# for n_estimators = 1000 and max depth =  2
# Log Loss : 1.6329580027198343
# for n_estimators = 1000 and max depth =  3
# Log Loss : 1.5176202727483172
# for n_estimators = 1000 and max depth =  5
# Log Loss : 1.290608362825039
# for n_estimators = 1000 and max depth =  10
# Log Loss : 1.5621917950248034
# For values of best alpha =  100 The train log loss is: 0.053699240106292775
# For values of best alpha =  100 The cross validation log loss is: 1.2330337792619521
# For values of best alpha =  100 The test log loss is: 1.2562767312514533

# %% [markdown]
# <h3>4.5.4. Testing model with best hyper parameters (Response Coding)</h3>

# %%
# --------------------------------
# default parameters 
# sklearn.ensemble.RandomForestClassifier(n_estimators=10, criterion=’gini’, max_depth=None, min_samples_split=2, 
# min_samples_leaf=1, min_weight_fraction_leaf=0.0, max_features=’auto’, max_leaf_nodes=None, min_impurity_decrease=0.0, 
# min_impurity_split=None, bootstrap=True, oob_score=False, n_jobs=1, random_state=None, verbose=0, warm_start=False, 
# class_weight=None)

# Some of methods of RandomForestClassifier()
# fit(X, y, [sample_weight])	Fit the SVM model according to the given training data.
# predict(X)	Perform classification on samples in X.
# predict_proba (X)	Perform classification on samples in X.

# some of attributes of  RandomForestClassifier()
# feature_importances_ : array of shape = [n_features]
# The feature importances (the higher, the more important the feature).

# --------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/random-forest-and-their-construction-2/
# --------------------------------

clf = RandomForestClassifier(max_depth=max_depth[int(best_alpha%4)], n_estimators=alpha[int(best_alpha/4)], criterion='gini', max_features='auto',random_state=42)
predict_and_plot_confusion_matrix(train_x_responseCoding, train_y,cv_x_responseCoding,cv_y, clf)
# Out:
# Log loss : 1.2330337792619521
# Number of mis-classified points : 0.44360902255639095
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# <h3>4.5.5. Feature Importance</h3>

# %% [markdown]
# <h4>4.5.5.1. Correctly Classified point</h4>

# %%
clf = RandomForestClassifier(n_estimators=alpha[int(best_alpha/4)], criterion='gini', max_depth=max_depth[int(best_alpha%4)], random_state=42, n_jobs=-1)
clf.fit(train_x_responseCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_responseCoding, train_y)


test_point_index = 1
no_feature = 27
predicted_cls = sig_clf.predict(test_x_responseCoding[test_point_index].reshape(1,-1))
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_responseCoding[test_point_index].reshape(1,-1)),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.feature_importances_)
print("-"*50)
for i in indices:
    if i<9:
        print("Gene is important feature")
    elif i<18:
        print("Variation is important feature")
    else:
        print("Text is important feature")
# Out:
# Predicted Class : 6
# Predicted Class Probabilities: [[0.0133 0.3281 0.0559 0.0179 0.0203 0.4287 0.1137 0.0115 0.0105]]
# Actual Class : 2
# --------------------------------------------------
# Variation is important feature
# Variation is important feature
# Variation is important feature
# Variation is important feature
# Gene is important feature
# Variation is important feature
# Variation is important feature
# Text is important feature
# Text is important feature
# Gene is important feature
# Text is important feature
# Gene is important feature
# Text is important feature
# Text is important feature
# Gene is important feature
# Variation is important feature
# Text is important feature
# Gene is important feature
# Variation is important feature
# Gene is important feature
# Text is important feature
# Text is important feature
# Variation is important feature
# Gene is important feature
# Text is important feature
# Gene is important feature
# Gene is important feature

# %% [markdown]
# <h4>4.5.5.2. Incorrectly Classified point</h4>

# %%
test_point_index = 100
predicted_cls = sig_clf.predict(test_x_responseCoding[test_point_index].reshape(1,-1))
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_responseCoding[test_point_index].reshape(1,-1)),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.feature_importances_)
print("-"*50)
for i in indices:
    if i<9:
        print("Gene is important feature")
    elif i<18:
        print("Variation is important feature")
    else:
        print("Text is important feature")
# Out:
# Predicted Class : 3
# Predicted Class Probabilities: [[0.0112 0.3353 0.3688 0.0141 0.0104 0.0168 0.2228 0.0106 0.01  ]]
# Actual Class : 7
# --------------------------------------------------
# Variation is important feature
# Variation is important feature
# Variation is important feature
# Variation is important feature
# Gene is important feature
# Variation is important feature
# Variation is important feature
# Text is important feature
# Text is important feature
# Gene is important feature
# Text is important feature
# Gene is important feature
# Text is important feature
# Text is important feature
# Gene is important feature
# Variation is important feature
# Text is important feature
# Gene is important feature
# Variation is important feature
# Gene is important feature
# Text is important feature
# Text is important feature
# Variation is important feature
# Gene is important feature
# Text is important feature
# Gene is important feature
# Gene is important feature

# %% [markdown]
# <h2>4.7 Stack the models </h2>

# %% [markdown]
# <h3>4.7.1 testing with hyper parameter tuning</h3>

# %%
# read more about SGDClassifier() at http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.SGDClassifier.html
# ------------------------------
# default parameters
# SGDClassifier(loss=’hinge’, penalty=’l2’, alpha=0.0001, l1_ratio=0.15, fit_intercept=True, max_iter=None, tol=None, 
# shuffle=True, verbose=0, epsilon=0.1, n_jobs=1, random_state=None, learning_rate=’optimal’, eta0=0.0, power_t=0.5, 
# class_weight=None, warm_start=False, average=False, n_iter=None)

# some of methods
# fit(X, y[, coef_init, intercept_init, …])	Fit linear model with Stochastic Gradient Descent.
# predict(X)	Predict class labels for samples in X.

#-------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/geometric-intuition-1/
#------------------------------


# read more about support vector machines with linear kernals here http://scikit-learn.org/stable/modules/generated/sklearn.svm.SVC.html
# --------------------------------
# default parameters 
# SVC(C=1.0, kernel=’rbf’, degree=3, gamma=’auto’, coef0=0.0, shrinking=True, probability=False, tol=0.001, 
# cache_size=200, class_weight=None, verbose=False, max_iter=-1, decision_function_shape=’ovr’, random_state=None)

# Some of methods of SVM()
# fit(X, y, [sample_weight])	Fit the SVM model according to the given training data.
# predict(X)	Perform classification on samples in X.
# --------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/mathematical-derivation-copy-8/
# --------------------------------


# read more about support vector machines with linear kernals here http://scikit-learn.org/stable/modules/generated/sklearn.ensemble.RandomForestClassifier.html
# --------------------------------
# default parameters 
# sklearn.ensemble.RandomForestClassifier(n_estimators=10, criterion=’gini’, max_depth=None, min_samples_split=2, 
# min_samples_leaf=1, min_weight_fraction_leaf=0.0, max_features=’auto’, max_leaf_nodes=None, min_impurity_decrease=0.0, 
# min_impurity_split=None, bootstrap=True, oob_score=False, n_jobs=1, random_state=None, verbose=0, warm_start=False, 
# class_weight=None)

# Some of methods of RandomForestClassifier()
# fit(X, y, [sample_weight])	Fit the SVM model according to the given training data.
# predict(X)	Perform classification on samples in X.
# predict_proba (X)	Perform classification on samples in X.

# some of attributes of  RandomForestClassifier()
# feature_importances_ : array of shape = [n_features]
# The feature importances (the higher, the more important the feature).

# --------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/random-forest-and-their-construction-2/
# --------------------------------


clf1 = SGDClassifier(alpha=0.001, penalty='l2', loss='log', class_weight='balanced', random_state=0)
clf1.fit(train_x_onehotCoding, train_y)
sig_clf1 = CalibratedClassifierCV(clf1, method="sigmoid")

clf2 = SGDClassifier(alpha=1, penalty='l2', loss='hinge', class_weight='balanced', random_state=0)
clf2.fit(train_x_onehotCoding, train_y)
sig_clf2 = CalibratedClassifierCV(clf2, method="sigmoid")


clf3 = MultinomialNB(alpha=0.001)
clf3.fit(train_x_onehotCoding, train_y)
sig_clf3 = CalibratedClassifierCV(clf3, method="sigmoid")

sig_clf1.fit(train_x_onehotCoding, train_y)
print("Logistic Regression :  Log Loss: %0.2f" % (log_loss(cv_y, sig_clf1.predict_proba(cv_x_onehotCoding))))
sig_clf2.fit(train_x_onehotCoding, train_y)
print("Support vector machines : Log Loss: %0.2f" % (log_loss(cv_y, sig_clf2.predict_proba(cv_x_onehotCoding))))
sig_clf3.fit(train_x_onehotCoding, train_y)
print("Naive Bayes : Log Loss: %0.2f" % (log_loss(cv_y, sig_clf3.predict_proba(cv_x_onehotCoding))))
print("-"*50)
alpha = [0.0001,0.001,0.01,0.1,1,10] 
best_alpha_stack = 999
for i in alpha:
    lr = LogisticRegression(C=i)
    sclf = StackingClassifier(classifiers=[sig_clf1, sig_clf2, sig_clf3], meta_classifier=lr, use_probas=True)
    sclf.fit(train_x_onehotCoding, train_y)
    print("Stacking Classifer : for the value of alpha: %f Log Loss: %0.3f" % (i, log_loss(cv_y, sclf.predict_proba(cv_x_onehotCoding))))
    log_error =log_loss(cv_y, sclf.predict_proba(cv_x_onehotCoding))
    if best_alpha_stack > log_error:
        best_alpha_stack = log_error
# Out:
# Logistic Regression :  Log Loss: 1.01
# Support vector machines : Log Loss: 1.81
# Naive Bayes : Log Loss: 1.15
# --------------------------------------------------
# Stacking Classifer : for the value of alpha: 0.000100 Log Loss: 2.177
# Stacking Classifer : for the value of alpha: 0.001000 Log Loss: 2.030
# Stacking Classifer : for the value of alpha: 0.010000 Log Loss: 1.485
# Stacking Classifer : for the value of alpha: 0.100000 Log Loss: 1.130
# Stacking Classifer : for the value of alpha: 1.000000 Log Loss: 1.322
# Stacking Classifer : for the value of alpha: 10.000000 Log Loss: 1.756

# %% [markdown]
# <h3>4.7.2 testing the model with the best hyper parameters</h3>

# %%
lr = LogisticRegression(C=best_alpha_stack)
sclf = StackingClassifier(classifiers=[sig_clf1, sig_clf2, sig_clf3], meta_classifier=lr, use_probas=True)
sclf.fit(train_x_onehotCoding, train_y)

log_error = log_loss(train_y, sclf.predict_proba(train_x_onehotCoding))
print("Log loss (train) on the stacking classifier :",log_error)
train_loss_stack=log_error
log_error = log_loss(cv_y, sclf.predict_proba(cv_x_onehotCoding))
print("Log loss (CV) on the stacking classifier :",log_error)
cv_loss_stack=log_error
log_error = log_loss(test_y, sclf.predict_proba(test_x_onehotCoding))
print("Log loss (test) on the stacking classifier :",log_error)
test_loss_stack=log_error
print("Number of missclassified point :", np.count_nonzero((sclf.predict(test_x_onehotCoding)- test_y))/test_y.shape[0])
misc_classified_stack=(np.count_nonzero((sclf.predict(test_x_onehotCoding)- test_y))/test_y.shape[0])*100
plot_confusion_matrix(test_y=test_y, predict_y=sclf.predict(test_x_onehotCoding))
# Out:
# Log loss (train) on the stacking classifier : 0.15247477854637453
# Log loss (CV) on the stacking classifier : 1.3419964132548279
# Log loss (test) on the stacking classifier : 1.3981058976554377
# Number of missclassified point : 0.3879699248120301
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# <h3>4.7.3 Maximum Voting classifier </h3>

# %%
#Refer:http://scikit-learn.org/stable/modules/generated/sklearn.ensemble.VotingClassifier.html
from sklearn.ensemble import VotingClassifier
vclf = VotingClassifier(estimators=[('lr', sig_clf1), ('svc', sig_clf2), ('rf', sig_clf3)], voting='soft')
vclf.fit(train_x_onehotCoding, train_y)
print("Log loss (train) on the VotingClassifier :", log_loss(train_y, vclf.predict_proba(train_x_onehotCoding)))
train_loss_mvc=log_loss(train_y, vclf.predict_proba(train_x_onehotCoding))
print("Log loss (CV) on the VotingClassifier :", log_loss(cv_y, vclf.predict_proba(cv_x_onehotCoding)))
cv_loss_mvc=log_loss(cv_y, vclf.predict_proba(cv_x_onehotCoding))
print("Log loss (test) on the VotingClassifier :", log_loss(test_y, vclf.predict_proba(test_x_onehotCoding)))
test_loss_mvc=log_loss(test_y, vclf.predict_proba(test_x_onehotCoding))
print("Number of missclassified point :", np.count_nonzero((vclf.predict(test_x_onehotCoding)- test_y))/test_y.shape[0])
misc_classified_mvc=(np.count_nonzero((vclf.predict(test_x_onehotCoding)- test_y))/test_y.shape[0])*100
plot_confusion_matrix(test_y=test_y, predict_y=vclf.predict(test_x_onehotCoding))
# Out:
# Log loss (train) on the VotingClassifier : 0.8331892550670529
# Log loss (CV) on the VotingClassifier : 1.176728476308316
# Log loss (test) on the VotingClassifier : 1.2008388734520037
# Number of missclassified point : 0.3669172932330827
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# <h1>5. Assignments</h1>

# %% [markdown]
# <ol>
#     <li> Apply All the models with tf-idf features (Replace CountVectorizer with tfidfVectorizer and run the same cells)</li>
#     <li> Instead of using all the words in the dataset, use only the top 1000 words based of tf-idf values</li>
#     <li>Apply Logistic regression with CountVectorizer Features, including both unigrams and bigrams</li>
#     <li> Try any of the feature engineering techniques discussed in the course to reduce the CV and test log-loss to a value less than 1.0</li>
# </ol>

# %%
from prettytable import PrettyTable
    
x = PrettyTable()

x.field_names = ["index","MODEL","best_hyperparameter","Train_Loss","CV_Loss","Test_Loss","misclassified points in %"]
x.add_row([1,"random_model",'NAN',round(train_loss_ran,2),round(cv_loss_ran,2),round(test_loss_ran,2),"NAN"])
x.add_row([2,"Naive Bayes",best_alpha_nb,round(train_loss_nb,2),round(cv_loss_nb,2),round(test_loss_nb,2),round(misc_classified_nb,2)])
x.add_row([3,"K-NN",best_alpha_knn,round(train_loss_knn,2),round(cv_loss_knn,2),round(test_loss_knn,2),round(misc_classified[0],2)])
x.add_row([4,"Logistic Regression with class balancing",best_alpha_lr,round(train_loss_lr,2),round(cv_loss_lr,2),round(test_loss_lr,2),round(misc_classified[1],2)])
x.add_row([5,"Logistic Regression without class balancing",best_alpha_lrwb,round(train_loss_lrwb,2),round(cv_loss_lrwb,2),round(test_loss_lrwb,2),round(misc_classified[2],2)])
x.add_row([6,"Linear SVM",best_alpha_svm,round(train_loss_svm,2),round(cv_loss_svm,2),round(test_loss_svm,2),round(misc_classified[3],2)])
x.add_row([7,"Random Forest With one hot encoding",best_alpha_rf,round(train_loss_rf,2),round(cv_loss_rf,2),round(test_loss_rf,2),round(misc_classified[4],2)])
x.add_row([8,"Random Forest With one response coding",best_alpha_rfrc,round(train_loss_rfrc,2),round(cv_loss_rfrc,2),round(test_loss_rfrc,2),round(misc_classified[5],2)])
x.add_row([9,"stacking models",best_alpha_stack,round(train_loss_stack,2),round(cv_loss_stack,2),round(test_loss_stack,2),round(misc_classified_stack,2)])
x.add_row([10,"Maximum voting classifier","NAN",round(train_loss_mvc,2),round(cv_loss_mvc,2),round(test_loss_mvc,2),round(misc_classified_mvc,2)])
print(x)
# Out:
# +-------+---------------------------------------------+---------------------+------------+---------+-----------+---------------------------+
# | index |                    MODEL                    | best_hyperparameter | Train_Loss | CV_Loss | Test_Loss | misclassified points in % |
# +-------+---------------------------------------------+---------------------+------------+---------+-----------+---------------------------+
# |   1   |                 random_model                |         NAN         |    0.72    |   1.1   |    1.08   |            NAN            |
# |   2   |                 Naive Bayes                 |        0.001        |    0.52    |   1.15  |    1.2    |           37.22           |
# |   3   |                     K-NN                    |          11         |    0.64    |   0.99  |    1.04   |           34.77           |
# |   4   |   Logistic Regression with class balancing  |        0.0001       |    0.45    |   0.97  |    1.01   |           33.65           |
# |   5   | Logistic Regression without class balancing |        0.0001       |    0.44    |   1.01  |    1.04   |           33.65           |
# |   6   |                  Linear SVM                 |        0.0001       |    0.4     |   1.02  |    1.06   |           33.83           |
# |   7   |     Random Forest With one hot encoding     |         2000        |    0.87    |   1.22  |    1.2    |           42.48           |
# |   8   |    Random Forest With one response coding   |         100         |    0.05    |   1.23  |    1.26   |           44.36           |
# |   9   |               stacking models               |  1.1296517041217071 |    0.15    |   1.34  |    1.4    |            38.8           |
# |   10  |          Maximum voting classifier          |         NAN         |    0.83    |   1.18  |    1.2    |           36.69           |
# +-------+---------------------------------------------+---------------------+------------+---------+-----------+---------------------------+

# %% [markdown]
# #observations

# %% [markdown]
# we can see that for lot of models difference between train loss and cv,test loss is greater thn 30-40 percent which means they are overfitting.

# %% [markdown]
# #3rd part of assignment:applying count vectorizer on logistic regression using both uni and bigrams

# %%
# one-hot encoding of Gene feature.
gene_vectorizer = CountVectorizer()
train_gene_feature_onehotCoding = gene_vectorizer.fit_transform(train_df['Gene'])
test_gene_feature_onehotCoding = gene_vectorizer.transform(test_df['Gene'])
cv_gene_feature_onehotCoding = gene_vectorizer.transform(cv_df['Gene'])

# %%
# one-hot encoding of variation feature.
variation_vectorizer =  CountVectorizer()
train_variation_feature_onehotCoding = variation_vectorizer.fit_transform(train_df['Variation'])
test_variation_feature_onehotCoding = variation_vectorizer.transform(test_df['Variation'])
cv_variation_feature_onehotCoding = variation_vectorizer.transform(cv_df['Variation'])

# %%
# building a CountVectorizer with all the words that occured minimum 3 times in train data
text_vectorizer = CountVectorizer(ngram_range=(1,2),max_features=2000,min_df=5)
train_text_feature_onehotCoding = text_vectorizer.fit_transform(train_df['TEXT'])
# getting all the feature names (words)
train_text_features= text_vectorizer.get_feature_names()

# train_text_feature_onehotCoding.sum(axis=0).A1 will sum every row and returns (1*number of features) vector
train_text_fea_counts = train_text_feature_onehotCoding.sum(axis=0).A1

# zip(list(text_features),text_fea_counts) will zip a word with its number of times it occured
text_fea_dict = dict(zip(list(train_text_features),train_text_fea_counts))


print("Total number of unique words in train data :", len(train_text_features))
# Out:
# Total number of unique words in train data : 2000

# %%
# don't forget to normalize every feature
train_text_feature_onehotCoding = normalize(train_text_feature_onehotCoding, axis=0)

# we use the same vectorizer that was trained on train data
test_text_feature_onehotCoding = text_vectorizer.transform(test_df['TEXT'])
# don't forget to normalize every feature
test_text_feature_onehotCoding = normalize(test_text_feature_onehotCoding, axis=0)

# we use the same vectorizer that was trained on train data
cv_text_feature_onehotCoding = text_vectorizer.transform(cv_df['TEXT'])
# don't forget to normalize every feature
cv_text_feature_onehotCoding = normalize(cv_text_feature_onehotCoding, axis=0)

# %%
# merging gene, variance and text features

# building train, test and cross validation data sets
# a = [[1, 2], 
#      [3, 4]]
# b = [[4, 5], 
#      [6, 7]]
# hstack(a, b) = [[1, 2, 4, 5],
#                [ 3, 4, 6, 7]]

train_gene_var_onehotCoding = hstack((train_gene_feature_onehotCoding,train_variation_feature_onehotCoding))
test_gene_var_onehotCoding = hstack((test_gene_feature_onehotCoding,test_variation_feature_onehotCoding))
cv_gene_var_onehotCoding = hstack((cv_gene_feature_onehotCoding,cv_variation_feature_onehotCoding))

train_x_onehotCoding = hstack((train_gene_var_onehotCoding, train_text_feature_onehotCoding)).tocsr()
train_y = np.array(list(train_df['Class']))

test_x_onehotCoding = hstack((test_gene_var_onehotCoding, test_text_feature_onehotCoding)).tocsr()
test_y = np.array(list(test_df['Class']))

cv_x_onehotCoding = hstack((cv_gene_var_onehotCoding, cv_text_feature_onehotCoding)).tocsr()
cv_y = np.array(list(cv_df['Class']))


train_gene_var_responseCoding = np.hstack((train_gene_feature_responseCoding,train_variation_feature_responseCoding))
test_gene_var_responseCoding = np.hstack((test_gene_feature_responseCoding,test_variation_feature_responseCoding))
cv_gene_var_responseCoding = np.hstack((cv_gene_feature_responseCoding,cv_variation_feature_responseCoding))

train_x_responseCoding = np.hstack((train_gene_var_responseCoding, train_text_feature_responseCoding))
test_x_responseCoding = np.hstack((test_gene_var_responseCoding, test_text_feature_responseCoding))
cv_x_responseCoding = np.hstack((cv_gene_var_responseCoding, cv_text_feature_responseCoding))

# %%
alpha = [10 ** x for x in range(-6, 3)]
cv_log_error_array = []
for i in alpha:
    print("for alpha =", i)
    clf = SGDClassifier(class_weight='balanced', alpha=i, penalty='l2', loss='log', random_state=42)
    clf.fit(train_x_onehotCoding, train_y)
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_x_onehotCoding, train_y)
    sig_clf_probs = sig_clf.predict_proba(cv_x_onehotCoding)
    cv_log_error_array.append(log_loss(cv_y, sig_clf_probs, labels=clf.classes_, eps=1e-15))
    # to avoid rounding error while multiplying probabilites we use log-probability estimates
    print("Log Loss :",log_loss(cv_y, sig_clf_probs)) 

fig, ax = plt.subplots()
ax.plot(alpha, cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[i],str(txt)), (alpha[i],cv_log_error_array[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()


best_alpha = np.argmin(cv_log_error_array)
clf = SGDClassifier(class_weight='balanced', alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
clf.fit(train_x_onehotCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_onehotCoding, train_y)
best_alpha_lr1=alpha[best_alpha]
predict_y = sig_clf.predict_proba(train_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
train_loss_lr1=log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15)
predict_y = sig_clf.predict_proba(cv_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
cv_loss_lr1=log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15)
predict_y = sig_clf.predict_proba(test_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
test_loss_lr1=log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15)
# Out:
# for alpha = 1e-06
# Log Loss : 1.052440865139357
# for alpha = 1e-05
# Log Loss : 1.0249052673418906
# for alpha = 0.0001
# Log Loss : 0.9493579892547558
# for alpha = 0.001
# Log Loss : 1.012729455426623
# for alpha = 0.01
# Log Loss : 1.253466984174709
# for alpha = 0.1
# Log Loss : 1.747042986830622
# for alpha = 1
# Log Loss : 1.8023631090729937
# for alpha = 10
# Log Loss : 1.80738096380751
# for alpha = 100
# Log Loss : 1.8079216148084263
# For values of best alpha =  0.0001 The train log loss is: 0.4288898448742195
# For values of best alpha =  0.0001 The cross validation log loss is: 0.9493579892547558
# For values of best alpha =  0.0001 The test log loss is: 0.9779599748992106

# %%
alpha = [10 ** x for x in range(-6, 3)]
cv_log_error_array = []
for i in alpha:
    print("for alpha =", i)
    clf = SGDClassifier(alpha=i, penalty='l2', loss='log', random_state=42)
    clf.fit(train_x_onehotCoding, train_y)
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_x_onehotCoding, train_y)
    sig_clf_probs = sig_clf.predict_proba(cv_x_onehotCoding)
    cv_log_error_array.append(log_loss(cv_y, sig_clf_probs, labels=clf.classes_, eps=1e-15))
    # to avoid rounding error while multiplying probabilites we use log-probability estimates
    print("Log Loss :",log_loss(cv_y, sig_clf_probs)) 

fig, ax = plt.subplots()
ax.plot(alpha, cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[i],str(txt)), (alpha[i],cv_log_error_array[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()


best_alpha = np.argmin(cv_log_error_array)
clf = SGDClassifier(class_weight='balanced', alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
clf.fit(train_x_onehotCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_onehotCoding, train_y)
best_alpha_lrwb1=alpha[best_alpha]
predict_y = sig_clf.predict_proba(train_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
train_loss_lrwb1=log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15)
predict_y = sig_clf.predict_proba(cv_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
cv_loss_lrwb1=log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15)
predict_y = sig_clf.predict_proba(test_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
test_loss_lrwb1=log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15)
# Out:
# for alpha = 1e-06
# Log Loss : 1.1241707701967787
# for alpha = 1e-05
# Log Loss : 1.0405693666801084
# for alpha = 0.0001
# Log Loss : 0.9474580095285051
# for alpha = 0.001
# Log Loss : 1.0492630281868638
# for alpha = 0.01
# Log Loss : 1.310268510287078
# for alpha = 0.1
# Log Loss : 1.7076570749847622
# for alpha = 1
# Log Loss : 1.794671607327794
# for alpha = 10
# Log Loss : 1.801834972139799
# for alpha = 100
# Log Loss : 1.8026112370012672
# For values of best alpha =  0.0001 The train log loss is: 0.4288898448742195
# For values of best alpha =  0.0001 The cross validation log loss is: 0.9493579892547558
# For values of best alpha =  0.0001 The test log loss is: 0.9779599748992106

# %%
from prettytable import PrettyTable
    
x = PrettyTable()

x.field_names = ["index","MODEL","best_hyperparameter","Train_Loss","CV_Loss","Test_loss"]
x.add_row([1,"Logistic Regression with class balancing",best_alpha_lr1,round(train_loss_lr1,2),round(cv_loss_lr,2),round(test_loss_lr1,2)])
x.add_row([2,"Logistic Regression without class balancing",best_alpha_lrwb1,round(train_loss_lrwb1,2),round(cv_loss_lrwb1,2),round(test_loss_lrwb1,2)])
print(x)
# Out:
# +-------+---------------------------------------------+---------------------+------------+---------+-----------+
# | index |                    MODEL                    | best_hyperparameter | Train_Loss | CV_Loss | Test_loss |
# +-------+---------------------------------------------+---------------------+------------+---------+-----------+
# |   1   |   Logistic Regression with class balancing  |        0.0001       |    0.43    |   0.97  |    0.98   |
# |   2   | Logistic Regression without class balancing |        0.0001       |    0.43    |   0.95  |    0.98   |
# +-------+---------------------------------------------+---------------------+------------+---------+-----------+

# %% [markdown]
# #4.feauture engineering

# %%
# one-hot encoding of Gene feature.
gene_vectorizer = CountVectorizer()
train_gene_feature_onehotCoding = gene_vectorizer.fit_transform(train_df['Gene'])
test_gene_feature_onehotCoding = gene_vectorizer.transform(test_df['Gene'])
cv_gene_feature_onehotCoding = gene_vectorizer.transform(cv_df['Gene'])

# %%
# one-hot encoding of variation feature.
variation_vectorizer =  CountVectorizer()
train_variation_feature_onehotCoding = variation_vectorizer.fit_transform(train_df['Variation'])
test_variation_feature_onehotCoding = variation_vectorizer.transform(test_df['Variation'])
cv_variation_feature_onehotCoding = variation_vectorizer.transform(cv_df['Variation'])

# %%
# building a CountVectorizer with all the words that occured minimum 3 times in train data
text_vectorizer = TfidfVectorizer(ngram_range=(1,4),max_features=2000,min_df=5)
train_text_feature_onehotCoding = text_vectorizer.fit_transform(train_df['TEXT'])
# getting all the feature names (words)
train_text_features= text_vectorizer.get_feature_names()

# train_text_feature_onehotCoding.sum(axis=0).A1 will sum every row and returns (1*number of features) vector
train_text_fea_counts = train_text_feature_onehotCoding.sum(axis=0).A1

# zip(list(text_features),text_fea_counts) will zip a word with its number of times it occured
text_fea_dict = dict(zip(list(train_text_features),train_text_fea_counts))


print("Total number of unique words in train data :", len(train_text_features))
# Out:
# Total number of unique words in train data : 2000

# %%
# don't forget to normalize every feature
train_text_feature_onehotCoding = normalize(train_text_feature_onehotCoding, axis=0)

# we use the same vectorizer that was trained on train data
test_text_feature_onehotCoding = text_vectorizer.transform(test_df['TEXT'])
# don't forget to normalize every feature
test_text_feature_onehotCoding = normalize(test_text_feature_onehotCoding, axis=0)

# we use the same vectorizer that was trained on train data
cv_text_feature_onehotCoding = text_vectorizer.transform(cv_df['TEXT'])
# don't forget to normalize every feature
cv_text_feature_onehotCoding = normalize(cv_text_feature_onehotCoding, axis=0)

# %%
train_gene_var_onehotCoding = hstack((train_gene_feature_onehotCoding,train_variation_feature_onehotCoding))
test_gene_var_onehotCoding = hstack((test_gene_feature_onehotCoding,test_variation_feature_onehotCoding))
cv_gene_var_onehotCoding = hstack((cv_gene_feature_onehotCoding,cv_variation_feature_onehotCoding))

train_x_onehotCoding = hstack((train_gene_var_onehotCoding, train_text_feature_onehotCoding)).tocsr()
train_y = np.array(list(train_df['Class']))

test_x_onehotCoding = hstack((test_gene_var_onehotCoding, test_text_feature_onehotCoding)).tocsr()
test_y = np.array(list(test_df['Class']))

cv_x_onehotCoding = hstack((cv_gene_var_onehotCoding, cv_text_feature_onehotCoding)).tocsr()
cv_y = np.array(list(cv_df['Class']))


train_gene_var_responseCoding = np.hstack((train_gene_feature_responseCoding,train_variation_feature_responseCoding))
test_gene_var_responseCoding = np.hstack((test_gene_feature_responseCoding,test_variation_feature_responseCoding))
cv_gene_var_responseCoding = np.hstack((cv_gene_feature_responseCoding,cv_variation_feature_responseCoding))

train_x_responseCoding = np.hstack((train_gene_var_responseCoding, train_text_feature_responseCoding))
test_x_responseCoding = np.hstack((test_gene_var_responseCoding, test_text_feature_responseCoding))
cv_x_responseCoding = np.hstack((cv_gene_var_responseCoding, cv_text_feature_responseCoding))

# %%
alpha = [10 ** x for x in range(-6, 3)]
cv_log_error_array = []
for i in alpha:
    print("for alpha =", i)
    clf = SGDClassifier(class_weight='balanced', alpha=i, penalty='l2', loss='log', random_state=42)
    clf.fit(train_x_onehotCoding, train_y)
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_x_onehotCoding, train_y)
    sig_clf_probs = sig_clf.predict_proba(cv_x_onehotCoding)
    cv_log_error_array.append(log_loss(cv_y, sig_clf_probs, labels=clf.classes_, eps=1e-15))
    # to avoid rounding error while multiplying probabilites we use log-probability estimates
    print("Log Loss :",log_loss(cv_y, sig_clf_probs)) 

fig, ax = plt.subplots()
ax.plot(alpha, cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[i],str(txt)), (alpha[i],cv_log_error_array[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()


best_alpha = np.argmin(cv_log_error_array)
clf = SGDClassifier(class_weight='balanced', alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
clf.fit(train_x_onehotCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_onehotCoding, train_y)
best_alpha_lr2=alpha[best_alpha]
predict_y = sig_clf.predict_proba(train_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
train_loss_lr2=log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15)
predict_y = sig_clf.predict_proba(cv_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
cv_loss_lr2=log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15)
predict_y = sig_clf.predict_proba(test_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
test_loss_lr2=log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15)
# Out:
# for alpha = 1e-06
# Log Loss : 1.0642018175266876
# for alpha = 1e-05
# Log Loss : 1.0027680777873165
# for alpha = 0.0001
# Log Loss : 0.9741953602376605
# for alpha = 0.001
# Log Loss : 1.0164634554674377
# for alpha = 0.01
# Log Loss : 1.1201045137945682
# for alpha = 0.1
# Log Loss : 1.6831903603426037
# for alpha = 1
# Log Loss : 1.8271638738568712
# for alpha = 10
# Log Loss : 1.8422929856606414
# for alpha = 100
# Log Loss : 1.8440299693482218
# For values of best alpha =  0.0001 The train log loss is: 0.43511266617184785
# For values of best alpha =  0.0001 The cross validation log loss is: 0.9741953602376605
# For values of best alpha =  0.0001 The test log loss is: 0.9988717873380716

# %%
alpha = [10 ** x for x in range(-6, 3)]
cv_log_error_array = []
for i in alpha:
    print("for alpha =", i)
    clf = SGDClassifier(alpha=i, penalty='l2', loss='log', random_state=42)
    clf.fit(train_x_onehotCoding, train_y)
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_x_onehotCoding, train_y)
    sig_clf_probs = sig_clf.predict_proba(cv_x_onehotCoding)
    cv_log_error_array.append(log_loss(cv_y, sig_clf_probs, labels=clf.classes_, eps=1e-15))
    # to avoid rounding error while multiplying probabilites we use log-probability estimates
    print("Log Loss :",log_loss(cv_y, sig_clf_probs)) 

fig, ax = plt.subplots()
ax.plot(alpha, cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[i],str(txt)), (alpha[i],cv_log_error_array[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()


best_alpha = np.argmin(cv_log_error_array)
clf = SGDClassifier(class_weight='balanced', alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
clf.fit(train_x_onehotCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_onehotCoding, train_y)
best_alpha_lrwb2=alpha[best_alpha]
predict_y = sig_clf.predict_proba(train_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
train_loss_lrwb2=log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15)
predict_y = sig_clf.predict_proba(cv_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
cv_loss_lrwb2=log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15)
predict_y = sig_clf.predict_proba(test_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
test_loss_lrwb2=log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15)
# Out:
# for alpha = 1e-06
# Log Loss : 1.0816857244964087
# for alpha = 1e-05
# Log Loss : 1.0508776589945543
# for alpha = 0.0001
# Log Loss : 0.9978298412872423
# for alpha = 0.001
# Log Loss : 1.0738405605156969
# for alpha = 0.01
# Log Loss : 1.2613805262659437
# for alpha = 0.1
# Log Loss : 1.6552853343613576
# for alpha = 1
# Log Loss : 1.822002883250581
# for alpha = 10
# Log Loss : 1.8430861523227862
# for alpha = 100
# Log Loss : 1.8455271433926659
# For values of best alpha =  0.0001 The train log loss is: 0.43511266617184785
# For values of best alpha =  0.0001 The cross validation log loss is: 0.9741953602376605
# For values of best alpha =  0.0001 The test log loss is: 0.9988717873380716

# %%
alpha = [10 ** x for x in range(-5, 3)]
cv_log_error_array = []
for i in alpha:
    print("for C =", i)
#     clf = SVC(C=i,kernel='linear',probability=True, class_weight='balanced')
    clf = SGDClassifier( class_weight='balanced', alpha=i, penalty='l2', loss='hinge', random_state=42)
    clf.fit(train_x_onehotCoding, train_y)
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_x_onehotCoding, train_y)
    sig_clf_probs = sig_clf.predict_proba(cv_x_onehotCoding)
    cv_log_error_array.append(log_loss(cv_y, sig_clf_probs, labels=clf.classes_, eps=1e-15))
    print("Log Loss :",log_loss(cv_y, sig_clf_probs)) 

fig, ax = plt.subplots()
ax.plot(alpha, cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[i],str(txt)), (alpha[i],cv_log_error_array[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()


best_alpha = np.argmin(cv_log_error_array)
# clf = SVC(C=i,kernel='linear',probability=True, class_weight='balanced')
clf = SGDClassifier(class_weight='balanced', alpha=alpha[best_alpha], penalty='l2', loss='hinge', random_state=42)
clf.fit(train_x_onehotCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_onehotCoding, train_y)
best_alpha_svm2=alpha[best_alpha]
predict_y = sig_clf.predict_proba(train_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
train_loss_svm2=log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15)
predict_y = sig_clf.predict_proba(cv_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
cv_loss_svm2=log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15)
predict_y = sig_clf.predict_proba(test_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
test_loss_svm2=log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15)
# Out:
# for C = 1e-05
# Log Loss : 1.0438969563006475
# for C = 0.0001
# Log Loss : 0.9831745744431578
# for C = 0.001
# Log Loss : 1.016759853439933
# for C = 0.01
# Log Loss : 1.183665485455226
# for C = 0.1
# Log Loss : 1.691896133647068
# for C = 1
# Log Loss : 1.844474254478952
# for C = 10
# Log Loss : 1.8444741488256413
# for C = 100
# Log Loss : 1.8444742755329637
# For values of best alpha =  0.0001 The train log loss is: 0.40030449687759684
# For values of best alpha =  0.0001 The cross validation log loss is: 0.9831745744431578
# For values of best alpha =  0.0001 The test log loss is: 1.01610550269017

# %%
x = PrettyTable()

x.field_names = ["index","MODEL","best_hyperparameter","Train_Loss","CV_Loss","Test_loss"]
x.add_row([2,"Logistic Regression with class balancing",best_alpha_lr2,round(train_loss_lr2,2),round(cv_loss_lr2,3),round(test_loss_lr2,3)])
x.add_row([3,"Logistic Regression without class balancing",best_alpha_lrwb2,round(train_loss_lrwb2,2),round(cv_loss_lrwb2,3),round(test_loss_lrwb2,3)])
x.add_row([4,"Linear SVM",best_alpha_svm2,round(train_loss_svm2,2),round(cv_loss_svm2,2),round(test_loss_svm2,2)])
print(x.get_string(title="TASK 4:Feauture Engineeing with ngrams,max_feautures,vectorizers"))
# Out:
# +-------+---------------------------------------------+---------------------+------------+---------+-----------+
# | index |                    MODEL                    | best_hyperparameter | Train_Loss | CV_Loss | Test_loss |
# +-------+---------------------------------------------+---------------------+------------+---------+-----------+
# |   2   |   Logistic Regression with class balancing  |        0.0001       |    0.44    |  0.974  |   0.999   |
# |   3   | Logistic Regression without class balancing |        0.0001       |    0.44    |  0.974  |   0.999   |
# |   4   |                  Linear SVM                 |        0.0001       |    0.4     |   0.98  |    1.02   |
# +-------+---------------------------------------------+---------------------+------------+---------+-----------+

# %% [markdown]
# #observation

# %% [markdown]
# by performing feature engineering like ngram_range=(1,4),max_features=2000,min_df=5 test loss and cv loss of logistic regression with claas_weight=balanced is reduced to less than 1.

# %% [markdown]
# #CONCLUSION:

# %%
from prettytable import PrettyTable
    
x = PrettyTable()
x.field_names = ["index","MODEL","best_hyperparameter","Train_Loss","CV_Loss","Test_Loss","misclassified points in %"]
x.add_row([1,"random_model",'NAN',round(train_loss_ran,2),round(cv_loss_ran,2),round(test_loss_ran,2),"NAN"])
x.add_row([2,"Naive Bayes",best_alpha_nb,round(train_loss_nb,2),round(cv_loss_nb,2),round(test_loss_nb,2),round(misc_classified_nb,2)])
x.add_row([3,"K-NN",best_alpha_knn,round(train_loss_knn,2),round(cv_loss_knn,2),round(test_loss_knn,2),round(misc_classified[0],2)])
x.add_row([4,"Logistic Regression with class balancing",best_alpha_lr,round(train_loss_lr,2),round(cv_loss_lr,2),round(test_loss_lr,2),round(misc_classified[1],2)])
x.add_row([5,"Logistic Regression without class balancing",best_alpha_lrwb,round(train_loss_lrwb,2),round(cv_loss_lrwb,2),round(test_loss_lrwb,2),round(misc_classified[2],2)])
x.add_row([6,"Linear SVM",best_alpha_svm,round(train_loss_svm,2),round(cv_loss_svm,2),round(test_loss_svm,2),round(misc_classified[3],2)])
x.add_row([7,"Random Forest With one hot encoding",best_alpha_rf,round(train_loss_rf,2),round(cv_loss_rf,2),round(test_loss_rf,2),round(misc_classified[4],2)])
x.add_row([8,"Random Forest With one response coding",best_alpha_rfrc,round(train_loss_rfrc,2),round(cv_loss_rfrc,2),round(test_loss_rfrc,2),round(misc_classified[5],2)])
x.add_row([9,"stacking models",best_alpha_stack,round(train_loss_stack,2),round(cv_loss_stack,2),round(test_loss_stack,2),round(misc_classified_stack,2)])
x.add_row([10,"Maximum voting classifier","NAN",round(train_loss_mvc,2),round(cv_loss_mvc,2),round(test_loss_mvc,2),round(misc_classified_mvc,2)])
print(x.get_string(title="TASK 1 & 2:Tfidf_Vectorizer-max_feautures=1000"))

    
x = PrettyTable()

x.field_names = ["index","MODEL","best_hyperparameter","Train_Loss","CV_Loss","Test_loss"]
x.add_row([1,"Logistic Regression with class balancing",best_alpha_lr1,round(train_loss_lr1,2),round(cv_loss_lr1,2),round(test_loss_lr1,2)])
x.add_row([2,"Logistic Regression without class balancing",best_alpha_lrwb1,round(train_loss_lrwb1,2),round(cv_loss_lrwb1,2),round(test_loss_lrwb1,2)])
print(x.get_string(title="TASK3:CountVectorizer on logistic regression with and without class balancing"))

x = PrettyTable()

x.field_names = ["index","MODEL","best_hyperparameter","Train_Loss","CV_Loss","Test_loss"]
x.add_row([2,"Logistic Regression with class balancing",best_alpha_lr2,round(train_loss_lr2,2),round(cv_loss_lr2,3),round(test_loss_lr2,3)])
x.add_row([3,"Logistic Regression without class balancing",best_alpha_lrwb2,round(train_loss_lrwb2,2),round(cv_loss_lrwb2,3),round(test_loss_lrwb2,3)])
x.add_row([4,"Linear SVM",best_alpha_svm2,round(train_loss_svm2,2),round(cv_loss_svm2,2),round(test_loss_svm2,2)])
print(x.get_string(title="TASK 4:Feauture Engineeing with ngrams,max_feautures,vectorizers"))
# Out:
# +-------+---------------------------------------------+---------------------+------------+---------+-----------+---------------------------+
# | index |                    MODEL                    | best_hyperparameter | Train_Loss | CV_Loss | Test_Loss | misclassified points in % |
# +-------+---------------------------------------------+---------------------+------------+---------+-----------+---------------------------+
# |   1   |                 random_model                |         NAN         |    0.72    |   1.1   |    1.08   |            NAN            |
# |   2   |                 Naive Bayes                 |        0.001        |    0.52    |   1.15  |    1.2    |           37.22           |
# |   3   |                     K-NN                    |          11         |    0.64    |   0.99  |    1.04   |           34.77           |
# |   4   |   Logistic Regression with class balancing  |        0.0001       |    0.45    |   0.97  |    1.01   |           33.65           |
# |   5   | Logistic Regression without class balancing |        0.0001       |    0.44    |   1.01  |    1.04   |           33.65           |
# |   6   |                  Linear SVM                 |        0.0001       |    0.4     |   1.02  |    1.06   |           33.83           |
# |   7   |     Random Forest With one hot encoding     |         2000        |    0.87    |   1.22  |    1.2    |           42.48           |
# |   8   |    Random Forest With one response coding   |         100         |    0.05    |   1.23  |    1.26   |           44.36           |
# |   9   |               stacking models               |  1.1296517041217071 |    0.15    |   1.34  |    1.4    |            38.8           |
# |   10  |          Maximum voting classifier          |         NAN         |    0.83    |   1.18  |    1.2    |           36.69           |
# +-------+---------------------------------------------+---------------------+------------+---------+-----------+---------------------------+
# +-------+---------------------------------------------+---------------------+------------+---------+-----------+
# | index |                    MODEL                    | best_hyperparameter | Train_Loss | CV_Loss | Test_loss |
# +-------+---------------------------------------------+---------------------+------------+---------+-----------+
# |   1   |   Logistic Regression with class balancing  |        0.0001       |    0.43    |   0.95  |    0.98   |
# |   2   | Logistic Regression without class balancing |        0.0001       |    0.43    |   0.95  |    0.98   |
# +-------+---------------------------------------------+---------------------+------------+---------+-----------+
# +-------+---------------------------------------------+---------------------+------------+---------+-----------+
# | index |                    MODEL                    | best_hyperparameter | Train_Loss | CV_Loss | Test_loss |
# +-------+---------------------------------------------+---------------------+------------+---------+-----------+
# |   2   |   Logistic Regression with class balancing  |        0.0001       |    0.44    |  0.974  |   0.999   |
# |   3   | Logistic Regression without class balancing |        0.0001       |    0.44    |  0.974  |   0.999   |
# |   4   |                  Linear SVM                 |        0.0001       |    0.4     |   0.98  |    1.02   |
# +-------+---------------------------------------------+---------------------+------------+---------+-----------+

# %% [markdown]
# #Tasks performed in  this particular case study

# %% [markdown]
# **TASK 1 & 2**: Applied all the models are with TfidfVectorizer with max features =1000 based on tfidf scores on text data
# <br>
# **TASK 3**: countvectorizer is applied on logistic regression with and without balancing class labels.
# <br>
# **TASK 4**:Feauture enginnering is applied on any one of the above models to obtain cv and test log loss less than 1.
# <br>
# For each task results are represented using pretty table and observations are made using pretty table.
